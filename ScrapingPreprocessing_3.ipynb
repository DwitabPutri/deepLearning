# %%
# !pip install requests beautifulsoup4 lxml tqdm
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (5.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)

# %% [markdown]
# # Scraping Money

# %%
from google.colab import drive
import os

# Tentukan folder dan file output di Drive
DRIVE_FOLDER = "/content/drive/MyDrive/KompasMoney"
os.makedirs(DRIVE_FOLDER, exist_ok=True)

OUTPUT_CSV = os.path.join(DRIVE_FOLDER, "kompas_money_scraped.csv")
print("Folder Drive:", DRIVE_FOLDER)
print("File output :", OUTPUT_CSV)
# Out:
# Folder Drive: /content/drive/MyDrive/KompasMoney
# File output : /content/drive/MyDrive/KompasMoney/kompas_money_scraped.csv

# %%
# Scraper Kompas Money (menu-aware + subcategory + tags + resumeable)

import os, re, time, csv, random, json
from urllib.parse import urljoin, urlparse
import requests
from bs4 import BeautifulSoup
from collections import OrderedDict
from tqdm import tqdm

# ==========================
# Konfigurasi umum
# ==========================
BASE = "https://money.kompas.com/"
REQUEST_DELAY = (0.8, 1.6)
TIMEOUT = 20
MAX_PAGES_PER_SUB = None  # None = lanjut sampai 3 halaman kosong berturut-turut
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
}

# ==========================
# Session HTTP dengan retry
# ==========================
from requests.adapters import HTTPAdapter, Retry

def make_session():
    s = requests.Session()
    retries = Retry(
        total=5, connect=5, read=5,
        backoff_factor=1.2,
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=frozenset(["GET"])
    )
    s.headers.update(HEADERS)
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.mount("http://", HTTPAdapter(max_retries=retries))
    return s

SESSION = make_session()

# ==========================
# CSV helper
# ==========================
FIELDNAMES = ["url", "category", "subcategory", "tanggal_publish", "judul", "tags", "konten"]

def ensure_csv(path):
    if not os.path.exists(path):
        with open(path, "w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=FIELDNAMES)
            writer.writeheader()

def load_done_urls(path):
    done = set()
    if os.path.exists(path):
        with open(path, "r", encoding="utf-8") as f:
            r = csv.DictReader(f)
            for row in r:
                u = (row.get("url") or "").strip()
                if u:
                    done.add(u)
    return done

def append_row(path, row: dict):
    clean = {k: (row.get(k) or "") for k in FIELDNAMES}
    with open(path, "a", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=FIELDNAMES)
        w.writerow(clean)

# ==========================
# Utilities
# ==========================
def normalize_ws(text):
    return re.sub(r"\s+", " ", (text or "").strip())

def looks_like_baca_juga(text):
    return "baca juga" in (text or "").lower()

def safe_get(url):
    r = SESSION.get(url, timeout=TIMEOUT)
    r.raise_for_status()
    return r

def absolutize(base_url, href):
    if href.startswith("//"):
        return "https:" + href
    if href.startswith("/"):
        parsed = urlparse(base_url)
        return f"{parsed.scheme}://{parsed.netloc}{href}"
    return href

# ==========================
# Dapatkan daftar sub-kategori dari menu
# ==========================
def discover_menu_links():
    found = OrderedDict()
    try:
        r = safe_get(BASE)
        soup = BeautifulSoup(r.text, "lxml")
        for a in soup.select(".kanalHeader[data-kanal='money'] .kanalMenu a[href]"):
            name = normalize_ws(a.get_text())
            href = absolutize(BASE, a.get("href","").strip())
            if not href or not name:
                continue
            found[href] = name
    except Exception:
        pass

    # fallback kalau parsing gagal
    SEED = OrderedDict([
        ("https://money.kompas.com/ekbis", "Ekbis"),
        ("https://money.kompas.com/keuangan", "Keuangan"),
        ("https://money.kompas.com/syariah", "Syariah"),
        ("https://money.kompas.com/industri", "Industri"),
        ("https://money.kompas.com/energi", "Energi"),
        ("https://money.kompas.com/belanja", "Belanja"),
        ("https://money.kompas.com/cuan", "Cuan"),
        ("https://money.kompas.com/karier", "Karier"),
    ])
    for href, name in SEED.items():
        found.setdefault(href, name)

    return list(found.items())

# ==========================
# Ambil daftar URL artikel per subcategory
# ==========================
def is_article_url(href: str):
    if not href or "kompas.com" not in href:
        return False
    if "/read/" not in href:
        return False
    if any(b in href for b in ["/komentar/", "/copy/"]):
        return False
    return True

def collect_urls_from_list(listing_url):
    try:
        res = safe_get(listing_url)
    except Exception:
        return set()
    soup = BeautifulSoup(res.text, "lxml")
    urls = set()
    for a in soup.select("a[href*='/read/']"):
        href = a.get("href")
        if not href:
            continue
        full = absolutize(listing_url, href)
        if is_article_url(full):
            urls.add(full)
    return urls

def page_url(base, page):
    if page <= 1:
        return base
    parsed = urlparse(base)
    joiner = "&" if parsed.query else "?"
    return f"{base}{joiner}page={page}"

def crawl_subcategory_urls(sub_url, max_pages=None):
    discovered = OrderedDict()
    consecutive_empty = 0
    page = 1
    while True:
        if max_pages is not None and page > max_pages:
            break
        url = page_url(sub_url, page)
        urls = collect_urls_from_list(url)
        before = len(discovered)
        for u in sorted(urls):
            discovered.setdefault(u, None)
        gained = len(discovered) - before
        print(f"  [page={page}] +{gained} URL (total {len(discovered)})")
        time.sleep(random.uniform(*REQUEST_DELAY))
        consecutive_empty = consecutive_empty + 1 if gained == 0 else 0
        if consecutive_empty >= 3:
            break
        page += 1
    return list(discovered.keys())

# ==========================
# Parsing artikel
# ==========================
def extract_publish_date(soup):
    meta = soup.find("meta", attrs={"name": "content_PublishedDate"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    meta2 = soup.select_one('meta[property="article:published_time"]')
    if meta2 and meta2.get("content"):
        return meta2["content"].strip()
    return ""

def extract_tags(soup):
    meta = soup.find("meta", attrs={"name": "content_tags"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    tag_links = soup.select("a.tag__article__link, .tag__item a")
    if tag_links:
        tags = [normalize_ws(a.get_text()) for a in tag_links if a.get_text().strip()]
        return ", ".join(tags)
    return ""

def parse_article(url):
    res = safe_get(url)
    soup = BeautifulSoup(res.text, "lxml")
    title_el = soup.select_one("h1.read__title") or soup.select_one("h1.article__title") or soup.select_one("h1")
    judul = normalize_ws(title_el.get_text()) if title_el else normalize_ws(soup.title.get_text() if soup.title else "")
    tanggal_publish = extract_publish_date(soup)
    tags = extract_tags(soup)
    wrapper = soup.select_one(".read__content") or soup.select_one(".article__content") or soup
    ps = wrapper.find_all("p")
    paragraphs = []
    for p in ps:
        txt = p.get_text(" ").strip()
        if not txt:
            continue
        if looks_like_baca_juga(txt):
            continue
        if "KOMPAS.com" in txt and "Download" in txt:
            continue
        paragraphs.append(normalize_ws(txt))
    konten = " ".join(paragraphs)
    return {"judul": judul, "tanggal_publish": tanggal_publish, "tags": tags, "konten": konten}

# ==========================
# Pipeline utama
# ==========================
def run_scrape_money(output_csv_path, max_pages_per_sub=None):
    ensure_csv(output_csv_path)
    done = load_done_urls(output_csv_path)
    print(f"URL sudah ada di CSV: {len(done)}")

    submenus = discover_menu_links()
    print("Sub-kategori terdeteksi:")
    for href, name in submenus:
        print(f" - {name}: {href}")

    all_urls = OrderedDict()
    for href, name in submenus:
        print(f"\nCrawl sub-kategori: {name}")
        urls = crawl_subcategory_urls(href, max_pages=max_pages_per_sub)
        for u in urls:
            all_urls.setdefault((u, name), None)

    print(f"\nTotal kandidat (URL unik per sub): {len(all_urls)}")

    category = "Money"
    saved = 0
    for i, ((url, subcat), _) in enumerate(tqdm(all_urls.items(), desc="Scraping", unit="url"), 1):
        if url in done:
            continue
        try:
            data = parse_article(url)
            if not data or not data.get("judul") or not data.get("konten"):
                continue
            row = {
                "url": url,
                "category": category,
                "subcategory": subcat,
                "tanggal_publish": data["tanggal_publish"],
                "judul": data["judul"],
                "tags": data["tags"],
                "konten": data["konten"]
            }
            append_row(output_csv_path, row)
            done.add(url)
            saved += 1
        except KeyboardInterrupt:
            print("\n⛔ Dihentikan manual, progres tersimpan.")
            break
        except Exception as e:
            print(f"\nERROR [{i}] {url} -> {e.__class__.__name__}: {e}")
        finally:
            time.sleep(random.uniform(*REQUEST_DELAY))

    print(f"Selesai. Artikel baru tersimpan: {saved}.")
    print("CSV:", output_csv_path)

# ==========================
# Jalankan
# ==========================
run_scrape_money(OUTPUT_CSV, max_pages_per_sub=MAX_PAGES_PER_SUB)
# Out:
# URL sudah ada di CSV: 0
# Sub-kategori terdeteksi:
#  - Ekbis: https://money.kompas.com/ekbis
#  - Keuangan: https://money.kompas.com/keuangan
#  - Syariah: https://money.kompas.com/syariah
#  - Industri: https://money.kompas.com/industri
#  - Energi: https://money.kompas.com/energi
#  - Belanja: https://money.kompas.com/belanja
#  - Cuan: https://money.kompas.com/cuan
#  - Karier: https://money.kompas.com/karier
#  - Indeks: https://indeks.kompas.com/?site=money
#  - Kilas: #
#  - Kilas Badan: https://kilasbadan.kompas.com/
#  - Kilas Fintech: https://kilasfintech.kompas.com/
#  - Kilas Transportasi: https://kilastransportasi.kompas.com/
#  - Kilas Investasi: https://kilasinvestasi.kompas.com/
#  - Kilas Perbankan: https://kilasperbankan.kompas.com/
#
# Crawl sub-kategori: Ekbis
#   [page=1] +40 URL (total 40)
#   [page=2] +0 URL (total 40)
#   [page=3] +0 URL (total 40)
#   [page=4] +0 URL (total 40)
#
# Crawl sub-kategori: Keuangan
#   [page=1] +43 URL (total 43)
#   [page=2] +0 URL (total 43)
#   [page=3] +0 URL (total 43)
#   [page=4] +0 URL (total 43)
#
# Crawl sub-kategori: Syariah
#   [page=1] +44 URL (total 44)
#   [page=2] +0 URL (total 44)
#   [page=3] +0 URL (total 44)
#   [page=4] +0 URL (total 44)
#
# Crawl sub-kategori: Industri
#   [page=1] +44 URL (total 44)
#   [page=2] +0 URL (total 44)
#   [page=3] +0 URL (total 44)
#   [page=4] +0 URL (total 44)
#
# Crawl sub-kategori: Energi
#   [page=1] +44 URL (total 44)
#   [page=2] +0 URL (total 44)
#   [page=3] +0 URL (total 44)
#   [page=4] +0 URL (total 44)
#
# Crawl sub-kategori: Belanja
#   [page=1] +44 URL (total 44)
#   [page=2] +0 URL (total 44)
#   [page=3] +0 URL (total 44)
#   [page=4] +0 URL (total 44)
#
# Crawl sub-kategori: Cuan
#   [page=1] +41 URL (total 41)
#   [page=2] +0 URL (total 41)
#   [page=3] +0 URL (total 41)
#   [page=4] +0 URL (total 41)
#
# Crawl sub-kategori: Karier
#   [page=1] +44 URL (total 44)
#   [page=2] +0 URL (total 44)
#   [page=3] +0 URL (total 44)
#   [page=4] +0 URL (total 44)
#
# Crawl sub-kategori: Indeks
#   [page=1] +21 URL (total 21)
#   [page=2] +20 URL (total 41)
#   [page=3] +20 URL (total 61)
#   [page=4] +19 URL (total 80)
#   [page=5] +0 URL (total 80)
#   [page=6] +0 URL (total 80)
#   [page=7] +0 URL (total 80)
#
# Crawl sub-kategori: Kilas
#   [page=1] +0 URL (total 0)
#   [page=2] +0 URL (total 0)
#   [page=3] +0 URL (total 0)
#
# Crawl sub-kategori: Kilas Badan
#   [page=1] +20 URL (total 20)
#   [page=2] +0 URL (total 20)
#   [page=3] +0 URL (total 20)
#   [page=4] +0 URL (total 20)
#
# Crawl sub-kategori: Kilas Fintech
#   [page=1] +19 URL (total 19)
#   [page=2] +0 URL (total 19)
#   [page=3] +0 URL (total 19)
#   [page=4] +0 URL (total 19)
#
# Crawl sub-kategori: Kilas Transportasi
#   [page=1] +18 URL (total 18)
#   [page=2] +0 URL (total 18)
#   [page=3] +0 URL (total 18)
#   [page=4] +0 URL (total 18)
#
# Crawl sub-kategori: Kilas Investasi
#   [page=1] +14 URL (total 14)
#   [page=2] +0 URL (total 14)
#   [page=3] +0 URL (total 14)
#   [page=4] +0 URL (total 14)
#
# Crawl sub-kategori: Kilas Perbankan
#   [page=1] +21 URL (total 21)
#   [page=2] +0 URL (total 21)
#   [page=3] +0 URL (total 21)
#   [page=4] +0 URL (total 21)
#
# Total kandidat (URL unik per sub): 516
# Scraping: 100%|██████████| 516/516 [12:13<00:00,  1.42s/url]
# Selesai. Artikel baru tersimpan: 354.
# CSV: /content/drive/MyDrive/KompasMoney/kompas_money_scraped.csv

# %% [markdown]
# # Scraping Tekno

# %%
from google.colab import drive
import os

# Tentukan folder dan file output di Drive
DRIVE_FOLDER = "/content/drive/MyDrive/KompasTekno"
os.makedirs(DRIVE_FOLDER, exist_ok=True)

OUTPUT_CSV = os.path.join(DRIVE_FOLDER, "kompas_tekno_scraped.csv")
print("Folder Drive:", DRIVE_FOLDER)
print("File output :", OUTPUT_CSV)
# Out:
# Folder Drive: /content/drive/MyDrive/KompasTekno
# File output : /content/drive/MyDrive/KompasTekno/kompas_tekno_scraped.csv

# %%
# Scraper Kompas Money (menu-aware + subcategory + tags + resumeable)

import os, re, time, csv, random, json
from urllib.parse import urljoin, urlparse
import requests
from bs4 import BeautifulSoup
from collections import OrderedDict
from tqdm import tqdm

# ==========================
# Konfigurasi umum
# ==========================
BASE = "https://tekno.kompas.com/"
REQUEST_DELAY = (0.8, 1.6)
TIMEOUT = 20
MAX_PAGES_PER_SUB = None  # None = lanjut sampai 3 halaman kosong berturut-turut
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
}

# ==========================
# Session HTTP dengan retry
# ==========================
from requests.adapters import HTTPAdapter, Retry

def make_session():
    s = requests.Session()
    retries = Retry(
        total=5, connect=5, read=5,
        backoff_factor=1.2,
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=frozenset(["GET"])
    )
    s.headers.update(HEADERS)
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.mount("http://", HTTPAdapter(max_retries=retries))
    return s

SESSION = make_session()

# ==========================
# CSV helper
# ==========================
FIELDNAMES = ["url", "category", "subcategory", "tanggal_publish", "judul", "tags", "konten"]

def ensure_csv(path):
    if not os.path.exists(path):
        with open(path, "w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=FIELDNAMES)
            writer.writeheader()

def load_done_urls(path):
    done = set()
    if os.path.exists(path):
        with open(path, "r", encoding="utf-8") as f:
            r = csv.DictReader(f)
            for row in r:
                u = (row.get("url") or "").strip()
                if u:
                    done.add(u)
    return done

def append_row(path, row: dict):
    clean = {k: (row.get(k) or "") for k in FIELDNAMES}
    with open(path, "a", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=FIELDNAMES)
        w.writerow(clean)

# ==========================
# Utilities
# ==========================
def normalize_ws(text):
    return re.sub(r"\s+", " ", (text or "").strip())

def looks_like_baca_juga(text):
    return "baca juga" in (text or "").lower()

def safe_get(url):
    r = SESSION.get(url, timeout=TIMEOUT)
    r.raise_for_status()
    return r

def absolutize(base_url, href):
    if href.startswith("//"):
        return "https:" + href
    if href.startswith("/"):
        parsed = urlparse(base_url)
        return f"{parsed.scheme}://{parsed.netloc}{href}"
    return href

# ==========================
# Dapatkan daftar sub-kategori dari menu
# ==========================
def discover_menu_links():
    found = OrderedDict()
    try:
        r = safe_get(BASE)
        soup = BeautifulSoup(r.text, "lxml")
        for a in soup.select(".kanalHeader[data-kanal='tekno'] .kanalMenu a[href]"):
            name = normalize_ws(a.get_text())
            href = absolutize(BASE, a.get("href","").strip())
            if not href or not name:
                continue
            found[href] = name
    except Exception:
        pass

    # fallback kalau parsing gagal
    SEED = OrderedDict([
        ("https://tekno.kompas.com/apps-os", "Apps & OS"),
        ("https://tekno.kompas.com/gadget", "Gadget"),
        ("https://tekno.kompas.com/internet", "Internet"),
        ("https://tekno.kompas.com/hardware", "Hardware"),
        ("https://tekno.kompas.com/business", "Business"),
        ("https://tekno.kompas.com/game", "Game"),
    ])
    for href, name in SEED.items():
        found.setdefault(href, name)

    return list(found.items())

# ==========================
# Ambil daftar URL artikel per subcategory
# ==========================
def is_article_url(href: str):
    if not href or "kompas.com" not in href:
        return False
    if "/read/" not in href:
        return False
    if any(b in href for b in ["/komentar/", "/copy/"]):
        return False
    return True

def collect_urls_from_list(listing_url):
    try:
        res = safe_get(listing_url)
    except Exception:
        return set()
    soup = BeautifulSoup(res.text, "lxml")
    urls = set()
    for a in soup.select("a[href*='/read/']"):
        href = a.get("href")
        if not href:
            continue
        full = absolutize(listing_url, href)
        if is_article_url(full):
            urls.add(full)
    return urls

def page_url(base, page):
    if page <= 1:
        return base
    parsed = urlparse(base)
    joiner = "&" if parsed.query else "?"
    return f"{base}{joiner}page={page}"

def crawl_subcategory_urls(sub_url, max_pages=None):
    discovered = OrderedDict()
    consecutive_empty = 0
    page = 1
    while True:
        if max_pages is not None and page > max_pages:
            break
        url = page_url(sub_url, page)
        urls = collect_urls_from_list(url)
        before = len(discovered)
        for u in sorted(urls):
            discovered.setdefault(u, None)
        gained = len(discovered) - before
        print(f"  [page={page}] +{gained} URL (total {len(discovered)})")
        time.sleep(random.uniform(*REQUEST_DELAY))
        consecutive_empty = consecutive_empty + 1 if gained == 0 else 0
        if consecutive_empty >= 3:
            break
        page += 1
    return list(discovered.keys())

# ==========================
# Parsing artikel
# ==========================
def extract_publish_date(soup):
    meta = soup.find("meta", attrs={"name": "content_PublishedDate"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    meta2 = soup.select_one('meta[property="article:published_time"]')
    if meta2 and meta2.get("content"):
        return meta2["content"].strip()
    return ""

def extract_tags(soup):
    meta = soup.find("meta", attrs={"name": "content_tags"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    tag_links = soup.select("a.tag__article__link, .tag__item a")
    if tag_links:
        tags = [normalize_ws(a.get_text()) for a in tag_links if a.get_text().strip()]
        return ", ".join(tags)
    return ""

def parse_article(url):
    res = safe_get(url)
    soup = BeautifulSoup(res.text, "lxml")
    title_el = soup.select_one("h1.read__title") or soup.select_one("h1.article__title") or soup.select_one("h1")
    judul = normalize_ws(title_el.get_text()) if title_el else normalize_ws(soup.title.get_text() if soup.title else "")
    tanggal_publish = extract_publish_date(soup)
    tags = extract_tags(soup)
    wrapper = soup.select_one(".read__content") or soup.select_one(".article__content") or soup
    ps = wrapper.find_all("p")
    paragraphs = []
    for p in ps:
        txt = p.get_text(" ").strip()
        if not txt:
            continue
        if looks_like_baca_juga(txt):
            continue
        if "KOMPAS.com" in txt and "Download" in txt:
            continue
        paragraphs.append(normalize_ws(txt))
    konten = " ".join(paragraphs)
    return {"judul": judul, "tanggal_publish": tanggal_publish, "tags": tags, "konten": konten}

# ==========================
# Pipeline utama
# ==========================
def run_scrape_tekno(output_csv_path, max_pages_per_sub=None):
    ensure_csv(output_csv_path)
    done = load_done_urls(output_csv_path)
    print(f"URL sudah ada di CSV: {len(done)}")

    submenus = discover_menu_links()
    print("Sub-kategori terdeteksi:")
    for href, name in submenus:
        print(f" - {name}: {href}")

    all_urls = OrderedDict()
    for href, name in submenus:
        print(f"\nCrawl sub-kategori: {name}")
        urls = crawl_subcategory_urls(href, max_pages=max_pages_per_sub)
        for u in urls:
            all_urls.setdefault((u, name), None)

    print(f"\nTotal kandidat (URL unik per sub): {len(all_urls)}")

    category = "Tekno"
    saved = 0
    for i, ((url, subcat), _) in enumerate(tqdm(all_urls.items(), desc="Scraping", unit="url"), 1):
        if url in done:
            continue
        try:
            data = parse_article(url)
            if not data or not data.get("judul") or not data.get("konten"):
                continue
            row = {
                "url": url,
                "category": category,
                "subcategory": subcat,
                "tanggal_publish": data["tanggal_publish"],
                "judul": data["judul"],
                "tags": data["tags"],
                "konten": data["konten"]
            }
            append_row(output_csv_path, row)
            done.add(url)
            saved += 1
        except KeyboardInterrupt:
            print("\n⛔ Dihentikan manual, progres tersimpan.")
            break
        except Exception as e:
            print(f"\nERROR [{i}] {url} -> {e.__class__.__name__}: {e}")
        finally:
            time.sleep(random.uniform(*REQUEST_DELAY))

    print(f"Selesai. Artikel baru tersimpan: {saved}.")
    print("CSV:", output_csv_path)

# ==========================
# Jalankan
# ==========================
run_scrape_tekno(OUTPUT_CSV, max_pages_per_sub=MAX_PAGES_PER_SUB)
# Out:
# URL sudah ada di CSV: 0
# Sub-kategori terdeteksi:
#  - Apps & OS: https://tekno.kompas.com/apps-os
#  - Gadget: https://tekno.kompas.com/gadget
#  - Internet: https://tekno.kompas.com/internet
#  - Hardware: https://tekno.kompas.com/hardware
#  - Business: https://tekno.kompas.com/business
#  - Game: https://tekno.kompas.com/game
#  - Galeri: https://tekno.kompas.com/galeri
#  - Indeks: https://indeks.kompas.com/?site=tekno
#  - Tech Innovation: https://pubads.g.doubleclick.net/gampad/clk?id=6163907479&iu=/31800665/KOMPAS.COM/tekno
#  - Kilas Internet: https://kilasinternet.kompas.com/
#
# Crawl sub-kategori: Apps & OS
#   [page=1] +34 URL (total 34)
#   [page=2] +0 URL (total 34)
#   [page=3] +0 URL (total 34)
#   [page=4] +0 URL (total 34)
#
# Crawl sub-kategori: Gadget
#   [page=1] +29 URL (total 29)
#   [page=2] +0 URL (total 29)
#   [page=3] +0 URL (total 29)
#   [page=4] +0 URL (total 29)
#
# Crawl sub-kategori: Internet
#   [page=1] +32 URL (total 32)
#   [page=2] +0 URL (total 32)
#   [page=3] +0 URL (total 32)
#   [page=4] +0 URL (total 32)
#
# Crawl sub-kategori: Hardware
#   [page=1] +33 URL (total 33)
#   [page=2] +0 URL (total 33)
#   [page=3] +0 URL (total 33)
#   [page=4] +0 URL (total 33)
#
# Crawl sub-kategori: Business
#   [page=1] +34 URL (total 34)
#   [page=2] +0 URL (total 34)
#   [page=3] +0 URL (total 34)
#   [page=4] +0 URL (total 34)
#
# Crawl sub-kategori: Game
#   [page=1] +40 URL (total 40)
#   [page=2] +16 URL (total 56)
#   [page=3] +17 URL (total 73)
#   [page=4] +17 URL (total 90)
#   [page=5] +17 URL (total 107)
#   [page=6] +17 URL (total 124)
#   [page=7] +17 URL (total 141)
#   [page=8] +17 URL (total 158)
#   [page=9] +17 URL (total 175)
#   [page=10] +17 URL (total 192)
#   [page=11] +17 URL (total 209)
#   [page=12] +17 URL (total 226)
#   [page=13] +17 URL (total 243)
#   [page=14] +17 URL (total 260)
#   [page=15] +17 URL (total 277)
#   [page=16] +0 URL (total 277)
#   [page=17] +0 URL (total 277)
#   [page=18] +0 URL (total 277)
#
# Crawl sub-kategori: Galeri
#   [page=1] +14 URL (total 14)
#   [page=2] +0 URL (total 14)
#   [page=3] +0 URL (total 14)
#   [page=4] +0 URL (total 14)
#
# Crawl sub-kategori: Indeks
#   [page=1] +21 URL (total 21)
#   [page=2] +3 URL (total 24)
#   [page=3] +0 URL (total 24)
#   [page=4] +0 URL (total 24)
#   [page=5] +0 URL (total 24)
#
# Crawl sub-kategori: Tech Innovation
#   [page=1] +11 URL (total 11)
#   [page=2] +0 URL (total 11)
#   [page=3] +0 URL (total 11)
#   [page=4] +0 URL (total 11)
#
# Crawl sub-kategori: Kilas Internet
#   [page=1] +16 URL (total 16)
#   [page=2] +0 URL (total 16)
#   [page=3] +0 URL (total 16)
#   [page=4] +0 URL (total 16)
#
# Total kandidat (URL unik per sub): 504
# Scraping: 100%|██████████| 504/504 [12:29<00:00,  1.49s/url]
# Selesai. Artikel baru tersimpan: 401.
# CSV: /content/drive/MyDrive/KompasTekno/kompas_tekno_scraped.csv

# %% [markdown]
# # Scraping Otomotif

# %%
from google.colab import drive
import os

# Tentukan folder dan file output di Drive
DRIVE_FOLDER = "/content/drive/MyDrive/KompasOtomotif"
os.makedirs(DRIVE_FOLDER, exist_ok=True)

OUTPUT_CSV = os.path.join(DRIVE_FOLDER, "kompas_otomotif_scraped.csv")
print("Folder Drive:", DRIVE_FOLDER)
print("File output :", OUTPUT_CSV)
# Out:
# Folder Drive: /content/drive/MyDrive/KompasOtomotif
# File output : /content/drive/MyDrive/KompasOtomotif/kompas_otomotif_scraped.csv

# %%
# Scraper Kompas Money (menu-aware + subcategory + tags + resumeable)

import os, re, time, csv, random, json
from urllib.parse import urljoin, urlparse
import requests
from bs4 import BeautifulSoup
from collections import OrderedDict
from tqdm import tqdm

# ==========================
# Konfigurasi umum
# ==========================
BASE = "https://otomotif.kompas.com/"
REQUEST_DELAY = (0.8, 1.6)
TIMEOUT = 20
MAX_PAGES_PER_SUB = None  # None = lanjut sampai 3 halaman kosong berturut-turut
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
}

# ==========================
# Session HTTP dengan retry
# ==========================
from requests.adapters import HTTPAdapter, Retry

def make_session():
    s = requests.Session()
    retries = Retry(
        total=5, connect=5, read=5,
        backoff_factor=1.2,
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=frozenset(["GET"])
    )
    s.headers.update(HEADERS)
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.mount("http://", HTTPAdapter(max_retries=retries))
    return s

SESSION = make_session()

# ==========================
# CSV helper
# ==========================
FIELDNAMES = ["url", "category", "subcategory", "tanggal_publish", "judul", "tags", "konten"]

def ensure_csv(path):
    if not os.path.exists(path):
        with open(path, "w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=FIELDNAMES)
            writer.writeheader()

def load_done_urls(path):
    done = set()
    if os.path.exists(path):
        with open(path, "r", encoding="utf-8") as f:
            r = csv.DictReader(f)
            for row in r:
                u = (row.get("url") or "").strip()
                if u:
                    done.add(u)
    return done

def append_row(path, row: dict):
    clean = {k: (row.get(k) or "") for k in FIELDNAMES}
    with open(path, "a", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=FIELDNAMES)
        w.writerow(clean)

# ==========================
# Utilities
# ==========================
def normalize_ws(text):
    return re.sub(r"\s+", " ", (text or "").strip())

def looks_like_baca_juga(text):
    return "baca juga" in (text or "").lower()

def safe_get(url):
    r = SESSION.get(url, timeout=TIMEOUT)
    r.raise_for_status()
    return r

def absolutize(base_url, href):
    if href.startswith("//"):
        return "https:" + href
    if href.startswith("/"):
        parsed = urlparse(base_url)
        return f"{parsed.scheme}://{parsed.netloc}{href}"
    return href

# ==========================
# Dapatkan daftar sub-kategori dari menu
# ==========================
def discover_menu_links():
    found = OrderedDict()
    try:
        r = safe_get(BASE)
        soup = BeautifulSoup(r.text, "lxml")
        for a in soup.select(".kanalHeader[data-kanal='otomotif'] .kanalMenu a[href]"):
            name = normalize_ws(a.get_text())
            href = absolutize(BASE, a.get("href","").strip())
            if not href or not name:
                continue
            found[href] = name
    except Exception:
        pass

    # fallback kalau parsing gagal
    SEED = OrderedDict([
        ("https://otomotif.kompas.com/news", "News"),
        ("https://otomotif.kompas.com/mobil", "Mobil"),
        ("https://otomotif.kompas.com/motor", "Motor"),
        ("https://otomotif.kompas.com/sport", "Sport"),
        ("https://otomotif.kompas.com/feature", "Feature"),
        ("https://otomotif.kompas.com/niaga", "Niaga"),
        ("https://otomotif.kompas.com/komunitas", "Komunitas"),
        ("https://otomotif.kompas.com/otopedia", "Otopedia"),
    ])
    for href, name in SEED.items():
        found.setdefault(href, name)

    return list(found.items())

# ==========================
# Ambil daftar URL artikel per subcategory
# ==========================
def is_article_url(href: str):
    if not href or "kompas.com" not in href:
        return False
    if "/read/" not in href:
        return False
    if any(b in href for b in ["/komentar/", "/copy/"]):
        return False
    return True

def collect_urls_from_list(listing_url):
    try:
        res = safe_get(listing_url)
    except Exception:
        return set()
    soup = BeautifulSoup(res.text, "lxml")
    urls = set()
    for a in soup.select("a[href*='/read/']"):
        href = a.get("href")
        if not href:
            continue
        full = absolutize(listing_url, href)
        if is_article_url(full):
            urls.add(full)
    return urls

def page_url(base, page):
    if page <= 1:
        return base
    parsed = urlparse(base)
    joiner = "&" if parsed.query else "?"
    return f"{base}{joiner}page={page}"

def crawl_subcategory_urls(sub_url, max_pages=None):
    discovered = OrderedDict()
    consecutive_empty = 0
    page = 1
    while True:
        if max_pages is not None and page > max_pages:
            break
        url = page_url(sub_url, page)
        urls = collect_urls_from_list(url)
        before = len(discovered)
        for u in sorted(urls):
            discovered.setdefault(u, None)
        gained = len(discovered) - before
        print(f"  [page={page}] +{gained} URL (total {len(discovered)})")
        time.sleep(random.uniform(*REQUEST_DELAY))
        consecutive_empty = consecutive_empty + 1 if gained == 0 else 0
        if consecutive_empty >= 3:
            break
        page += 1
    return list(discovered.keys())

# ==========================
# Parsing artikel
# ==========================
def extract_publish_date(soup):
    meta = soup.find("meta", attrs={"name": "content_PublishedDate"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    meta2 = soup.select_one('meta[property="article:published_time"]')
    if meta2 and meta2.get("content"):
        return meta2["content"].strip()
    return ""

def extract_tags(soup):
    meta = soup.find("meta", attrs={"name": "content_tags"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    tag_links = soup.select("a.tag__article__link, .tag__item a")
    if tag_links:
        tags = [normalize_ws(a.get_text()) for a in tag_links if a.get_text().strip()]
        return ", ".join(tags)
    return ""

def parse_article(url):
    res = safe_get(url)
    soup = BeautifulSoup(res.text, "lxml")
    title_el = soup.select_one("h1.read__title") or soup.select_one("h1.article__title") or soup.select_one("h1")
    judul = normalize_ws(title_el.get_text()) if title_el else normalize_ws(soup.title.get_text() if soup.title else "")
    tanggal_publish = extract_publish_date(soup)
    tags = extract_tags(soup)
    wrapper = soup.select_one(".read__content") or soup.select_one(".article__content") or soup
    ps = wrapper.find_all("p")
    paragraphs = []
    for p in ps:
        txt = p.get_text(" ").strip()
        if not txt:
            continue
        if looks_like_baca_juga(txt):
            continue
        if "KOMPAS.com" in txt and "Download" in txt:
            continue
        paragraphs.append(normalize_ws(txt))
    konten = " ".join(paragraphs)
    return {"judul": judul, "tanggal_publish": tanggal_publish, "tags": tags, "konten": konten}

# ==========================
# Pipeline utama
# ==========================
def run_scrape_otomotif(output_csv_path, max_pages_per_sub=None):
    ensure_csv(output_csv_path)
    done = load_done_urls(output_csv_path)
    print(f"URL sudah ada di CSV: {len(done)}")

    submenus = discover_menu_links()
    print("Sub-kategori terdeteksi:")
    for href, name in submenus:
        print(f" - {name}: {href}")

    all_urls = OrderedDict()
    for href, name in submenus:
        print(f"\nCrawl sub-kategori: {name}")
        urls = crawl_subcategory_urls(href, max_pages=max_pages_per_sub)
        for u in urls:
            all_urls.setdefault((u, name), None)

    print(f"\nTotal kandidat (URL unik per sub): {len(all_urls)}")

    category = "Otomotif"
    saved = 0
    for i, ((url, subcat), _) in enumerate(tqdm(all_urls.items(), desc="Scraping", unit="url"), 1):
        if url in done:
            continue
        try:
            data = parse_article(url)
            if not data or not data.get("judul") or not data.get("konten"):
                continue
            row = {
                "url": url,
                "category": category,
                "subcategory": subcat,
                "tanggal_publish": data["tanggal_publish"],
                "judul": data["judul"],
                "tags": data["tags"],
                "konten": data["konten"]
            }
            append_row(output_csv_path, row)
            done.add(url)
            saved += 1
        except KeyboardInterrupt:
            print("\n⛔ Dihentikan manual, progres tersimpan.")
            break
        except Exception as e:
            print(f"\nERROR [{i}] {url} -> {e.__class__.__name__}: {e}")
        finally:
            time.sleep(random.uniform(*REQUEST_DELAY))

    print(f"Selesai. Artikel baru tersimpan: {saved}.")
    print("CSV:", output_csv_path)

# ==========================
# Jalankan
# ==========================
run_scrape_otomotif(OUTPUT_CSV, max_pages_per_sub=MAX_PAGES_PER_SUB)
# Out:
# URL sudah ada di CSV: 0
# Sub-kategori terdeteksi:
#  - News: https://otomotif.kompas.com/news
#  - Mobil: https://otomotif.kompas.com/mobil
#  - Produk: https://otomotif.kompas.com/mobil/produk
#  - Modifikasi: https://otomotif.kompas.com/mobil/modifikasi
#  - Aksesoris: https://otomotif.kompas.com/mobil/aksesoris
#  - Tes: https://otomotif.kompas.com/mobil/tes
#  - Teknologi: https://otomotif.kompas.com/mobil/teknologi
#  - Motor: https://otomotif.kompas.com/motor
#  - Produk: https://otomotif.kompas.com/motor/produk
#  - Modifikasi: https://otomotif.kompas.com/motor/modifikasi
#  - Aksesoris: https://otomotif.kompas.com/motor/aksesoris
#  - Tes: https://otomotif.kompas.com/motor/tes
#  - Teknologi: https://otomotif.kompas.com/motor/teknologi
#  - Sport: https://otomotif.kompas.com/sport
#  - Feature: https://otomotif.kompas.com/feature
#  - Niaga: https://otomotif.kompas.com/niaga
#  - Komunitas: https://otomotif.kompas.com/komunitas
#  - Otopedia: https://otomotif.kompas.com/otopedia
#  - Galeri: https://otomotif.kompas.com/galeri
#  - Indeks: https://indeks.kompas.com/?site=otomotif
#  - Pameran: https://lipsus.kompas.com/pameranotomotifnasional2024
#
# Crawl sub-kategori: News
#   [page=1] +29 URL (total 29)
#   [page=2] +0 URL (total 29)
#   [page=3] +0 URL (total 29)
#   [page=4] +0 URL (total 29)
#
# Crawl sub-kategori: Mobil
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Produk
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Modifikasi
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Aksesoris
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Tes
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Teknologi
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Motor
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Produk
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Modifikasi
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Aksesoris
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Tes
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Teknologi
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Sport
#   [page=1] +28 URL (total 28)
#   [page=2] +0 URL (total 28)
#   [page=3] +0 URL (total 28)
#   [page=4] +0 URL (total 28)
#
# Crawl sub-kategori: Feature
#   [page=1] +30 URL (total 30)
#   [page=2] +0 URL (total 30)
#   [page=3] +0 URL (total 30)
#   [page=4] +0 URL (total 30)
#
# Crawl sub-kategori: Niaga
#   [page=1] +30 URL (total 30)
#   [page=2] +0 URL (total 30)
#   [page=3] +0 URL (total 30)
#   [page=4] +0 URL (total 30)
#
# Crawl sub-kategori: Komunitas
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Otopedia
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Galeri
#   [page=1] +11 URL (total 11)
#   [page=2] +0 URL (total 11)
#   [page=3] +0 URL (total 11)
#   [page=4] +0 URL (total 11)
#
# Crawl sub-kategori: Indeks
#   [page=1] +21 URL (total 21)
#   [page=2] +20 URL (total 41)
#   [page=3] +20 URL (total 61)
#   [page=4] +6 URL (total 67)
#   [page=5] +0 URL (total 67)
#   [page=6] +0 URL (total 67)
#   [page=7] +0 URL (total 67)
#
# Crawl sub-kategori: Pameran
#   [page=1] +8 URL (total 8)
#   [page=2] +0 URL (total 8)
#   [page=3] +0 URL (total 8)
#   [page=4] +0 URL (total 8)
#
# Total kandidat (URL unik per sub): 582
# Scraping: 100%|██████████| 582/582 [12:03<00:00,  1.24s/url]
# Selesai. Artikel baru tersimpan: 362.
# CSV: /content/drive/MyDrive/KompasOtomotif/kompas_otomotif_scraped.csv

# %% [markdown]
# # Scraping Nusaraya

# %%
from google.colab import drive
import os

# Tentukan folder dan file output di Drive
DRIVE_FOLDER = "/content/drive/MyDrive/KompasNusaraya"
os.makedirs(DRIVE_FOLDER, exist_ok=True)

OUTPUT_CSV = os.path.join(DRIVE_FOLDER, "kompas_nusaraya_scraped.csv")
print("Folder Drive:", DRIVE_FOLDER)
print("File output :", OUTPUT_CSV)
# Out:
# Folder Drive: /content/drive/MyDrive/KompasNusaraya
# File output : /content/drive/MyDrive/KompasNusaraya/kompas_nusaraya_scraped.csv

# %%
# Scraper Kompas Money (menu-aware + subcategory + tags + resumeable)

import os, re, time, csv, random, json
from urllib.parse import urljoin, urlparse
import requests
from bs4 import BeautifulSoup
from collections import OrderedDict
from tqdm import tqdm

# ==========================
# Konfigurasi umum
# ==========================
BASE = "https://www.kompas.com/nusaraya"
REQUEST_DELAY = (0.8, 1.6)
TIMEOUT = 20
MAX_PAGES_PER_SUB = None  # None = lanjut sampai 3 halaman kosong berturut-turut
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
}

# ==========================
# Session HTTP dengan retry
# ==========================
from requests.adapters import HTTPAdapter, Retry

def make_session():
    s = requests.Session()
    retries = Retry(
        total=5, connect=5, read=5,
        backoff_factor=1.2,
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=frozenset(["GET"])
    )
    s.headers.update(HEADERS)
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.mount("http://", HTTPAdapter(max_retries=retries))
    return s

SESSION = make_session()

# ==========================
# CSV helper
# ==========================
FIELDNAMES = ["url", "category", "subcategory", "tanggal_publish", "judul", "tags", "konten"]

def ensure_csv(path):
    if not os.path.exists(path):
        with open(path, "w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=FIELDNAMES)
            writer.writeheader()

def load_done_urls(path):
    done = set()
    if os.path.exists(path):
        with open(path, "r", encoding="utf-8") as f:
            r = csv.DictReader(f)
            for row in r:
                u = (row.get("url") or "").strip()
                if u:
                    done.add(u)
    return done

def append_row(path, row: dict):
    clean = {k: (row.get(k) or "") for k in FIELDNAMES}
    with open(path, "a", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=FIELDNAMES)
        w.writerow(clean)

# ==========================
# Utilities
# ==========================
def normalize_ws(text):
    return re.sub(r"\s+", " ", (text or "").strip())

def looks_like_baca_juga(text):
    return "baca juga" in (text or "").lower()

def safe_get(url):
    r = SESSION.get(url, timeout=TIMEOUT)
    r.raise_for_status()
    return r

def absolutize(base_url, href):
    if href.startswith("//"):
        return "https:" + href
    if href.startswith("/"):
        parsed = urlparse(base_url)
        return f"{parsed.scheme}://{parsed.netloc}{href}"
    return href

# ==========================
# Dapatkan daftar sub-kategori dari menu
# ==========================
def discover_menu_links():
    found = OrderedDict()
    try:
        r = safe_get(BASE)
        soup = BeautifulSoup(r.text, "lxml")
        for a in soup.select(".kanalHeader[data-kanal='nusaraya'] .kanalMenu a[href]"):
            name = normalize_ws(a.get_text())
            href = absolutize(BASE, a.get("href","").strip())
            if not href or not name:
                continue
            found[href] = name
    except Exception:
        pass

    # fallback kalau parsing gagal
    SEED = OrderedDict([
        ("https://www.kompas.com/sumatera-utara", "Sumatera Utara"),
        ("https://www.kompas.com/sumatera-selatan", "Sumatera Selatan"),
        ("https://www.kompas.com/sumatera-barat", "Sumatera Barat"),
        ("https://www.kompas.com/riau", "Riau"),
        ("https://www.kompas.com/lampung", "Lampung"),
        ("https://www.kompas.com/banten", "Banten"),
        ("https://www.kompas.com/yogyakarta", "Yogyakarta"),
        ("https://www.kompas.com/jawa-barat", "Jawa Barat"),
        ("https://www.kompas.com/jawa-tengah", "Jawa Tengah"),
        ("https://www.kompas.com/jawa-timur", "Jawa Timur"),
        ("https://www.kompas.com/kalimantan-barat", "Kalimantan Barat"),
        ("https://www.kompas.com/kalimantan-timur", "Kalimantan Timur"),
        ("https://www.kompas.com/sulawesi-selatan", "Sulawesi Selatan"),
        ("https://www.kompas.com/bali", "Bali"),
    ])
    for href, name in SEED.items():
        found.setdefault(href, name)

    return list(found.items())

# ==========================
# Ambil daftar URL artikel per subcategory
# ==========================
def is_article_url(href: str):
    if not href or "kompas.com" not in href:
        return False
    if "/read/" not in href:
        return False
    if any(b in href for b in ["/komentar/", "/copy/"]):
        return False
    return True

def collect_urls_from_list(listing_url):
    try:
        res = safe_get(listing_url)
    except Exception:
        return set()
    soup = BeautifulSoup(res.text, "lxml")
    urls = set()
    for a in soup.select("a[href*='/read/']"):
        href = a.get("href")
        if not href:
            continue
        full = absolutize(listing_url, href)
        if is_article_url(full):
            urls.add(full)
    return urls

def page_url(base, page):
    if page <= 1:
        return base
    parsed = urlparse(base)
    joiner = "&" if parsed.query else "?"
    return f"{base}{joiner}page={page}"

def crawl_subcategory_urls(sub_url, max_pages=None):
    discovered = OrderedDict()
    consecutive_empty = 0
    page = 1
    while True:
        if max_pages is not None and page > max_pages:
            break
        url = page_url(sub_url, page)
        urls = collect_urls_from_list(url)
        before = len(discovered)
        for u in sorted(urls):
            discovered.setdefault(u, None)
        gained = len(discovered) - before
        print(f"  [page={page}] +{gained} URL (total {len(discovered)})")
        time.sleep(random.uniform(*REQUEST_DELAY))
        consecutive_empty = consecutive_empty + 1 if gained == 0 else 0
        if consecutive_empty >= 3:
            break
        page += 1
    return list(discovered.keys())

# ==========================
# Parsing artikel
# ==========================
def extract_publish_date(soup):
    meta = soup.find("meta", attrs={"name": "content_PublishedDate"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    meta2 = soup.select_one('meta[property="article:published_time"]')
    if meta2 and meta2.get("content"):
        return meta2["content"].strip()
    return ""

def extract_tags(soup):
    meta = soup.find("meta", attrs={"name": "content_tags"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    tag_links = soup.select("a.tag__article__link, .tag__item a")
    if tag_links:
        tags = [normalize_ws(a.get_text()) for a in tag_links if a.get_text().strip()]
        return ", ".join(tags)
    return ""

def parse_article(url):
    res = safe_get(url)
    soup = BeautifulSoup(res.text, "lxml")
    title_el = soup.select_one("h1.read__title") or soup.select_one("h1.article__title") or soup.select_one("h1")
    judul = normalize_ws(title_el.get_text()) if title_el else normalize_ws(soup.title.get_text() if soup.title else "")
    tanggal_publish = extract_publish_date(soup)
    tags = extract_tags(soup)
    wrapper = soup.select_one(".read__content") or soup.select_one(".article__content") or soup
    ps = wrapper.find_all("p")
    paragraphs = []
    for p in ps:
        txt = p.get_text(" ").strip()
        if not txt:
            continue
        if looks_like_baca_juga(txt):
            continue
        if "KOMPAS.com" in txt and "Download" in txt:
            continue
        paragraphs.append(normalize_ws(txt))
    konten = " ".join(paragraphs)
    return {"judul": judul, "tanggal_publish": tanggal_publish, "tags": tags, "konten": konten}

# ==========================
# Pipeline utama
# ==========================
def run_scrape_nusaraya(output_csv_path, max_pages_per_sub=None):
    ensure_csv(output_csv_path)
    done = load_done_urls(output_csv_path)
    print(f"URL sudah ada di CSV: {len(done)}")

    submenus = discover_menu_links()
    print("Sub-kategori terdeteksi:")
    for href, name in submenus:
        print(f" - {name}: {href}")

    all_urls = OrderedDict()
    for href, name in submenus:
        print(f"\nCrawl sub-kategori: {name}")
        urls = crawl_subcategory_urls(href, max_pages=max_pages_per_sub)
        for u in urls:
            all_urls.setdefault((u, name), None)

    print(f"\nTotal kandidat (URL unik per sub): {len(all_urls)}")

    category = "Nusaraya"
    saved = 0
    for i, ((url, subcat), _) in enumerate(tqdm(all_urls.items(), desc="Scraping", unit="url"), 1):
        if url in done:
            continue
        try:
            data = parse_article(url)
            if not data or not data.get("judul") or not data.get("konten"):
                continue
            row = {
                "url": url,
                "category": category,
                "subcategory": subcat,
                "tanggal_publish": data["tanggal_publish"],
                "judul": data["judul"],
                "tags": data["tags"],
                "konten": data["konten"]
            }
            append_row(output_csv_path, row)
            done.add(url)
            saved += 1
        except KeyboardInterrupt:
            print("\n⛔ Dihentikan manual, progres tersimpan.")
            break
        except Exception as e:
            print(f"\nERROR [{i}] {url} -> {e.__class__.__name__}: {e}")
        finally:
            time.sleep(random.uniform(*REQUEST_DELAY))

    print(f"Selesai. Artikel baru tersimpan: {saved}.")
    print("CSV:", output_csv_path)

# ==========================
# Jalankan
# ==========================
run_scrape_nusaraya(OUTPUT_CSV, max_pages_per_sub=MAX_PAGES_PER_SUB)
# Out:
# URL sudah ada di CSV: 0
# Sub-kategori terdeteksi:
#  - Kalimantan: javascript:void(0)
#  - Sumatera Utara: https://www.kompas.com/sumatera-utara
#  - Sumatera Selatan: https://www.kompas.com/sumatera-selatan
#  - Sumatera Barat: https://www.kompas.com/sumatera-barat
#  - Riau: https://www.kompas.com/riau
#  - Lampung: https://www.kompas.com/lampung
#  - Banten: https://www.kompas.com/banten
#  - Yogyakarta: https://yogyakarta.kompas.com
#  - Jawa Barat: https://www.kompas.com/jawa-barat
#  - Jawa Tengah: https://www.kompas.com/jawa-tengah
#  - Jawa Timur: https://www.kompas.com/jawa-timur
#  - Kalimantan Barat: https://www.kompas.com/kalimantan-barat
#  - Kalimantan Timur: https://www.kompas.com/kalimantan-timur
#  - Sulawesi Selatan: https://www.kompas.com/sulawesi-selatan
#  - Bali: https://denpasar.kompas.com
#  - Indeks: https://indeks.kompas.com/?site=nusaraya
#  - Yogyakarta: https://www.kompas.com/yogyakarta
#  - Bali: https://www.kompas.com/bali
#
# Crawl sub-kategori: Kalimantan
#   [page=1] +0 URL (total 0)
#   [page=2] +0 URL (total 0)
#   [page=3] +0 URL (total 0)
#
# Crawl sub-kategori: Sumatera Utara
#   [page=1] +40 URL (total 40)
#   [page=2] +25 URL (total 65)
#   [page=3] +25 URL (total 90)
#   [page=4] +25 URL (total 115)
#   [page=5] +25 URL (total 140)
#   [page=6] +25 URL (total 165)
#   [page=7] +25 URL (total 190)
#   [page=8] +25 URL (total 215)
#   [page=9] +25 URL (total 240)
#   [page=10] +25 URL (total 265)
#   [page=11] +25 URL (total 290)
#   [page=12] +25 URL (total 315)
#   [page=13] +25 URL (total 340)
#   [page=14] +25 URL (total 365)
#   [page=15] +25 URL (total 390)
#   [page=16] +25 URL (total 415)
#   [page=17] +25 URL (total 440)
#   [page=18] +25 URL (total 465)
#   [page=19] +25 URL (total 490)
#   [page=20] +25 URL (total 515)
#   [page=21] +25 URL (total 540)
#   [page=22] +25 URL (total 565)
#   [page=23] +25 URL (total 590)
#   [page=24] +25 URL (total 615)
#   [page=25] +25 URL (total 640)
#   [page=26] +25 URL (total 665)
#   [page=27] +25 URL (total 690)
#   [page=28] +25 URL (total 715)
#   [page=29] +25 URL (total 740)
#   [page=30] +25 URL (total 765)
#   [page=31] +25 URL (total 790)
#   [page=32] +25 URL (total 815)
#   [page=33] +25 URL (total 840)
#   [page=34] +25 URL (total 865)
#   [page=35] +25 URL (total 890)
#   [page=36] +25 URL (total 915)
#   [page=37] +25 URL (total 940)
#   [page=38] +25 URL (total 965)
#   [page=39] +25 URL (total 990)
#   [page=40] +25 URL (total 1015)
#   [page=41] +25 URL (total 1040)
#   [page=42] +25 URL (total 1065)
#   [page=43] +25 URL (total 1090)
#   [page=44] +25 URL (total 1115)
#   [page=45] +25 URL (total 1140)
#   [page=46] +25 URL (total 1165)
#   [page=47] +25 URL (total 1190)
#   [page=48] +25 URL (total 1215)
#   [page=49] +25 URL (total 1240)
#   [page=50] +25 URL (total 1265)
#   [page=51] +25 URL (total 1290)
#   [page=52] +25 URL (total 1315)
#   [page=53] +25 URL (total 1340)
#   [page=54] +25 URL (total 1365)
#   [page=55] +25 URL (total 1390)
#   [page=56] +25 URL (total 1415)
#   [page=57] +25 URL (total 1440)
#   [page=58] +25 URL (total 1465)
#   [page=59] +25 URL (total 1490)
#   [page=60] +25 URL (total 1515)
#   [page=61] +25 URL (total 1540)
#   [page=62] +25 URL (total 1565)
#   [page=63] +25 URL (total 1590)
#   [page=64] +25 URL (total 1615)
#   [page=65] +25 URL (total 1640)
#   [page=66] +25 URL (total 1665)
#   [page=67] +25 URL (total 1690)
#   [page=68] +25 URL (total 1715)
#   [page=69] +25 URL (total 1740)
#   [page=70] +25 URL (total 1765)
#   [page=71] +25 URL (total 1790)
#   [page=72] +25 URL (total 1815)
#   [page=73] +25 URL (total 1840)
#   [page=74] +25 URL (total 1865)
#   [page=75] +25 URL (total 1890)
#   [page=76] +25 URL (total 1915)
#   [page=77] +25 URL (total 1940)
#   [page=78] +25 URL (total 1965)
#   [page=79] +25 URL (total 1990)
#   [page=80] +25 URL (total 2015)
#   [page=81] +25 URL (total 2040)
#   [page=82] +25 URL (total 2065)
#   [page=83] +25 URL (total 2090)
#   [page=84] +25 URL (total 2115)
#   [page=85] +25 URL (total 2140)
#   [page=86] +25 URL (total 2165)
#   [page=87] +25 URL (total 2190)
#   [page=88] +25 URL (total 2215)
#   [page=89] +25 URL (total 2240)
#   [page=90] +25 URL (total 2265)
#   [page=91] +25 URL (total 2290)
#   [page=92] +25 URL (total 2315)
#   [page=93] +25 URL (total 2340)
#   [page=94] +25 URL (total 2365)
#   [page=95] +25 URL (total 2390)
#   [page=96] +25 URL (total 2415)
#   [page=97] +25 URL (total 2440)
#   [page=98] +25 URL (total 2465)
#   [page=99] +25 URL (total 2490)
#   [page=100] +25 URL (total 2515)
#   [page=101] +25 URL (total 2540)
#   [page=102] +25 URL (total 2565)
#   [page=103] +25 URL (total 2590)
#   [page=104] +25 URL (total 2615)
#   [page=105] +25 URL (total 2640)
#   [page=106] +25 URL (total 2665)
#   [page=107] +25 URL (total 2690)
#   [page=108] +25 URL (total 2715)
#   [page=109] +25 URL (total 2740)
#   [page=110] +25 URL (total 2765)
#   [page=111] +25 URL (total 2790)
#   [page=112] +25 URL (total 2815)
#   [page=113] +25 URL (total 2840)
#   [page=114] +25 URL (total 2865)
#   [page=115] +25 URL (total 2890)
#   [page=116] +25 URL (total 2915)
#   [page=117] +25 URL (total 2940)
#   [page=118] +25 URL (total 2965)
#   [page=119] +25 URL (total 2990)
#   [page=120] +25 URL (total 3015)
#   [page=121] +25 URL (total 3040)
#   [page=122] +25 URL (total 3065)
#   [page=123] +25 URL (total 3090)
#   [page=124] +25 URL (total 3115)
#   [page=125] +25 URL (total 3140)
#   [page=126] +25 URL (total 3165)
#   [page=127] +25 URL (total 3190)
#   [page=128] +25 URL (total 3215)
#   [page=129] +25 URL (total 3240)
#   [page=130] +25 URL (total 3265)
#   [page=131] +25 URL (total 3290)
#   [page=132] +25 URL (total 3315)
#   [page=133] +25 URL (total 3340)
#   [page=134] +25 URL (total 3365)
#   [page=135] +25 URL (total 3390)
#   [page=136] +25 URL (total 3415)
#   [page=137] +25 URL (total 3440)
#   [page=138] +25 URL (total 3465)
#   [page=139] +25 URL (total 3490)
#   [page=140] +25 URL (total 3515)
#   [page=141] +25 URL (total 3540)
#   [page=142] +25 URL (total 3565)
#   [page=143] +25 URL (total 3590)
#   [page=144] +25 URL (total 3615)
#   [page=145] +25 URL (total 3640)
#   [page=146] +25 URL (total 3665)
#   [page=147] +25 URL (total 3690)
#   [page=148] +25 URL (total 3715)
#   [page=149] +25 URL (total 3740)
#   [page=150] +25 URL (total 3765)
#   [page=151] +25 URL (total 3790)
#   [page=152] +25 URL (total 3815)
#   [page=153] +25 URL (total 3840)
#   [page=154] +25 URL (total 3865)
#   [page=155] +25 URL (total 3890)
#   [page=156] +25 URL (total 3915)
#   [page=157] +25 URL (total 3940)
#   [page=158] +25 URL (total 3965)
#   [page=159] +25 URL (total 3990)
#   [page=160] +25 URL (total 4015)
#   [page=161] +25 URL (total 4040)
#   [page=162] +25 URL (total 4065)
#   [page=163] +25 URL (total 4090)
#   [page=164] +25 URL (total 4115)
#   [page=165] +25 URL (total 4140)
#   [page=166] +25 URL (total 4165)
#   [page=167] +25 URL (total 4190)
#   [page=168] +25 URL (total 4215)
#   [page=169] +25 URL (total 4240)
#   [page=170] +25 URL (total 4265)
#   [page=171] +25 URL (total 4290)
#   [page=172] +25 URL (total 4315)
#   [page=173] +25 URL (total 4340)
#   [page=174] +25 URL (total 4365)
#   [page=175] +25 URL (total 4390)
#   [page=176] +25 URL (total 4415)
#   [page=177] +25 URL (total 4440)
#   [page=178] +25 URL (total 4465)
#   [page=179] +25 URL (total 4490)
#   [page=180] +25 URL (total 4515)
#   [page=181] +25 URL (total 4540)
#   [page=182] +25 URL (total 4565)
#   [page=183] +25 URL (total 4590)
#   [page=184] +25 URL (total 4615)
#   [page=185] +25 URL (total 4640)
#   [page=186] +25 URL (total 4665)
#   [page=187] +25 URL (total 4690)
#   [page=188] +25 URL (total 4715)
#   [page=189] +25 URL (total 4740)
#   [page=190] +25 URL (total 4765)
#   [page=191] +25 URL (total 4790)
#   [page=192] +25 URL (total 4815)
#   [page=193] +25 URL (total 4840)
#   [page=194] +25 URL (total 4865)
#   [page=195] +25 URL (total 4890)
#   [page=196] +25 URL (total 4915)
#   [page=197] +25 URL (total 4940)
#   [page=198] +25 URL (total 4965)
#   [page=199] +25 URL (total 4990)
#   [page=200] +25 URL (total 5015)
#   [page=201] +25 URL (total 5040)
#   [page=202] +25 URL (total 5065)
#   [page=203] +25 URL (total 5090)
#   [page=204] +25 URL (total 5115)
#   [page=205] +25 URL (total 5140)
#   [page=206] +25 URL (total 5165)
#   [page=207] +25 URL (total 5190)
#   [page=208] +25 URL (total 5215)
#   [page=209] +25 URL (total 5240)
#   [page=210] +25 URL (total 5265)
#   [page=211] +25 URL (total 5290)
#   [page=212] +25 URL (total 5315)
#   [page=213] +25 URL (total 5340)
#   [page=214] +25 URL (total 5365)
#   [page=215] +25 URL (total 5390)
#   [page=216] +25 URL (total 5415)
#   [page=217] +25 URL (total 5440)
#   [page=218] +25 URL (total 5465)
#   [page=219] +25 URL (total 5490)
#   [page=220] +25 URL (total 5515)
#   [page=221] +25 URL (total 5540)
#   [page=222] +25 URL (total 5565)
#   [page=223] +25 URL (total 5590)
#   [page=224] +25 URL (total 5615)
#   [page=225] +25 URL (total 5640)
#   [page=226] +25 URL (total 5665)
#   [page=227] +25 URL (total 5690)
#   [page=228] +25 URL (total 5715)
#   [page=229] +25 URL (total 5740)
#   [page=230] +25 URL (total 5765)
#   [page=231] +25 URL (total 5790)
#   [page=232] +25 URL (total 5815)
#   [page=233] +25 URL (total 5840)
#   [page=234] +25 URL (total 5865)
#   [page=235] +25 URL (total 5890)
#   [page=236] +25 URL (total 5915)
#   [page=237] +25 URL (total 5940)
#   [page=238] +25 URL (total 5965)
#   [page=239] +25 URL (total 5990)
#   [page=240] +25 URL (total 6015)
#   [page=241] +25 URL (total 6040)
#   [page=242] +25 URL (total 6065)
#   [page=243] +25 URL (total 6090)
#   [page=244] +25 URL (total 6115)
#   [page=245] +25 URL (total 6140)
#   [page=246] +25 URL (total 6165)
#   [page=247] +25 URL (total 6190)
#   [page=248] +25 URL (total 6215)
#   [page=249] +25 URL (total 6240)
#   [page=250] +25 URL (total 6265)
#   [page=251] +25 URL (total 6290)
#   [page=252] +25 URL (total 6315)
#   [page=253] +25 URL (total 6340)
#   [page=254] +25 URL (total 6365)
#   [page=255] +25 URL (total 6390)
#   [page=256] +25 URL (total 6415)
#   [page=257] +25 URL (total 6440)
#   [page=258] +25 URL (total 6465)
#   [page=259] +25 URL (total 6490)
#   [page=260] +25 URL (total 6515)
#   [page=261] +25 URL (total 6540)
#   [page=262] +25 URL (total 6565)
#   [page=263] +25 URL (total 6590)
#   [page=264] +25 URL (total 6615)
#   [page=265] +25 URL (total 6640)
#   [page=266] +25 URL (total 6665)
#   [page=267] +25 URL (total 6690)
#   [page=268] +25 URL (total 6715)
#   [page=269] +25 URL (total 6740)
#   [page=270] +25 URL (total 6765)
#   [page=271] +25 URL (total 6790)
#   [page=272] +25 URL (total 6815)
#   [page=273] +25 URL (total 6840)
#   [page=274] +25 URL (total 6865)
#   [page=275] +25 URL (total 6890)
#   [page=276] +25 URL (total 6915)
#   [page=277] +25 URL (total 6940)
#   [page=278] +25 URL (total 6965)
#   [page=279] +25 URL (total 6990)
#   [page=280] +25 URL (total 7015)
#   [page=281] +25 URL (total 7040)
#   [page=282] +25 URL (total 7065)
#   [page=283] +25 URL (total 7090)
#   [page=284] +25 URL (total 7115)
#   [page=285] +25 URL (total 7140)
#   [page=286] +25 URL (total 7165)
#   [page=287] +25 URL (total 7190)
#   [page=288] +25 URL (total 7215)
#   [page=289] +25 URL (total 7240)
#   [page=290] +25 URL (total 7265)
#   [page=291] +25 URL (total 7290)
#   [page=292] +25 URL (total 7315)
#   [page=293] +25 URL (total 7340)
#   [page=294] +25 URL (total 7365)
#   [page=295] +25 URL (total 7390)
#   [page=296] +25 URL (total 7415)
#   [page=297] +25 URL (total 7440)
#   [page=298] +25 URL (total 7465)
#   [page=299] +25 URL (total 7490)
#   [page=300] +25 URL (total 7515)
#   [page=301] +25 URL (total 7540)
#   [page=302] +25 URL (total 7565)
#   [page=303] +25 URL (total 7590)
#   [page=304] +25 URL (total 7615)
#   [page=305] +25 URL (total 7640)
#   [page=306] +25 URL (total 7665)
#   [page=307] +25 URL (total 7690)
#   [page=308] +25 URL (total 7715)
#   [page=309] +25 URL (total 7740)
#   [page=310] +25 URL (total 7765)
#   [page=311] +25 URL (total 7790)
#   [page=312] +25 URL (total 7815)
#   [page=313] +25 URL (total 7840)
#   [page=314] +25 URL (total 7865)
#   [page=315] +25 URL (total 7890)
#   [page=316] +25 URL (total 7915)
#   [page=317] +25 URL (total 7940)
#   [page=318] +25 URL (total 7965)
#   [page=319] +25 URL (total 7990)
#   [page=320] +25 URL (total 8015)
#   [page=321] +25 URL (total 8040)
#   [page=322] +25 URL (total 8065)
#   [page=323] +25 URL (total 8090)
#   [page=324] +25 URL (total 8115)
#   [page=325] +25 URL (total 8140)
#   [page=326] +25 URL (total 8165)
#   [page=327] +25 URL (total 8190)
#   [page=328] +25 URL (total 8215)
#   [page=329] +25 URL (total 8240)
#   [page=330] +25 URL (total 8265)
#   [page=331] +25 URL (total 8290)
#   [page=332] +25 URL (total 8315)
#   [page=333] +25 URL (total 8340)
#   [page=334] +25 URL (total 8365)
#   [page=335] +25 URL (total 8390)
#   [page=336] +25 URL (total 8415)
#   [page=337] +25 URL (total 8440)
#   [page=338] +25 URL (total 8465)
#   [page=339] +25 URL (total 8490)
#   [page=340] +25 URL (total 8515)
#   [page=341] +25 URL (total 8540)
#   [page=342] +25 URL (total 8565)
#   [page=343] +25 URL (total 8590)
#   [page=344] +25 URL (total 8615)
#   [page=345] +25 URL (total 8640)
#   [page=346] +25 URL (total 8665)
#   [page=347] +25 URL (total 8690)
#   [page=348] +25 URL (total 8715)
#   [page=349] +25 URL (total 8740)
#   [page=350] +25 URL (total 8765)
#   [page=351] +25 URL (total 8790)
#   [page=352] +25 URL (total 8815)
#   [page=353] +25 URL (total 8840)
#   [page=354] +25 URL (total 8865)
#   [page=355] +25 URL (total 8890)
#   [page=356] +25 URL (total 8915)
#   [page=357] +25 URL (total 8940)
#   [page=358] +25 URL (total 8965)
#   [page=359] +25 URL (total 8990)
#   [page=360] +25 URL (total 9015)
#   [page=361] +25 URL (total 9040)
#   [page=362] +25 URL (total 9065)
#   [page=363] +25 URL (total 9090)
#   [page=364] +25 URL (total 9115)
#   [page=365] +25 URL (total 9140)
#   [page=366] +25 URL (total 9165)
#   [page=367] +25 URL (total 9190)
#   [page=368] +25 URL (total 9215)
#   [page=369] +25 URL (total 9240)
#   [page=370] +25 URL (total 9265)
#   [page=371] +25 URL (total 9290)
#   [page=372] +25 URL (total 9315)
#   [page=373] +25 URL (total 9340)
#   [page=374] +25 URL (total 9365)
#   [page=375] +25 URL (total 9390)
#   [page=376] +25 URL (total 9415)
#   [page=377] +25 URL (total 9440)
#   [page=378] +25 URL (total 9465)
#   [page=379] +25 URL (total 9490)
#   [page=380] +25 URL (total 9515)
#   [page=381] +25 URL (total 9540)
#   [page=382] +25 URL (total 9565)
#   [page=383] +25 URL (total 9590)
#   [page=384] +25 URL (total 9615)
#   [page=385] +25 URL (total 9640)
#   [page=386] +25 URL (total 9665)
#   [page=387] +25 URL (total 9690)
#   [page=388] +25 URL (total 9715)
#   [page=389] +25 URL (total 9740)
#   [page=390] +25 URL (total 9765)
#   [page=391] +25 URL (total 9790)
#   [page=392] +25 URL (total 9815)
#   [page=393] +25 URL (total 9840)
#   [page=394] +25 URL (total 9865)
#   [page=395] +25 URL (total 9890)
#   [page=396] +25 URL (total 9915)
#   [page=397] +25 URL (total 9940)
#   [page=398] +25 URL (total 9965)
#   [page=399] +25 URL (total 9990)
#   [page=400] +25 URL (total 10015)
#   [page=401] +0 URL (total 10015)
#   [page=402] +0 URL (total 10015)
#   [page=403] +0 URL (total 10015)
#
# Crawl sub-kategori: Sumatera Selatan
#   [page=1] +40 URL (total 40)
#   [page=2] +25 URL (total 65)
#   [page=3] +25 URL (total 90)
#   [page=4] +25 URL (total 115)
#   [page=5] +25 URL (total 140)
#   [page=6] +24 URL (total 164)
#   [page=7] +25 URL (total 189)
#   [page=8] +25 URL (total 214)
#   [page=9] +25 URL (total 239)
#   [page=10] +25 URL (total 264)
#   [page=11] +25 URL (total 289)
#   [page=12] +25 URL (total 314)
#   [page=13] +25 URL (total 339)
#   [page=14] +25 URL (total 364)
#   [page=15] +25 URL (total 389)
#   [page=16] +25 URL (total 414)
#   [page=17] +25 URL (total 439)
#   [page=18] +25 URL (total 464)
#   [page=19] +25 URL (total 489)
#   [page=20] +25 URL (total 514)
#   [page=21] +25 URL (total 539)
#   [page=22] +25 URL (total 564)
#   [page=23] +25 URL (total 589)
#   [page=24] +25 URL (total 614)
#   [page=25] +25 URL (total 639)
#   [page=26] +25 URL (total 664)
#   [page=27] +25 URL (total 689)
#   [page=28] +25 URL (total 714)
#   [page=29] +25 URL (total 739)
#   [page=30] +25 URL (total 764)
#   [page=31] +25 URL (total 789)
#   [page=32] +25 URL (total 814)
#   [page=33] +25 URL (total 839)
#   [page=34] +25 URL (total 864)
#   [page=35] +25 URL (total 889)
#   [page=36] +0 URL (total 889)
#   [page=37] +0 URL (total 889)
#   [page=38] +0 URL (total 889)
#
# Crawl sub-kategori: Sumatera Barat
#   [page=1] +40 URL (total 40)
#   [page=2] +25 URL (total 65)
#   [page=3] +25 URL (total 90)
#   [page=4] +25 URL (total 115)
#   [page=5] +25 URL (total 140)
#   [page=6] +25 URL (total 165)
#   [page=7] +25 URL (total 190)
#   [page=8] +25 URL (total 215)
#   [page=9] +25 URL (total 240)
#   [page=10] +25 URL (total 265)
#   [page=11] +25 URL (total 290)
#   [page=12] +25 URL (total 315)
#   [page=13] +25 URL (total 340)
#   [page=14] +25 URL (total 365)
#   [page=15] +25 URL (total 390)
#   [page=16] +25 URL (total 415)
#   [page=17] +25 URL (total 440)
#   [page=18] +25 URL (total 465)
#   [page=19] +25 URL (total 490)
#   [page=20] +25 URL (total 515)
#   [page=21] +25 URL (total 540)
#   [page=22] +25 URL (total 565)
#   [page=23] +25 URL (total 590)
#   [page=24] +25 URL (total 615)
#   [page=25] +21 URL (total 636)
#   [page=26] +0 URL (total 636)
#   [page=27] +0 URL (total 636)
#   [page=28] +0 URL (total 636)
#
# Crawl sub-kategori: Riau
#   [page=1] +40 URL (total 40)
#   [page=2] +25 URL (total 65)
#   [page=3] +25 URL (total 90)
#   [page=4] +25 URL (total 115)
#   [page=5] +25 URL (total 140)
#   [page=6] +25 URL (total 165)
#   [page=7] +25 URL (total 190)
#   [page=8] +25 URL (total 215)
#   [page=9] +25 URL (total 240)
#   [page=10] +25 URL (total 265)
#   [page=11] +25 URL (total 290)
#   [page=12] +25 URL (total 315)
#   [page=13] +25 URL (total 340)
#   [page=14] +25 URL (total 365)
#   [page=15] +25 URL (total 390)
#   [page=16] +25 URL (total 415)
#   [page=17] +25 URL (total 440)
#   [page=18] +25 URL (total 465)
#   [page=19] +25 URL (total 490)
#   [page=20] +25 URL (total 515)
#   [page=21] +25 URL (total 540)
#   [page=22] +25 URL (total 565)
#   [page=23] +25 URL (total 590)
#   [page=24] +25 URL (total 615)
#   [page=25] +25 URL (total 640)
#   [page=26] +25 URL (total 665)
#   [page=27] +25 URL (total 690)
#   [page=28] +25 URL (total 715)
#   [page=29] +25 URL (total 740)
#   [page=30] +25 URL (total 765)
#   [page=31] +25 URL (total 790)
#   [page=32] +25 URL (total 815)
#   [page=33] +25 URL (total 840)
#   [page=34] +25 URL (total 865)
#   [page=35] +25 URL (total 890)
#   [page=36] +25 URL (total 915)
#   [page=37] +25 URL (total 940)
#   [page=38] +25 URL (total 965)
#   [page=39] +25 URL (total 990)
#   [page=40] +25 URL (total 1015)
#   [page=41] +25 URL (total 1040)
#   [page=42] +25 URL (total 1065)
#   [page=43] +25 URL (total 1090)
#   [page=44] +25 URL (total 1115)
#   [page=45] +25 URL (total 1140)
#   [page=46] +25 URL (total 1165)
#   [page=47] +25 URL (total 1190)
#   [page=48] +25 URL (total 1215)
#   [page=49] +25 URL (total 1240)
#   [page=50] +25 URL (total 1265)
#   [page=51] +25 URL (total 1290)
#   [page=52] +25 URL (total 1315)
#   [page=53] +25 URL (total 1340)
#   [page=54] +25 URL (total 1365)
#   [page=55] +25 URL (total 1390)
#   [page=56] +25 URL (total 1415)
#   [page=57] +25 URL (total 1440)
#   [page=58] +25 URL (total 1465)
#   [page=59] +25 URL (total 1490)
#   [page=60] +25 URL (total 1515)
#   [page=61] +25 URL (total 1540)
#   [page=62] +25 URL (total 1565)
#   [page=63] +25 URL (total 1590)
#   [page=64] +25 URL (total 1615)
#   [page=65] +25 URL (total 1640)
#   [page=66] +25 URL (total 1665)
#   [page=67] +25 URL (total 1690)
#   [page=68] +25 URL (total 1715)
#   [page=69] +25 URL (total 1740)
#   [page=70] +25 URL (total 1765)
#   [page=71] +25 URL (total 1790)
#   [page=72] +25 URL (total 1815)
#   [page=73] +25 URL (total 1840)
#   [page=74] +25 URL (total 1865)
#   [page=75] +25 URL (total 1890)
#   [page=76] +25 URL (total 1915)
#   [page=77] +25 URL (total 1940)
#   [page=78] +25 URL (total 1965)
#   [page=79] +25 URL (total 1990)
#   [page=80] +25 URL (total 2015)
#   [page=81] +25 URL (total 2040)
#   [page=82] +25 URL (total 2065)
#   [page=83] +25 URL (total 2090)
#   [page=84] +25 URL (total 2115)
#   [page=85] +25 URL (total 2140)
#   [page=86] +25 URL (total 2165)
#   [page=87] +25 URL (total 2190)
#   [page=88] +25 URL (total 2215)
#   [page=89] +25 URL (total 2240)
#   [page=90] +25 URL (total 2265)
#   [page=91] +25 URL (total 2290)
#   [page=92] +25 URL (total 2315)
#   [page=93] +25 URL (total 2340)
#   [page=94] +25 URL (total 2365)
#   [page=95] +25 URL (total 2390)
#   [page=96] +25 URL (total 2415)
#   [page=97] +25 URL (total 2440)
#   [page=98] +25 URL (total 2465)
#   [page=99] +25 URL (total 2490)
#   [page=100] +25 URL (total 2515)
#   [page=101] +25 URL (total 2540)
#   [page=102] +25 URL (total 2565)
#   [page=103] +25 URL (total 2590)
#   [page=104] +25 URL (total 2615)
#   [page=105] +25 URL (total 2640)
#   [page=106] +25 URL (total 2665)
#   [page=107] +25 URL (total 2690)
#   [page=108] +25 URL (total 2715)
#   [page=109] +25 URL (total 2740)
#   [page=110] +25 URL (total 2765)
#   [page=111] +25 URL (total 2790)
#   [page=112] +25 URL (total 2815)
#   [page=113] +25 URL (total 2840)
#   [page=114] +25 URL (total 2865)
#   [page=115] +25 URL (total 2890)
#   [page=116] +25 URL (total 2915)
#   [page=117] +25 URL (total 2940)
#   [page=118] +25 URL (total 2965)
#   [page=119] +25 URL (total 2990)
#   [page=120] +25 URL (total 3015)
#   [page=121] +25 URL (total 3040)
#   [page=122] +25 URL (total 3065)
#   [page=123] +25 URL (total 3090)
#   [page=124] +25 URL (total 3115)
#   [page=125] +25 URL (total 3140)
#   [page=126] +25 URL (total 3165)
#   [page=127] +25 URL (total 3190)
#   [page=128] +25 URL (total 3215)
#   [page=129] +25 URL (total 3240)
#   [page=130] +25 URL (total 3265)
#   [page=131] +25 URL (total 3290)
#   [page=132] +25 URL (total 3315)
#   [page=133] +25 URL (total 3340)
#   [page=134] +25 URL (total 3365)
#   [page=135] +25 URL (total 3390)
#   [page=136] +25 URL (total 3415)
#   [page=137] +25 URL (total 3440)
#   [page=138] +25 URL (total 3465)
#   [page=139] +25 URL (total 3490)
#   [page=140] +25 URL (total 3515)
#   [page=141] +25 URL (total 3540)
#   [page=142] +25 URL (total 3565)
#   [page=143] +25 URL (total 3590)
#   [page=144] +25 URL (total 3615)
#   [page=145] +25 URL (total 3640)
#   [page=146] +25 URL (total 3665)
#   [page=147] +25 URL (total 3690)
#   [page=148] +25 URL (total 3715)
#   [page=149] +25 URL (total 3740)
#   [page=150] +25 URL (total 3765)
#   [page=151] +25 URL (total 3790)
#   [page=152] +25 URL (total 3815)
#   [page=153] +25 URL (total 3840)
#   [page=154] +25 URL (total 3865)
#   [page=155] +25 URL (total 3890)
#   [page=156] +25 URL (total 3915)
#   [page=157] +25 URL (total 3940)
#   [page=158] +25 URL (total 3965)
#   [page=159] +25 URL (total 3990)
#   [page=160] +25 URL (total 4015)
#   [page=161] +25 URL (total 4040)
#   [page=162] +25 URL (total 4065)
#   [page=163] +25 URL (total 4090)
#   [page=164] +25 URL (total 4115)
#   [page=165] +25 URL (total 4140)
#   [page=166] +25 URL (total 4165)
#   [page=167] +25 URL (total 4190)
#   [page=168] +25 URL (total 4215)
#   [page=169] +25 URL (total 4240)
#   [page=170] +25 URL (total 4265)
#   [page=171] +25 URL (total 4290)
#   [page=172] +25 URL (total 4315)
#   [page=173] +25 URL (total 4340)
#   [page=174] +25 URL (total 4365)
#   [page=175] +25 URL (total 4390)
#   [page=176] +25 URL (total 4415)
#   [page=177] +25 URL (total 4440)
#   [page=178] +25 URL (total 4465)
#   [page=179] +25 URL (total 4490)
#   [page=180] +14 URL (total 4504)
#   [page=181] +0 URL (total 4504)
#   [page=182] +0 URL (total 4504)
#   [page=183] +0 URL (total 4504)
#
# Crawl sub-kategori: Lampung
#   [page=1] +40 URL (total 40)
#   [page=2] +25 URL (total 65)
#   [page=3] +25 URL (total 90)
#   [page=4] +25 URL (total 115)
#   [page=5] +25 URL (total 140)
#   [page=6] +25 URL (total 165)
#   [page=7] +25 URL (total 190)
#   [page=8] +25 URL (total 215)
#   [page=9] +25 URL (total 240)
#   [page=10] +25 URL (total 265)
#   [page=11] +25 URL (total 290)
#   [page=12] +25 URL (total 315)
#   [page=13] +25 URL (total 340)
#   [page=14] +25 URL (total 365)
#   [page=15] +25 URL (total 390)
#   [page=16] +25 URL (total 415)
#   [page=17] +25 URL (total 440)
#   [page=18] +25 URL (total 465)
#   [page=19] +25 URL (total 490)
#   [page=20] +25 URL (total 515)
#   [page=21] +25 URL (total 540)
#   [page=22] +25 URL (total 565)
#   [page=23] +25 URL (total 590)
#   [page=24] +25 URL (total 615)
#   [page=25] +25 URL (total 640)
#   [page=26] +25 URL (total 665)
#   [page=27] +25 URL (total 690)
#   [page=28] +25 URL (total 715)
#   [page=29] +25 URL (total 740)
#   [page=30] +25 URL (total 765)
#   [page=31] +25 URL (total 790)
#   [page=32] +25 URL (total 815)
#   [page=33] +25 URL (total 840)
#   [page=34] +25 URL (total 865)
#   [page=35] +25 URL (total 890)
#   [page=36] +25 URL (total 915)
#   [page=37] +25 URL (total 940)
#   [page=38] +25 URL (total 965)
#   [page=39] +25 URL (total 990)
#   [page=40] +25 URL (total 1015)
#   [page=41] +25 URL (total 1040)
#   [page=42] +25 URL (total 1065)
#   [page=43] +25 URL (total 1090)
#   [page=44] +25 URL (total 1115)
#   [page=45] +25 URL (total 1140)
#   [page=46] +25 URL (total 1165)
#   [page=47] +25 URL (total 1190)
#   [page=48] +25 URL (total 1215)
#   [page=49] +25 URL (total 1240)
#   [page=50] +25 URL (total 1265)
#   [page=51] +25 URL (total 1290)
#   [page=52] +25 URL (total 1315)
#   [page=53] +25 URL (total 1340)
#   [page=54] +25 URL (total 1365)
#   [page=55] +25 URL (total 1390)
#   [page=56] +25 URL (total 1415)
#   [page=57] +25 URL (total 1440)
#   [page=58] +25 URL (total 1465)
#   [page=59] +25 URL (total 1490)
#   [page=60] +25 URL (total 1515)
#   [page=61] +25 URL (total 1540)
#   [page=62] +25 URL (total 1565)
#   [page=63] +25 URL (total 1590)
#   [page=64] +25 URL (total 1615)
#   [page=65] +25 URL (total 1640)
#   [page=66] +25 URL (total 1665)
#   [page=67] +25 URL (total 1690)
#   [page=68] +25 URL (total 1715)
#   [page=69] +25 URL (total 1740)
#   [page=70] +25 URL (total 1765)
#   [page=71] +25 URL (total 1790)
#   [page=72] +25 URL (total 1815)
#   [page=73] +25 URL (total 1840)
#   [page=74] +25 URL (total 1865)
#   [page=75] +25 URL (total 1890)
#   [page=76] +25 URL (total 1915)
#   [page=77] +25 URL (total 1940)
#   [page=78] +25 URL (total 1965)
#   [page=79] +25 URL (total 1990)
#   [page=80] +25 URL (total 2015)
#   [page=81] +25 URL (total 2040)
#   [page=82] +25 URL (total 2065)
#   [page=83] +25 URL (total 2090)
#   [page=84] +25 URL (total 2115)
#   [page=85] +25 URL (total 2140)
#   [page=86] +25 URL (total 2165)
#   [page=87] +25 URL (total 2190)
#   [page=88] +25 URL (total 2215)
#   [page=89] +25 URL (total 2240)
#   [page=90] +25 URL (total 2265)
#   [page=91] +25 URL (total 2290)
#   [page=92] +25 URL (total 2315)
#   [page=93] +25 URL (total 2340)
#   [page=94] +25 URL (total 2365)
#   [page=95] +25 URL (total 2390)
#   [page=96] +25 URL (total 2415)
#   [page=97] +25 URL (total 2440)
#   [page=98] +25 URL (total 2465)
#   [page=99] +25 URL (total 2490)
#   [page=100] +25 URL (total 2515)
#   [page=101] +25 URL (total 2540)
#   [page=102] +25 URL (total 2565)
#   [page=103] +25 URL (total 2590)
#   [page=104] +25 URL (total 2615)
#   [page=105] +25 URL (total 2640)
#   [page=106] +25 URL (total 2665)
#   [page=107] +25 URL (total 2690)
#   [page=108] +25 URL (total 2715)
#   [page=109] +25 URL (total 2740)
#   [page=110] +25 URL (total 2765)
#   [page=111] +25 URL (total 2790)
#   [page=112] +25 URL (total 2815)
#   [page=113] +25 URL (total 2840)
#   [page=114] +25 URL (total 2865)
#   [page=115] +25 URL (total 2890)
#   [page=116] +25 URL (total 2915)
#   [page=117] +25 URL (total 2940)
#   [page=118] +25 URL (total 2965)
#   [page=119] +25 URL (total 2990)
#   [page=120] +25 URL (total 3015)
#   [page=121] +25 URL (total 3040)
#   [page=122] +25 URL (total 3065)
#   [page=123] +25 URL (total 3090)
#   [page=124] +25 URL (total 3115)
#   [page=125] +25 URL (total 3140)
#   [page=126] +25 URL (total 3165)
#   [page=127] +25 URL (total 3190)
#   [page=128] +25 URL (total 3215)
#   [page=129] +25 URL (total 3240)
#   [page=130] +25 URL (total 3265)
#   [page=131] +25 URL (total 3290)
#   [page=132] +25 URL (total 3315)
#   [page=133] +25 URL (total 3340)
#   [page=134] +25 URL (total 3365)
#   [page=135] +25 URL (total 3390)
#   [page=136] +25 URL (total 3415)
#   [page=137] +25 URL (total 3440)
#   [page=138] +25 URL (total 3465)
#   [page=139] +25 URL (total 3490)
#   [page=140] +25 URL (total 3515)
#   [page=141] +25 URL (total 3540)
#   [page=142] +25 URL (total 3565)
#   [page=143] +25 URL (total 3590)
#   [page=144] +25 URL (total 3615)
#   [page=145] +25 URL (total 3640)
#   [page=146] +25 URL (total 3665)
#   [page=147] +25 URL (total 3690)
#   [page=148] +25 URL (total 3715)
#   [page=149] +25 URL (total 3740)
#   [page=150] +25 URL (total 3765)
#   [page=151] +25 URL (total 3790)
#   [page=152] +25 URL (total 3815)
#   [page=153] +25 URL (total 3840)
#   [page=154] +25 URL (total 3865)
#   [page=155] +25 URL (total 3890)
#   [page=156] +25 URL (total 3915)
#   [page=157] +25 URL (total 3940)
#   [page=158] +25 URL (total 3965)
#   [page=159] +25 URL (total 3990)
#   [page=160] +25 URL (total 4015)
#   [page=161] +25 URL (total 4040)
#   [page=162] +25 URL (total 4065)
#   [page=163] +25 URL (total 4090)
#   [page=164] +25 URL (total 4115)
#   [page=165] +25 URL (total 4140)
#   [page=166] +25 URL (total 4165)
#   [page=167] +25 URL (total 4190)
#   [page=168] +25 URL (total 4215)
#   [page=169] +25 URL (total 4240)
#   [page=170] +25 URL (total 4265)
#   [page=171] +25 URL (total 4290)
#   [page=172] +25 URL (total 4315)
#   [page=173] +25 URL (total 4340)
#   [page=174] +25 URL (total 4365)
#   [page=175] +25 URL (total 4390)
#   [page=176] +25 URL (total 4415)
#   [page=177] +25 URL (total 4440)
#   [page=178] +25 URL (total 4465)
#   [page=179] +25 URL (total 4490)
#   [page=180] +25 URL (total 4515)
#   [page=181] +25 URL (total 4540)
#   [page=182] +25 URL (total 4565)
#   [page=183] +25 URL (total 4590)
#   [page=184] +25 URL (total 4615)
#   [page=185] +25 URL (total 4640)
#   [page=186] +25 URL (total 4665)
#   [page=187] +25 URL (total 4690)
#   [page=188] +25 URL (total 4715)
#   [page=189] +25 URL (total 4740)
#   [page=190] +25 URL (total 4765)
#   [page=191] +25 URL (total 4790)
#   [page=192] +25 URL (total 4815)
#   [page=193] +25 URL (total 4840)
#   [page=194] +25 URL (total 4865)
#   [page=195] +25 URL (total 4890)
#   [page=196] +25 URL (total 4915)
#   [page=197] +25 URL (total 4940)
#   [page=198] +25 URL (total 4965)
#   [page=199] +25 URL (total 4990)
#   [page=200] +25 URL (total 5015)
#   [page=201] +25 URL (total 5040)
#   [page=202] +25 URL (total 5065)
#   [page=203] +25 URL (total 5090)
#   [page=204] +25 URL (total 5115)
#   [page=205] +25 URL (total 5140)
#   [page=206] +25 URL (total 5165)
#   [page=207] +25 URL (total 5190)
#   [page=208] +25 URL (total 5215)
#   [page=209] +25 URL (total 5240)
#   [page=210] +10 URL (total 5250)
#   [page=211] +0 URL (total 5250)
#   [page=212] +0 URL (total 5250)
#   [page=213] +0 URL (total 5250)
#
# Crawl sub-kategori: Banten
#   [page=1] +40 URL (total 40)
#   [page=2] +25 URL (total 65)
#   [page=3] +25 URL (total 90)
#   [page=4] +25 URL (total 115)
#   [page=5] +25 URL (total 140)
#   [page=6] +25 URL (total 165)
#   [page=7] +25 URL (total 190)
#   [page=8] +25 URL (total 215)
#   [page=9] +25 URL (total 240)
#   [page=10] +25 URL (total 265)
#   [page=11] +25 URL (total 290)
#   [page=12] +25 URL (total 315)
#   [page=13] +25 URL (total 340)
#   [page=14] +25 URL (total 365)
#   [page=15] +25 URL (total 390)
#   [page=16] +25 URL (total 415)
#   [page=17] +25 URL (total 440)
#   [page=18] +25 URL (total 465)
#   [page=19] +25 URL (total 490)
#   [page=20] +25 URL (total 515)
#   [page=21] +25 URL (total 540)
#   [page=22] +25 URL (total 565)
#   [page=23] +25 URL (total 590)
#   [page=24] +25 URL (total 615)
#   [page=25] +25 URL (total 640)
#   [page=26] +25 URL (total 665)
#   [page=27] +25 URL (total 690)
#   [page=28] +25 URL (total 715)
#   [page=29] +25 URL (total 740)
#   [page=30] +25 URL (total 765)
#   [page=31] +25 URL (total 790)
#   [page=32] +25 URL (total 815)
#   [page=33] +25 URL (total 840)
#   [page=34] +25 URL (total 865)
#   [page=35] +25 URL (total 890)
#   [page=36] +25 URL (total 915)
#   [page=37] +25 URL (total 940)
#   [page=38] +25 URL (total 965)
#   [page=39] +25 URL (total 990)
#   [page=40] +25 URL (total 1015)
#   [page=41] +25 URL (total 1040)
#   [page=42] +25 URL (total 1065)
#   [page=43] +25 URL (total 1090)
#   [page=44] +25 URL (total 1115)
#   [page=45] +25 URL (total 1140)
#   [page=46] +25 URL (total 1165)
#   [page=47] +25 URL (total 1190)
#   [page=48] +25 URL (total 1215)
#   [page=49] +25 URL (total 1240)
#   [page=50] +25 URL (total 1265)
#   [page=51] +25 URL (total 1290)
#   [page=52] +25 URL (total 1315)
#   [page=53] +25 URL (total 1340)
#   [page=54] +25 URL (total 1365)
#   [page=55] +25 URL (total 1390)
#   [page=56] +25 URL (total 1415)
#   [page=57] +25 URL (total 1440)
#   [page=58] +25 URL (total 1465)
#   [page=59] +25 URL (total 1490)
#   [page=60] +25 URL (total 1515)
#   [page=61] +25 URL (total 1540)
#   [page=62] +25 URL (total 1565)
#   [page=63] +25 URL (total 1590)
#   [page=64] +25 URL (total 1615)
#   [page=65] +25 URL (total 1640)
#   [page=66] +25 URL (total 1665)
#   [page=67] +25 URL (total 1690)
#   [page=68] +25 URL (total 1715)
#   [page=69] +25 URL (total 1740)
#   [page=70] +25 URL (total 1765)
#   [page=71] +25 URL (total 1790)
#   [page=72] +25 URL (total 1815)
#   [page=73] +25 URL (total 1840)
#   [page=74] +25 URL (total 1865)
#   [page=75] +25 URL (total 1890)
#   [page=76] +25 URL (total 1915)
#   [page=77] +25 URL (total 1940)
#   [page=78] +25 URL (total 1965)
#   [page=79] +25 URL (total 1990)
#   [page=80] +25 URL (total 2015)
#   [page=81] +25 URL (total 2040)
#   [page=82] +25 URL (total 2065)
#   [page=83] +25 URL (total 2090)
#   [page=84] +25 URL (total 2115)
#   [page=85] +25 URL (total 2140)
#   [page=86] +25 URL (total 2165)
#   [page=87] +25 URL (total 2190)
#   [page=88] +25 URL (total 2215)
#   [page=89] +25 URL (total 2240)
#   [page=90] +25 URL (total 2265)
#   [page=91] +25 URL (total 2290)
#   [page=92] +25 URL (total 2315)
#   [page=93] +25 URL (total 2340)
#   [page=94] +25 URL (total 2365)
#   [page=95] +25 URL (total 2390)
#   [page=96] +25 URL (total 2415)
#   [page=97] +25 URL (total 2440)
#   [page=98] +25 URL (total 2465)
#   [page=99] +25 URL (total 2490)
#   [page=100] +25 URL (total 2515)
#   [page=101] +25 URL (total 2540)
#   [page=102] +25 URL (total 2565)
#   [page=103] +25 URL (total 2590)
#   [page=104] +25 URL (total 2615)
#   [page=105] +25 URL (total 2640)
#   [page=106] +25 URL (total 2665)
#   [page=107] +25 URL (total 2690)
#   [page=108] +25 URL (total 2715)
#   [page=109] +25 URL (total 2740)
#   [page=110] +25 URL (total 2765)
#   [page=111] +25 URL (total 2790)
#   [page=112] +25 URL (total 2815)
#   [page=113] +25 URL (total 2840)
#   [page=114] +25 URL (total 2865)
#   [page=115] +25 URL (total 2890)
#   [page=116] +25 URL (total 2915)
#   [page=117] +25 URL (total 2940)
#   [page=118] +25 URL (total 2965)
#   [page=119] +25 URL (total 2990)
#   [page=120] +25 URL (total 3015)
#   [page=121] +25 URL (total 3040)
#   [page=122] +25 URL (total 3065)
#   [page=123] +25 URL (total 3090)
#   [page=124] +25 URL (total 3115)
#   [page=125] +25 URL (total 3140)
#   [page=126] +25 URL (total 3165)
#   [page=127] +25 URL (total 3190)
#   [page=128] +25 URL (total 3215)
#   [page=129] +25 URL (total 3240)
#   [page=130] +25 URL (total 3265)
#   [page=131] +25 URL (total 3290)
#   [page=132] +25 URL (total 3315)
#   [page=133] +25 URL (total 3340)
#   [page=134] +25 URL (total 3365)
#   [page=135] +25 URL (total 3390)
#   [page=136] +25 URL (total 3415)
#   [page=137] +25 URL (total 3440)
#   [page=138] +25 URL (total 3465)
#   [page=139] +25 URL (total 3490)
#   [page=140] +25 URL (total 3515)
#   [page=141] +25 URL (total 3540)
#   [page=142] +25 URL (total 3565)
#   [page=143] +25 URL (total 3590)
#   [page=144] +25 URL (total 3615)
#   [page=145] +25 URL (total 3640)
#   [page=146] +25 URL (total 3665)
#   [page=147] +25 URL (total 3690)
#   [page=148] +25 URL (total 3715)
#   [page=149] +25 URL (total 3740)
#   [page=150] +25 URL (total 3765)
#   [page=151] +25 URL (total 3790)
#   [page=152] +25 URL (total 3815)
#   [page=153] +25 URL (total 3840)
#   [page=154] +25 URL (total 3865)
#   [page=155] +25 URL (total 3890)
#   [page=156] +25 URL (total 3915)
#   [page=157] +25 URL (total 3940)
#   [page=158] +25 URL (total 3965)
#   [page=159] +25 URL (total 3990)
#   [page=160] +25 URL (total 4015)
#   [page=161] +25 URL (total 4040)
#   [page=162] +25 URL (total 4065)
#   [page=163] +25 URL (total 4090)
#   [page=164] +25 URL (total 4115)
#   [page=165] +25 URL (total 4140)
#   [page=166] +16 URL (total 4156)
#   [page=167] +0 URL (total 4156)
#   [page=168] +0 URL (total 4156)
#   [page=169] +0 URL (total 4156)
#
# Crawl sub-kategori: Yogyakarta
#   [page=1] +30 URL (total 30)
#   [page=2] +19 URL (total 49)
#   [page=3] +19 URL (total 68)
#   [page=4] +19 URL (total 87)
#   [page=5] +19 URL (total 106)
#   [page=6] +19 URL (total 125)
#   [page=7] +19 URL (total 144)
#   [page=8] +19 URL (total 163)
#   [page=9] +19 URL (total 182)
#   [page=10] +19 URL (total 201)
#   [page=11] +0 URL (total 201)
#   [page=12] +0 URL (total 201)
#   [page=13] +0 URL (total 201)
#
# Crawl sub-kategori: Jawa Barat
#   [page=1] +40 URL (total 40)
#   [page=2] +25 URL (total 65)
#   [page=3] +25 URL (total 90)
#   [page=4] +25 URL (total 115)
#   [page=5] +25 URL (total 140)
#   [page=6] +25 URL (total 165)
#   [page=7] +25 URL (total 190)
#   [page=8] +25 URL (total 215)
#   [page=9] +25 URL (total 240)
#   [page=10] +25 URL (total 265)
#   [page=11] +25 URL (total 290)
#   [page=12] +25 URL (total 315)
#   [page=13] +25 URL (total 340)
#   [page=14] +25 URL (total 365)
#   [page=15] +25 URL (total 390)
#   [page=16] +25 URL (total 415)
#   [page=17] +25 URL (total 440)
#   [page=18] +25 URL (total 465)
#   [page=19] +25 URL (total 490)
#   [page=20] +25 URL (total 515)
#   [page=21] +25 URL (total 540)
#   [page=22] +25 URL (total 565)
#   [page=23] +25 URL (total 590)
#   [page=24] +25 URL (total 615)
#   [page=25] +25 URL (total 640)
#   [page=26] +25 URL (total 665)
#   [page=27] +25 URL (total 690)
#   [page=28] +25 URL (total 715)
#   [page=29] +25 URL (total 740)
#   [page=30] +25 URL (total 765)
#   [page=31] +25 URL (total 790)
#   [page=32] +25 URL (total 815)
#   [page=33] +25 URL (total 840)
#   [page=34] +25 URL (total 865)
#   [page=35] +25 URL (total 890)
#   [page=36] +25 URL (total 915)
#   [page=37] +25 URL (total 940)
#   [page=38] +25 URL (total 965)
#   [page=39] +25 URL (total 990)
#   [page=40] +25 URL (total 1015)
#   [page=41] +25 URL (total 1040)
#   [page=42] +25 URL (total 1065)
#   [page=43] +25 URL (total 1090)
#   [page=44] +25 URL (total 1115)
#   [page=45] +25 URL (total 1140)
#   [page=46] +25 URL (total 1165)
#   [page=47] +25 URL (total 1190)
#   [page=48] +25 URL (total 1215)
#   [page=49] +25 URL (total 1240)
#   [page=50] +25 URL (total 1265)
#   [page=51] +25 URL (total 1290)
#   [page=52] +25 URL (total 1315)
#   [page=53] +25 URL (total 1340)
#   [page=54] +25 URL (total 1365)
#   [page=55] +25 URL (total 1390)
#   [page=56] +25 URL (total 1415)
#   [page=57] +25 URL (total 1440)
#   [page=58] +25 URL (total 1465)
#   [page=59] +25 URL (total 1490)
#   [page=60] +25 URL (total 1515)
#   [page=61] +25 URL (total 1540)
#   [page=62] +25 URL (total 1565)
#   [page=63] +25 URL (total 1590)
#   [page=64] +25 URL (total 1615)
#   [page=65] +25 URL (total 1640)
#   [page=66] +25 URL (total 1665)
#   [page=67] +25 URL (total 1690)
#   [page=68] +25 URL (total 1715)
#   [page=69] +25 URL (total 1740)
#   [page=70] +25 URL (total 1765)
#   [page=71] +25 URL (total 1790)
#   [page=72] +25 URL (total 1815)
#   [page=73] +25 URL (total 1840)
#   [page=74] +25 URL (total 1865)
#   [page=75] +25 URL (total 1890)
#   [page=76] +25 URL (total 1915)
#   [page=77] +25 URL (total 1940)
#   [page=78] +25 URL (total 1965)
#   [page=79] +25 URL (total 1990)
#   [page=80] +25 URL (total 2015)
#   [page=81] +25 URL (total 2040)
#   [page=82] +25 URL (total 2065)
#   [page=83] +25 URL (total 2090)
#   [page=84] +25 URL (total 2115)
#   [page=85] +25 URL (total 2140)
#   [page=86] +25 URL (total 2165)
#   [page=87] +25 URL (total 2190)
#   [page=88] +25 URL (total 2215)
#   [page=89] +25 URL (total 2240)
#   [page=90] +25 URL (total 2265)
#   [page=91] +25 URL (total 2290)
#   [page=92] +25 URL (total 2315)
#   [page=93] +25 URL (total 2340)
#   [page=94] +25 URL (total 2365)
#   [page=95] +25 URL (total 2390)
#   [page=96] +25 URL (total 2415)
#   [page=97] +25 URL (total 2440)
#   [page=98] +25 URL (total 2465)
#   [page=99] +25 URL (total 2490)
#   [page=100] +25 URL (total 2515)
#   [page=101] +25 URL (total 2540)
#   [page=102] +25 URL (total 2565)
#   [page=103] +25 URL (total 2590)
#   [page=104] +25 URL (total 2615)
#   [page=105] +25 URL (total 2640)
#   [page=106] +25 URL (total 2665)
#   [page=107] +25 URL (total 2690)
#   [page=108] +25 URL (total 2715)
#   [page=109] +25 URL (total 2740)
#   [page=110] +25 URL (total 2765)
#   [page=111] +25 URL (total 2790)
#   [page=112] +25 URL (total 2815)
#   [page=113] +25 URL (total 2840)
#   [page=114] +25 URL (total 2865)
#   [page=115] +25 URL (total 2890)
#   [page=116] +25 URL (total 2915)
#   [page=117] +25 URL (total 2940)
#   [page=118] +25 URL (total 2965)
#   [page=119] +25 URL (total 2990)
#   [page=120] +25 URL (total 3015)
#   [page=121] +25 URL (total 3040)
#   [page=122] +25 URL (total 3065)
#   [page=123] +25 URL (total 3090)
#   [page=124] +25 URL (total 3115)
#   [page=125] +25 URL (total 3140)
#   [page=126] +25 URL (total 3165)
#   [page=127] +25 URL (total 3190)
#   [page=128] +25 URL (total 3215)
#   [page=129] +25 URL (total 3240)
#   [page=130] +25 URL (total 3265)
#   [page=131] +25 URL (total 3290)
#   [page=132] +25 URL (total 3315)
#   [page=133] +25 URL (total 3340)
#   [page=134] +25 URL (total 3365)
#   [page=135] +25 URL (total 3390)
#   [page=136] +25 URL (total 3415)
#   [page=137] +25 URL (total 3440)
#   [page=138] +25 URL (total 3465)
#   [page=139] +25 URL (total 3490)
#   [page=140] +25 URL (total 3515)
#   [page=141] +25 URL (total 3540)
#   [page=142] +25 URL (total 3565)
#   [page=143] +25 URL (total 3590)
#   [page=144] +25 URL (total 3615)
#   [page=145] +25 URL (total 3640)
#   [page=146] +25 URL (total 3665)
#   [page=147] +25 URL (total 3690)
#   [page=148] +25 URL (total 3715)
#   [page=149] +25 URL (total 3740)
#   [page=150] +25 URL (total 3765)
#   [page=151] +25 URL (total 3790)
#   [page=152] +25 URL (total 3815)
#   [page=153] +25 URL (total 3840)
#   [page=154] +25 URL (total 3865)
#   [page=155] +25 URL (total 3890)
#   [page=156] +25 URL (total 3915)
#   [page=157] +25 URL (total 3940)
#   [page=158] +25 URL (total 3965)
#   [page=159] +25 URL (total 3990)
#   [page=160] +25 URL (total 4015)
#   [page=161] +25 URL (total 4040)
#   [page=162] +25 URL (total 4065)
#   [page=163] +25 URL (total 4090)
#   [page=164] +25 URL (total 4115)
#   [page=165] +25 URL (total 4140)
#   [page=166] +25 URL (total 4165)
#   [page=167] +25 URL (total 4190)
#   [page=168] +25 URL (total 4215)
#   [page=169] +25 URL (total 4240)
#   [page=170] +25 URL (total 4265)
#   [page=171] +25 URL (total 4290)
#   [page=172] +25 URL (total 4315)
#   [page=173] +25 URL (total 4340)
#   [page=174] +25 URL (total 4365)
#   [page=175] +25 URL (total 4390)
#   [page=176] +25 URL (total 4415)
#   [page=177] +25 URL (total 4440)
#   [page=178] +25 URL (total 4465)
#   [page=179] +25 URL (total 4490)
#   [page=180] +25 URL (total 4515)
#   [page=181] +25 URL (total 4540)
#   [page=182] +25 URL (total 4565)
#   [page=183] +25 URL (total 4590)
#   [page=184] +25 URL (total 4615)
#   [page=185] +25 URL (total 4640)
#   [page=186] +25 URL (total 4665)
#   [page=187] +25 URL (total 4690)
#   [page=188] +25 URL (total 4715)
#   [page=189] +25 URL (total 4740)
#   [page=190] +25 URL (total 4765)
#   [page=191] +25 URL (total 4790)
#   [page=192] +25 URL (total 4815)
#   [page=193] +25 URL (total 4840)
#   [page=194] +25 URL (total 4865)
#   [page=195] +25 URL (total 4890)
#   [page=196] +25 URL (total 4915)
#   [page=197] +25 URL (total 4940)
#   [page=198] +25 URL (total 4965)
#   [page=199] +25 URL (total 4990)
#   [page=200] +25 URL (total 5015)
#   [page=201] +25 URL (total 5040)
#   [page=202] +25 URL (total 5065)
#   [page=203] +25 URL (total 5090)
#   [page=204] +25 URL (total 5115)
#   [page=205] +25 URL (total 5140)
#   [page=206] +25 URL (total 5165)
#   [page=207] +25 URL (total 5190)
#   [page=208] +25 URL (total 5215)
#   [page=209] +25 URL (total 5240)
#   [page=210] +25 URL (total 5265)
#   [page=211] +25 URL (total 5290)
#   [page=212] +25 URL (total 5315)
#   [page=213] +25 URL (total 5340)
#   [page=214] +25 URL (total 5365)
#   [page=215] +25 URL (total 5390)
#   [page=216] +25 URL (total 5415)
#   [page=217] +25 URL (total 5440)
#   [page=218] +25 URL (total 5465)
#   [page=219] +25 URL (total 5490)
#   [page=220] +25 URL (total 5515)
#   [page=221] +25 URL (total 5540)
#   [page=222] +25 URL (total 5565)
#   [page=223] +25 URL (total 5590)
#   [page=224] +25 URL (total 5615)
#   [page=225] +25 URL (total 5640)
#   [page=226] +25 URL (total 5665)
#   [page=227] +25 URL (total 5690)
#   [page=228] +25 URL (total 5715)
#   [page=229] +25 URL (total 5740)
#   [page=230] +25 URL (total 5765)
#   [page=231] +25 URL (total 5790)
#   [page=232] +25 URL (total 5815)
#   [page=233] +25 URL (total 5840)
#   [page=234] +25 URL (total 5865)
#   [page=235] +25 URL (total 5890)
#   [page=236] +25 URL (total 5915)
#   [page=237] +25 URL (total 5940)
#   [page=238] +25 URL (total 5965)
#   [page=239] +25 URL (total 5990)
#   [page=240] +25 URL (total 6015)
#   [page=241] +25 URL (total 6040)
#   [page=242] +25 URL (total 6065)
#   [page=243] +25 URL (total 6090)
#   [page=244] +25 URL (total 6115)
#   [page=245] +25 URL (total 6140)
#   [page=246] +25 URL (total 6165)
#   [page=247] +25 URL (total 6190)
#   [page=248] +25 URL (total 6215)
#   [page=249] +25 URL (total 6240)
#   [page=250] +25 URL (total 6265)
#   [page=251] +25 URL (total 6290)
#   [page=252] +25 URL (total 6315)
#   [page=253] +25 URL (total 6340)
#   [page=254] +25 URL (total 6365)
#   [page=255] +25 URL (total 6390)
#   [page=256] +25 URL (total 6415)
#   [page=257] +25 URL (total 6440)
#   [page=258] +25 URL (total 6465)
#   [page=259] +25 URL (total 6490)
#   [page=260] +25 URL (total 6515)
#   [page=261] +25 URL (total 6540)
#   [page=262] +25 URL (total 6565)
#   [page=263] +25 URL (total 6590)
#   [page=264] +25 URL (total 6615)
#   [page=265] +25 URL (total 6640)
#   [page=266] +25 URL (total 6665)
#   [page=267] +25 URL (total 6690)
#   [page=268] +25 URL (total 6715)
#   [page=269] +25 URL (total 6740)
#   [page=270] +25 URL (total 6765)
#   [page=271] +25 URL (total 6790)
#   [page=272] +25 URL (total 6815)
#   [page=273] +25 URL (total 6840)
#   [page=274] +25 URL (total 6865)
#   [page=275] +25 URL (total 6890)
#   [page=276] +25 URL (total 6915)
#   [page=277] +25 URL (total 6940)
#   [page=278] +25 URL (total 6965)
#   [page=279] +25 URL (total 6990)
#   [page=280] +25 URL (total 7015)
#   [page=281] +25 URL (total 7040)
#   [page=282] +25 URL (total 7065)
#   [page=283] +25 URL (total 7090)
#   [page=284] +25 URL (total 7115)
#   [page=285] +25 URL (total 7140)
#   [page=286] +25 URL (total 7165)
#   [page=287] +25 URL (total 7190)
#   [page=288] +25 URL (total 7215)
#   [page=289] +25 URL (total 7240)
#   [page=290] +25 URL (total 7265)
#   [page=291] +25 URL (total 7290)
#   [page=292] +25 URL (total 7315)
#   [page=293] +25 URL (total 7340)
#   [page=294] +25 URL (total 7365)
#   [page=295] +25 URL (total 7390)
#   [page=296] +25 URL (total 7415)
#   [page=297] +25 URL (total 7440)
#   [page=298] +25 URL (total 7465)
#   [page=299] +25 URL (total 7490)
#   [page=300] +25 URL (total 7515)
#   [page=301] +25 URL (total 7540)
#   [page=302] +25 URL (total 7565)
#   [page=303] +25 URL (total 7590)
#   [page=304] +25 URL (total 7615)
#   [page=305] +25 URL (total 7640)
#   [page=306] +25 URL (total 7665)
#   [page=307] +25 URL (total 7690)
#   [page=308] +25 URL (total 7715)
#   [page=309] +25 URL (total 7740)
#   [page=310] +25 URL (total 7765)
#   [page=311] +25 URL (total 7790)
#   [page=312] +25 URL (total 7815)
#   [page=313] +25 URL (total 7840)
#   [page=314] +25 URL (total 7865)
#   [page=315] +25 URL (total 7890)
#   [page=316] +25 URL (total 7915)
#   [page=317] +25 URL (total 7940)
#   [page=318] +25 URL (total 7965)
#   [page=319] +25 URL (total 7990)
#   [page=320] +25 URL (total 8015)
#   [page=321] +25 URL (total 8040)
#   [page=322] +25 URL (total 8065)
#   [page=323] +25 URL (total 8090)
#   [page=324] +25 URL (total 8115)
#   [page=325] +25 URL (total 8140)
#   [page=326] +25 URL (total 8165)
#   [page=327] +25 URL (total 8190)
#   [page=328] +25 URL (total 8215)
#   [page=329] +25 URL (total 8240)
#   [page=330] +25 URL (total 8265)
#   [page=331] +25 URL (total 8290)
#   [page=332] +25 URL (total 8315)
#   [page=333] +25 URL (total 8340)
#   [page=334] +25 URL (total 8365)
#   [page=335] +25 URL (total 8390)
#   [page=336] +25 URL (total 8415)
#   [page=337] +25 URL (total 8440)
#   [page=338] +25 URL (total 8465)
#   [page=339] +25 URL (total 8490)
#   [page=340] +25 URL (total 8515)
#   [page=341] +25 URL (total 8540)
#   [page=342] +25 URL (total 8565)
#   [page=343] +25 URL (total 8590)
#   [page=344] +25 URL (total 8615)
#   [page=345] +25 URL (total 8640)
#   [page=346] +25 URL (total 8665)
#   [page=347] +25 URL (total 8690)
#   [page=348] +25 URL (total 8715)
#   [page=349] +25 URL (total 8740)
#   [page=350] +25 URL (total 8765)
#   [page=351] +25 URL (total 8790)
#   [page=352] +25 URL (total 8815)
#   [page=353] +25 URL (total 8840)
#   [page=354] +25 URL (total 8865)
# ...
#   [page=100] +25 URL (total 2515)
#   [page=101] +25 URL (total 2540)
#   [page=102] +25 URL (total 2565)
#   [page=103] +25 URL (total 2590)
#   [page=104] +25 URL (total 2615)
#   [page=105] +25 URL (total 2640)
#   [page=106] +25 URL (total 2665)
#   [page=107] +25 URL (total 2690)
#   [page=108] +25 URL (total 2715)
#   [page=109] +25 URL (total 2740)
#   [page=110] +25 URL (total 2765)
#   [page=111] +25 URL (total 2790)
#   [page=112] +25 URL (total 2815)
#   [page=113] +25 URL (total 2840)
#   [page=114] +25 URL (total 2865)
#   [page=115] +25 URL (total 2890)
#   [page=116] +25 URL (total 2915)
#   [page=117] +25 URL (total 2940)
#   [page=118] +25 URL (total 2965)
#   [page=119] +25 URL (total 2990)
#   [page=120] +25 URL (total 3015)
#   [page=121] +25 URL (total 3040)
#   [page=122] +23 URL (total 3063)
#   [page=123] +0 URL (total 3063)
#   [page=124] +0 URL (total 3063)
#   [page=125] +0 URL (total 3063)
#
# Crawl sub-kategori: Sulawesi Selatan
#   [page=1] +40 URL (total 40)
#   [page=2] +25 URL (total 65)
#   [page=3] +25 URL (total 90)
#   [page=4] +25 URL (total 115)
#   [page=5] +25 URL (total 140)
#   [page=6] +25 URL (total 165)
#   [page=7] +25 URL (total 190)
#   [page=8] +25 URL (total 215)
#   [page=9] +25 URL (total 240)
#   [page=10] +25 URL (total 265)
#   [page=11] +25 URL (total 290)
#   [page=12] +25 URL (total 315)
#   [page=13] +25 URL (total 340)
#   [page=14] +25 URL (total 365)
#   [page=15] +25 URL (total 390)
#   [page=16] +25 URL (total 415)
#   [page=17] +25 URL (total 440)
#   [page=18] +25 URL (total 465)
#   [page=19] +25 URL (total 490)
#   [page=20] +25 URL (total 515)
#   [page=21] +25 URL (total 540)
#   [page=22] +25 URL (total 565)
#   [page=23] +25 URL (total 590)
#   [page=24] +25 URL (total 615)
#   [page=25] +25 URL (total 640)
#   [page=26] +25 URL (total 665)
#   [page=27] +25 URL (total 690)
#   [page=28] +25 URL (total 715)
#   [page=29] +25 URL (total 740)
#   [page=30] +25 URL (total 765)
#   [page=31] +25 URL (total 790)
#   [page=32] +25 URL (total 815)
#   [page=33] +25 URL (total 840)
#   [page=34] +25 URL (total 865)
#   [page=35] +25 URL (total 890)
#   [page=36] +25 URL (total 915)
#   [page=37] +25 URL (total 940)
#   [page=38] +25 URL (total 965)
#   [page=39] +25 URL (total 990)
#   [page=40] +25 URL (total 1015)
#   [page=41] +25 URL (total 1040)
#   [page=42] +25 URL (total 1065)
#   [page=43] +25 URL (total 1090)
#   [page=44] +25 URL (total 1115)
#   [page=45] +25 URL (total 1140)
#   [page=46] +25 URL (total 1165)
#   [page=47] +25 URL (total 1190)
#   [page=48] +25 URL (total 1215)
#   [page=49] +25 URL (total 1240)
#   [page=50] +25 URL (total 1265)
#   [page=51] +25 URL (total 1290)
#   [page=52] +25 URL (total 1315)
#   [page=53] +25 URL (total 1340)
#   [page=54] +25 URL (total 1365)
#   [page=55] +25 URL (total 1390)
#   [page=56] +25 URL (total 1415)
#   [page=57] +25 URL (total 1440)
#   [page=58] +25 URL (total 1465)
#   [page=59] +25 URL (total 1490)
#   [page=60] +25 URL (total 1515)
#   [page=61] +25 URL (total 1540)
#   [page=62] +25 URL (total 1565)
#   [page=63] +25 URL (total 1590)
#   [page=64] +25 URL (total 1615)
#   [page=65] +25 URL (total 1640)
#   [page=66] +25 URL (total 1665)
#   [page=67] +25 URL (total 1690)
#   [page=68] +25 URL (total 1715)
#   [page=69] +25 URL (total 1740)
#   [page=70] +25 URL (total 1765)
#   [page=71] +25 URL (total 1790)
#   [page=72] +25 URL (total 1815)
#   [page=73] +25 URL (total 1840)
#   [page=74] +25 URL (total 1865)
#   [page=75] +25 URL (total 1890)
#   [page=76] +25 URL (total 1915)
#   [page=77] +25 URL (total 1940)
#   [page=78] +25 URL (total 1965)
#   [page=79] +25 URL (total 1990)
#   [page=80] +25 URL (total 2015)
#   [page=81] +25 URL (total 2040)
#   [page=82] +25 URL (total 2065)
#   [page=83] +25 URL (total 2090)
#   [page=84] +25 URL (total 2115)
#   [page=85] +25 URL (total 2140)
#   [page=86] +25 URL (total 2165)
#   [page=87] +25 URL (total 2190)
#   [page=88] +25 URL (total 2215)
#   [page=89] +25 URL (total 2240)
#   [page=90] +25 URL (total 2265)
#   [page=91] +25 URL (total 2290)
#   [page=92] +25 URL (total 2315)
#   [page=93] +25 URL (total 2340)
#   [page=94] +25 URL (total 2365)
#   [page=95] +25 URL (total 2390)
#   [page=96] +25 URL (total 2415)
#   [page=97] +25 URL (total 2440)
#   [page=98] +25 URL (total 2465)
#   [page=99] +25 URL (total 2490)
#   [page=100] +25 URL (total 2515)
#   [page=101] +25 URL (total 2540)
#   [page=102] +25 URL (total 2565)
#   [page=103] +25 URL (total 2590)
#   [page=104] +25 URL (total 2615)
#   [page=105] +25 URL (total 2640)
#   [page=106] +25 URL (total 2665)
#   [page=107] +25 URL (total 2690)
#   [page=108] +25 URL (total 2715)
#   [page=109] +25 URL (total 2740)
#   [page=110] +25 URL (total 2765)
#   [page=111] +25 URL (total 2790)
#   [page=112] +25 URL (total 2815)
#   [page=113] +25 URL (total 2840)
#   [page=114] +25 URL (total 2865)
#   [page=115] +25 URL (total 2890)
#   [page=116] +25 URL (total 2915)
#   [page=117] +25 URL (total 2940)
#   [page=118] +25 URL (total 2965)
#   [page=119] +25 URL (total 2990)
#   [page=120] +25 URL (total 3015)
#   [page=121] +25 URL (total 3040)
#   [page=122] +25 URL (total 3065)
#   [page=123] +25 URL (total 3090)
#   [page=124] +25 URL (total 3115)
#   [page=125] +25 URL (total 3140)
#   [page=126] +25 URL (total 3165)
#   [page=127] +25 URL (total 3190)
#   [page=128] +25 URL (total 3215)
#   [page=129] +25 URL (total 3240)
#   [page=130] +25 URL (total 3265)
#   [page=131] +25 URL (total 3290)
#   [page=132] +25 URL (total 3315)
#   [page=133] +25 URL (total 3340)
#   [page=134] +25 URL (total 3365)
#   [page=135] +25 URL (total 3390)
#   [page=136] +25 URL (total 3415)
#   [page=137] +25 URL (total 3440)
#   [page=138] +25 URL (total 3465)
#   [page=139] +25 URL (total 3490)
#   [page=140] +25 URL (total 3515)
#   [page=141] +25 URL (total 3540)
#   [page=142] +25 URL (total 3565)
#   [page=143] +25 URL (total 3590)
#   [page=144] +25 URL (total 3615)
#   [page=145] +25 URL (total 3640)
#   [page=146] +25 URL (total 3665)
#   [page=147] +25 URL (total 3690)
#   [page=148] +25 URL (total 3715)
#   [page=149] +25 URL (total 3740)
#   [page=150] +25 URL (total 3765)
#   [page=151] +25 URL (total 3790)
#   [page=152] +25 URL (total 3815)
#   [page=153] +25 URL (total 3840)
#   [page=154] +25 URL (total 3865)
#   [page=155] +25 URL (total 3890)
#   [page=156] +25 URL (total 3915)
#   [page=157] +25 URL (total 3940)
#   [page=158] +25 URL (total 3965)
#   [page=159] +25 URL (total 3990)
#   [page=160] +25 URL (total 4015)
#   [page=161] +25 URL (total 4040)
#   [page=162] +25 URL (total 4065)
#   [page=163] +25 URL (total 4090)
#   [page=164] +25 URL (total 4115)
#   [page=165] +25 URL (total 4140)
#   [page=166] +25 URL (total 4165)
#   [page=167] +25 URL (total 4190)
#   [page=168] +25 URL (total 4215)
#   [page=169] +25 URL (total 4240)
#   [page=170] +25 URL (total 4265)
#   [page=171] +25 URL (total 4290)
#   [page=172] +25 URL (total 4315)
#   [page=173] +25 URL (total 4340)
#   [page=174] +25 URL (total 4365)
#   [page=175] +25 URL (total 4390)
#   [page=176] +25 URL (total 4415)
#   [page=177] +25 URL (total 4440)
#   [page=178] +25 URL (total 4465)
#   [page=179] +25 URL (total 4490)
#   [page=180] +25 URL (total 4515)
#   [page=181] +25 URL (total 4540)
#   [page=182] +25 URL (total 4565)
#   [page=183] +25 URL (total 4590)
#   [page=184] +25 URL (total 4615)
#   [page=185] +25 URL (total 4640)
#   [page=186] +25 URL (total 4665)
#   [page=187] +25 URL (total 4690)
#   [page=188] +25 URL (total 4715)
#   [page=189] +25 URL (total 4740)
#   [page=190] +25 URL (total 4765)
#   [page=191] +25 URL (total 4790)
#   [page=192] +25 URL (total 4815)
#   [page=193] +25 URL (total 4840)
#   [page=194] +25 URL (total 4865)
#   [page=195] +25 URL (total 4890)
#   [page=196] +25 URL (total 4915)
#   [page=197] +25 URL (total 4940)
#   [page=198] +25 URL (total 4965)
#   [page=199] +25 URL (total 4990)
#   [page=200] +25 URL (total 5015)
#   [page=201] +25 URL (total 5040)
#   [page=202] +25 URL (total 5065)
#   [page=203] +25 URL (total 5090)
#   [page=204] +25 URL (total 5115)
#   [page=205] +25 URL (total 5140)
#   [page=206] +25 URL (total 5165)
#   [page=207] +25 URL (total 5190)
#   [page=208] +25 URL (total 5215)
#   [page=209] +25 URL (total 5240)
#   [page=210] +25 URL (total 5265)
#   [page=211] +25 URL (total 5290)
#   [page=212] +25 URL (total 5315)
#   [page=213] +25 URL (total 5340)
#   [page=214] +25 URL (total 5365)
#   [page=215] +25 URL (total 5390)
#   [page=216] +25 URL (total 5415)
#   [page=217] +25 URL (total 5440)
#   [page=218] +25 URL (total 5465)
#   [page=219] +25 URL (total 5490)
#   [page=220] +25 URL (total 5515)
#   [page=221] +25 URL (total 5540)
#   [page=222] +25 URL (total 5565)
#   [page=223] +25 URL (total 5590)
#   [page=224] +25 URL (total 5615)
#   [page=225] +25 URL (total 5640)
#   [page=226] +25 URL (total 5665)
#   [page=227] +25 URL (total 5690)
#   [page=228] +25 URL (total 5715)
#   [page=229] +25 URL (total 5740)
#   [page=230] +25 URL (total 5765)
#   [page=231] +25 URL (total 5790)
#   [page=232] +25 URL (total 5815)
#   [page=233] +25 URL (total 5840)
#   [page=234] +25 URL (total 5865)
#   [page=235] +25 URL (total 5890)
#   [page=236] +25 URL (total 5915)
#   [page=237] +25 URL (total 5940)
#   [page=238] +25 URL (total 5965)
#   [page=239] +25 URL (total 5990)
#   [page=240] +25 URL (total 6015)
#   [page=241] +25 URL (total 6040)
#   [page=242] +25 URL (total 6065)
#   [page=243] +25 URL (total 6090)
#   [page=244] +25 URL (total 6115)
#   [page=245] +25 URL (total 6140)
#   [page=246] +25 URL (total 6165)
#   [page=247] +25 URL (total 6190)
#   [page=248] +25 URL (total 6215)
#   [page=249] +25 URL (total 6240)
#   [page=250] +25 URL (total 6265)
#   [page=251] +25 URL (total 6290)
#   [page=252] +25 URL (total 6315)
#   [page=253] +25 URL (total 6340)
#   [page=254] +25 URL (total 6365)
#   [page=255] +25 URL (total 6390)
#   [page=256] +25 URL (total 6415)
#   [page=257] +25 URL (total 6440)
#   [page=258] +25 URL (total 6465)
#   [page=259] +25 URL (total 6490)
#   [page=260] +25 URL (total 6515)
#   [page=261] +25 URL (total 6540)
#   [page=262] +25 URL (total 6565)
#   [page=263] +25 URL (total 6590)
#   [page=264] +25 URL (total 6615)
#   [page=265] +25 URL (total 6640)
#   [page=266] +25 URL (total 6665)
#   [page=267] +25 URL (total 6690)
#   [page=268] +25 URL (total 6715)
#   [page=269] +25 URL (total 6740)
#   [page=270] +25 URL (total 6765)
#   [page=271] +25 URL (total 6790)
#   [page=272] +25 URL (total 6815)
#   [page=273] +25 URL (total 6840)
#   [page=274] +25 URL (total 6865)
#   [page=275] +25 URL (total 6890)
#   [page=276] +25 URL (total 6915)
#   [page=277] +25 URL (total 6940)
#   [page=278] +25 URL (total 6965)
#   [page=279] +25 URL (total 6990)
#   [page=280] +25 URL (total 7015)
#   [page=281] +25 URL (total 7040)
#   [page=282] +25 URL (total 7065)
#   [page=283] +25 URL (total 7090)
#   [page=284] +25 URL (total 7115)
#   [page=285] +25 URL (total 7140)
#   [page=286] +25 URL (total 7165)
#   [page=287] +25 URL (total 7190)
#   [page=288] +25 URL (total 7215)
#   [page=289] +25 URL (total 7240)
#   [page=290] +25 URL (total 7265)
#   [page=291] +25 URL (total 7290)
#   [page=292] +25 URL (total 7315)
#   [page=293] +25 URL (total 7340)
#   [page=294] +25 URL (total 7365)
#   [page=295] +25 URL (total 7390)
#   [page=296] +25 URL (total 7415)
#   [page=297] +25 URL (total 7440)
#   [page=298] +25 URL (total 7465)
#   [page=299] +25 URL (total 7490)
#   [page=300] +25 URL (total 7515)
#   [page=301] +25 URL (total 7540)
#   [page=302] +25 URL (total 7565)
#   [page=303] +25 URL (total 7590)
#   [page=304] +25 URL (total 7615)
#   [page=305] +25 URL (total 7640)
#   [page=306] +25 URL (total 7665)
#   [page=307] +25 URL (total 7690)
#   [page=308] +25 URL (total 7715)
#   [page=309] +25 URL (total 7740)
#   [page=310] +25 URL (total 7765)
#   [page=311] +25 URL (total 7790)
#   [page=312] +25 URL (total 7815)
#   [page=313] +25 URL (total 7840)
#   [page=314] +25 URL (total 7865)
#   [page=315] +25 URL (total 7890)
#   [page=316] +25 URL (total 7915)
#   [page=317] +25 URL (total 7940)
#   [page=318] +25 URL (total 7965)
#   [page=319] +25 URL (total 7990)
#   [page=320] +25 URL (total 8015)
#   [page=321] +25 URL (total 8040)
#   [page=322] +25 URL (total 8065)
#   [page=323] +25 URL (total 8090)
#   [page=324] +25 URL (total 8115)
#   [page=325] +25 URL (total 8140)
#   [page=326] +25 URL (total 8165)
#   [page=327] +25 URL (total 8190)
#   [page=328] +25 URL (total 8215)
#   [page=329] +25 URL (total 8240)
#   [page=330] +25 URL (total 8265)
#   [page=331] +25 URL (total 8290)
#   [page=332] +25 URL (total 8315)
#   [page=333] +25 URL (total 8340)
#   [page=334] +25 URL (total 8365)
#   [page=335] +25 URL (total 8390)
#   [page=336] +25 URL (total 8415)
#   [page=337] +25 URL (total 8440)
#   [page=338] +25 URL (total 8465)
#   [page=339] +25 URL (total 8490)
#   [page=340] +25 URL (total 8515)
#   [page=341] +25 URL (total 8540)
#   [page=342] +25 URL (total 8565)
#   [page=343] +25 URL (total 8590)
#   [page=344] +25 URL (total 8615)
#   [page=345] +25 URL (total 8640)
#   [page=346] +25 URL (total 8665)
#   [page=347] +25 URL (total 8690)
#   [page=348] +25 URL (total 8715)
#   [page=349] +25 URL (total 8740)
#   [page=350] +25 URL (total 8765)
#   [page=351] +25 URL (total 8790)
#   [page=352] +25 URL (total 8815)
#   [page=353] +25 URL (total 8840)
#   [page=354] +25 URL (total 8865)
#   [page=355] +25 URL (total 8890)
#   [page=356] +25 URL (total 8915)
#   [page=357] +25 URL (total 8940)
#   [page=358] +25 URL (total 8965)
#   [page=359] +25 URL (total 8990)
#   [page=360] +25 URL (total 9015)
#   [page=361] +25 URL (total 9040)
#   [page=362] +25 URL (total 9065)
#   [page=363] +25 URL (total 9090)
#   [page=364] +25 URL (total 9115)
#   [page=365] +25 URL (total 9140)
#   [page=366] +25 URL (total 9165)
#   [page=367] +25 URL (total 9190)
#   [page=368] +25 URL (total 9215)
#   [page=369] +25 URL (total 9240)
#   [page=370] +25 URL (total 9265)
#   [page=371] +25 URL (total 9290)
#   [page=372] +25 URL (total 9315)
#   [page=373] +25 URL (total 9340)
#   [page=374] +25 URL (total 9365)
#   [page=375] +25 URL (total 9390)
#   [page=376] +25 URL (total 9415)
#   [page=377] +25 URL (total 9440)
#   [page=378] +25 URL (total 9465)
#   [page=379] +25 URL (total 9490)
#   [page=380] +25 URL (total 9515)
#   [page=381] +22 URL (total 9537)
#   [page=382] +0 URL (total 9537)
#   [page=383] +0 URL (total 9537)
#   [page=384] +0 URL (total 9537)
#
# Crawl sub-kategori: Bali
#   [page=1] +30 URL (total 30)
#   [page=2] +19 URL (total 49)
#   [page=3] +19 URL (total 68)
#   [page=4] +19 URL (total 87)
#   [page=5] +19 URL (total 106)
#   [page=6] +19 URL (total 125)
#   [page=7] +19 URL (total 144)
#   [page=8] +19 URL (total 163)
#   [page=9] +19 URL (total 182)
#   [page=10] +19 URL (total 201)
#   [page=11] +0 URL (total 201)
#   [page=12] +0 URL (total 201)
#   [page=13] +0 URL (total 201)
#
# Crawl sub-kategori: Indeks
#   [page=1] +21 URL (total 21)
#   [page=2] +20 URL (total 41)
#   [page=3] +20 URL (total 61)
#   [page=4] +20 URL (total 81)
#   [page=5] +20 URL (total 101)
#   [page=6] +4 URL (total 105)
#   [page=7] +0 URL (total 105)
#   [page=8] +0 URL (total 105)
#   [page=9] +0 URL (total 105)
#
# Crawl sub-kategori: Yogyakarta
#   [page=1] +0 URL (total 0)
#   [page=2] +0 URL (total 0)
#   [page=3] +0 URL (total 0)
#
# Crawl sub-kategori: Bali
#   [page=1] +0 URL (total 0)
#   [page=2] +0 URL (total 0)
#   [page=3] +0 URL (total 0)
#
# Total kandidat (URL unik per sub): 66563
# Scraping:   2%|▏         | 1349/66563 [44:51<32:08:11,  1.77s/url]WARNING:urllib3.connectionpool:Retrying (Retry(total=4, connect=5, read=4, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='medan.kompas.com', port=443): Read timed out. (read timeout=20)")': /read/2025/07/07/162603678/buntut-anaknya-pakai-mobil-dinas-lalu-tabrak-lari-kasi-propam-polres-tapsel
# Scraping:   6%|▌         | 3778/66563 [2:03:50<34:17:56,  1.97s/url]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2572333358.py in <cell line: 0>()
#     289 # Jalankan
#     290 # ==========================
# --> 291 run_scrape_nusaraya(OUTPUT_CSV, max_pages_per_sub=MAX_PAGES_PER_SUB)
#
# /tmp/ipython-input-2572333358.py in run_scrape_nusaraya(output_csv_path, max_pages_per_sub)
#     281             print(f"\nERROR [{i}] {url} -> {e.__class__.__name__}: {e}")
#     282         finally:
# --> 283             time.sleep(random.uniform(*REQUEST_DELAY))
#     284
#     285     print(f"Selesai. Artikel baru tersimpan: {saved}.")
#
# KeyboardInterrupt:

# %% [markdown]
# # Scraping Lifestyle

# %%
from google.colab import drive
import os

# Tentukan folder dan file output di Drive
DRIVE_FOLDER = "/content/drive/MyDrive/KompasLifestyle"
os.makedirs(DRIVE_FOLDER, exist_ok=True)

OUTPUT_CSV = os.path.join(DRIVE_FOLDER, "kompas_lifestyle_scraped.csv")
print("Folder Drive:", DRIVE_FOLDER)
print("File output :", OUTPUT_CSV)
# Out:
# Folder Drive: /content/drive/MyDrive/KompasLifestyle
# File output : /content/drive/MyDrive/KompasLifestyle/kompas_lifestyle_scraped.csv

# %%
# Scraper Kompas Money (menu-aware + subcategory + tags + resumeable)

import os, re, time, csv, random, json
from urllib.parse import urljoin, urlparse
import requests
from bs4 import BeautifulSoup
from collections import OrderedDict
from tqdm import tqdm

# ==========================
# Konfigurasi umum
# ==========================
BASE = "https://lifestyle.kompas.com/"
REQUEST_DELAY = (0.8, 1.6)
TIMEOUT = 20
MAX_PAGES_PER_SUB = None  # None = lanjut sampai 3 halaman kosong berturut-turut
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
}

# ==========================
# Session HTTP dengan retry
# ==========================
from requests.adapters import HTTPAdapter, Retry

def make_session():
    s = requests.Session()
    retries = Retry(
        total=5, connect=5, read=5,
        backoff_factor=1.2,
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=frozenset(["GET"])
    )
    s.headers.update(HEADERS)
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.mount("http://", HTTPAdapter(max_retries=retries))
    return s

SESSION = make_session()

# ==========================
# CSV helper
# ==========================
FIELDNAMES = ["url", "category", "subcategory", "tanggal_publish", "judul", "tags", "konten"]

def ensure_csv(path):
    if not os.path.exists(path):
        with open(path, "w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=FIELDNAMES)
            writer.writeheader()

def load_done_urls(path):
    done = set()
    if os.path.exists(path):
        with open(path, "r", encoding="utf-8") as f:
            r = csv.DictReader(f)
            for row in r:
                u = (row.get("url") or "").strip()
                if u:
                    done.add(u)
    return done

def append_row(path, row: dict):
    clean = {k: (row.get(k) or "") for k in FIELDNAMES}
    with open(path, "a", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=FIELDNAMES)
        w.writerow(clean)

# ==========================
# Utilities
# ==========================
def normalize_ws(text):
    return re.sub(r"\s+", " ", (text or "").strip())

def looks_like_baca_juga(text):
    return "baca juga" in (text or "").lower()

def safe_get(url):
    r = SESSION.get(url, timeout=TIMEOUT)
    r.raise_for_status()
    return r

def absolutize(base_url, href):
    if href.startswith("//"):
        return "https:" + href
    if href.startswith("/"):
        parsed = urlparse(base_url)
        return f"{parsed.scheme}://{parsed.netloc}{href}"
    return href

# ==========================
# Dapatkan daftar sub-kategori dari menu
# ==========================
def discover_menu_links():
    found = OrderedDict()
    try:
        r = safe_get(BASE)
        soup = BeautifulSoup(r.text, "lxml")
        for a in soup.select(".kanalHeader[data-kanal='lifestyle'] .kanalMenu a[href]"):
            name = normalize_ws(a.get_text())
            href = absolutize(BASE, a.get("href","").strip())
            if not href or not name:
                continue
            found[href] = name
    except Exception:
        pass

    # fallback kalau parsing gagal
    SEED = OrderedDict([
        ("https://lifestyle.kompas.com/beauty", "Beauty & Grooming"),
        ("https://lifestyle.kompas.com/fashion", "Fashion"),
        ("https://lifestyle.kompas.com/wellness", "Wellness"),
        ("https://lifestyle.kompas.com/relationship", "Relationship"),
        ("https://lifestyle.kompas.com/parenting", "Parenting"),
    ])
    for href, name in SEED.items():
        found.setdefault(href, name)

    return list(found.items())

# ==========================
# Ambil daftar URL artikel per subcategory
# ==========================
def is_article_url(href: str):
    if not href or "kompas.com" not in href:
        return False
    if "/read/" not in href:
        return False
    if any(b in href for b in ["/komentar/", "/copy/"]):
        return False
    return True

def collect_urls_from_list(listing_url):
    try:
        res = safe_get(listing_url)
    except Exception:
        return set()
    soup = BeautifulSoup(res.text, "lxml")
    urls = set()
    for a in soup.select("a[href*='/read/']"):
        href = a.get("href")
        if not href:
            continue
        full = absolutize(listing_url, href)
        if is_article_url(full):
            urls.add(full)
    return urls

def page_url(base, page):
    if page <= 1:
        return base
    parsed = urlparse(base)
    joiner = "&" if parsed.query else "?"
    return f"{base}{joiner}page={page}"

def crawl_subcategory_urls(sub_url, max_pages=None):
    discovered = OrderedDict()
    consecutive_empty = 0
    page = 1
    while True:
        if max_pages is not None and page > max_pages:
            break
        url = page_url(sub_url, page)
        urls = collect_urls_from_list(url)
        before = len(discovered)
        for u in sorted(urls):
            discovered.setdefault(u, None)
        gained = len(discovered) - before
        print(f"  [page={page}] +{gained} URL (total {len(discovered)})")
        time.sleep(random.uniform(*REQUEST_DELAY))
        consecutive_empty = consecutive_empty + 1 if gained == 0 else 0
        if consecutive_empty >= 3:
            break
        page += 1
    return list(discovered.keys())

# ==========================
# Parsing artikel
# ==========================
def extract_publish_date(soup):
    meta = soup.find("meta", attrs={"name": "content_PublishedDate"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    meta2 = soup.select_one('meta[property="article:published_time"]')
    if meta2 and meta2.get("content"):
        return meta2["content"].strip()
    return ""

def extract_tags(soup):
    meta = soup.find("meta", attrs={"name": "content_tags"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    tag_links = soup.select("a.tag__article__link, .tag__item a")
    if tag_links:
        tags = [normalize_ws(a.get_text()) for a in tag_links if a.get_text().strip()]
        return ", ".join(tags)
    return ""

def parse_article(url):
    res = safe_get(url)
    soup = BeautifulSoup(res.text, "lxml")
    title_el = soup.select_one("h1.read__title") or soup.select_one("h1.article__title") or soup.select_one("h1")
    judul = normalize_ws(title_el.get_text()) if title_el else normalize_ws(soup.title.get_text() if soup.title else "")
    tanggal_publish = extract_publish_date(soup)
    tags = extract_tags(soup)
    wrapper = soup.select_one(".read__content") or soup.select_one(".article__content") or soup
    ps = wrapper.find_all("p")
    paragraphs = []
    for p in ps:
        txt = p.get_text(" ").strip()
        if not txt:
            continue
        if looks_like_baca_juga(txt):
            continue
        if "KOMPAS.com" in txt and "Download" in txt:
            continue
        paragraphs.append(normalize_ws(txt))
    konten = " ".join(paragraphs)
    return {"judul": judul, "tanggal_publish": tanggal_publish, "tags": tags, "konten": konten}

# ==========================
# Pipeline utama
# ==========================
def run_scrape_lifestyle(output_csv_path, max_pages_per_sub=None):
    ensure_csv(output_csv_path)
    done = load_done_urls(output_csv_path)
    print(f"URL sudah ada di CSV: {len(done)}")

    submenus = discover_menu_links()
    print("Sub-kategori terdeteksi:")
    for href, name in submenus:
        print(f" - {name}: {href}")

    all_urls = OrderedDict()
    for href, name in submenus:
        print(f"\nCrawl sub-kategori: {name}")
        urls = crawl_subcategory_urls(href, max_pages=max_pages_per_sub)
        for u in urls:
            all_urls.setdefault((u, name), None)

    print(f"\nTotal kandidat (URL unik per sub): {len(all_urls)}")

    category = "Lifestyle"
    saved = 0
    for i, ((url, subcat), _) in enumerate(tqdm(all_urls.items(), desc="Scraping", unit="url"), 1):
        if url in done:
            continue
        try:
            data = parse_article(url)
            if not data or not data.get("judul") or not data.get("konten"):
                continue
            row = {
                "url": url,
                "category": category,
                "subcategory": subcat,
                "tanggal_publish": data["tanggal_publish"],
                "judul": data["judul"],
                "tags": data["tags"],
                "konten": data["konten"]
            }
            append_row(output_csv_path, row)
            done.add(url)
            saved += 1
        except KeyboardInterrupt:
            print("\n⛔ Dihentikan manual, progres tersimpan.")
            break
        except Exception as e:
            print(f"\nERROR [{i}] {url} -> {e.__class__.__name__}: {e}")
        finally:
            time.sleep(random.uniform(*REQUEST_DELAY))

    print(f"Selesai. Artikel baru tersimpan: {saved}.")
    print("CSV:", output_csv_path)

# ==========================
# Jalankan
# ==========================
run_scrape_lifestyle(OUTPUT_CSV, max_pages_per_sub=MAX_PAGES_PER_SUB)
# Out:
# URL sudah ada di CSV: 0
# Sub-kategori terdeteksi:
#  - Beauty & Grooming: https://lifestyle.kompas.com/beauty
#  - Fashion: https://lifestyle.kompas.com/fashion
#  - Wellness: https://lifestyle.kompas.com/wellness
#  - Relationship: https://lifestyle.kompas.com/relationship
#  - Parenting: https://lifestyle.kompas.com/parenting
#  - Buku: https://buku.kompas.com
#  - Indeks: https://indeks.kompas.com/?site=lifestyle
#  - Sadar Stunting: https://genbest.kompas.com
#  - Kilas Lifestyle: https://kilaslifestyle.kompas.com
#
# Crawl sub-kategori: Beauty & Grooming
#   [page=1] +37 URL (total 37)
#   [page=2] +0 URL (total 37)
#   [page=3] +0 URL (total 37)
#   [page=4] +0 URL (total 37)
#
# Crawl sub-kategori: Fashion
#   [page=1] +36 URL (total 36)
#   [page=2] +0 URL (total 36)
#   [page=3] +0 URL (total 36)
#   [page=4] +0 URL (total 36)
#
# Crawl sub-kategori: Wellness
#   [page=1] +33 URL (total 33)
#   [page=2] +0 URL (total 33)
#   [page=3] +0 URL (total 33)
#   [page=4] +0 URL (total 33)
#
# Crawl sub-kategori: Relationship
#   [page=1] +36 URL (total 36)
#   [page=2] +0 URL (total 36)
#   [page=3] +0 URL (total 36)
#   [page=4] +0 URL (total 36)
#
# Crawl sub-kategori: Parenting
#   [page=1] +37 URL (total 37)
#   [page=2] +0 URL (total 37)
#   [page=3] +0 URL (total 37)
#   [page=4] +0 URL (total 37)
#
# Crawl sub-kategori: Buku
#   [page=1] +22 URL (total 22)
#   [page=2] +0 URL (total 22)
#   [page=3] +0 URL (total 22)
#   [page=4] +0 URL (total 22)
#
# Crawl sub-kategori: Indeks
#   [page=1] +15 URL (total 15)
#   [page=2] +0 URL (total 15)
#   [page=3] +0 URL (total 15)
#   [page=4] +0 URL (total 15)
#
# Crawl sub-kategori: Sadar Stunting
#   [page=1] +9 URL (total 9)
#   [page=2] +0 URL (total 9)
#   [page=3] +0 URL (total 9)
#   [page=4] +0 URL (total 9)
#
# Crawl sub-kategori: Kilas Lifestyle
#   [page=1] +18 URL (total 18)
#   [page=2] +0 URL (total 18)
#   [page=3] +0 URL (total 18)
#   [page=4] +0 URL (total 18)
#
# Total kandidat (URL unik per sub): 243
# Scraping: 100%|██████████| 243/243 [04:24<00:00,  1.09s/url]
# Selesai. Artikel baru tersimpan: 137.
# CSV: /content/drive/MyDrive/KompasLifestyle/kompas_lifestyle_scraped.csv

# %% [markdown]
# # Scraping Travel

# %%
from google.colab import drive
import os

# Tentukan folder dan file output di Drive
DRIVE_FOLDER = "/content/drive/MyDrive/KompasTravel"
os.makedirs(DRIVE_FOLDER, exist_ok=True)

OUTPUT_CSV = os.path.join(DRIVE_FOLDER, "kompas_travel_scraped.csv")
print("Folder Drive:", DRIVE_FOLDER)
print("File output :", OUTPUT_CSV)
# Out:
# Folder Drive: /content/drive/MyDrive/KompasTravel
# File output : /content/drive/MyDrive/KompasTravel/kompas_travel_scraped.csv

# %%
# Scraper Kompas Money (menu-aware + subcategory + tags + resumeable)

import os, re, time, csv, random, json
from urllib.parse import urljoin, urlparse
import requests
from bs4 import BeautifulSoup
from collections import OrderedDict
from tqdm import tqdm

# ==========================
# Konfigurasi umum
# ==========================
BASE = "https://travel.kompas.com/"
REQUEST_DELAY = (0.8, 1.6)
TIMEOUT = 20
MAX_PAGES_PER_SUB = None  # None = lanjut sampai 3 halaman kosong berturut-turut
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
}

# ==========================
# Session HTTP dengan retry
# ==========================
from requests.adapters import HTTPAdapter, Retry

def make_session():
    s = requests.Session()
    retries = Retry(
        total=5, connect=5, read=5,
        backoff_factor=1.2,
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=frozenset(["GET"])
    )
    s.headers.update(HEADERS)
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.mount("http://", HTTPAdapter(max_retries=retries))
    return s

SESSION = make_session()

# ==========================
# CSV helper
# ==========================
FIELDNAMES = ["url", "category", "subcategory", "tanggal_publish", "judul", "tags", "konten"]

def ensure_csv(path):
    if not os.path.exists(path):
        with open(path, "w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=FIELDNAMES)
            writer.writeheader()

def load_done_urls(path):
    done = set()
    if os.path.exists(path):
        with open(path, "r", encoding="utf-8") as f:
            r = csv.DictReader(f)
            for row in r:
                u = (row.get("url") or "").strip()
                if u:
                    done.add(u)
    return done

def append_row(path, row: dict):
    clean = {k: (row.get(k) or "") for k in FIELDNAMES}
    with open(path, "a", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=FIELDNAMES)
        w.writerow(clean)

# ==========================
# Utilities
# ==========================
def normalize_ws(text):
    return re.sub(r"\s+", " ", (text or "").strip())

def looks_like_baca_juga(text):
    return "baca juga" in (text or "").lower()

def safe_get(url):
    r = SESSION.get(url, timeout=TIMEOUT)
    r.raise_for_status()
    return r

def absolutize(base_url, href):
    if href.startswith("//"):
        return "https:" + href
    if href.startswith("/"):
        parsed = urlparse(base_url)
        return f"{parsed.scheme}://{parsed.netloc}{href}"
    return href

# ==========================
# Dapatkan daftar sub-kategori dari menu
# ==========================
def discover_menu_links():
    found = OrderedDict()
    try:
        r = safe_get(BASE)
        soup = BeautifulSoup(r.text, "lxml")
        for a in soup.select(".kanalHeader[data-kanal='travel'] .kanalMenu a[href]"):
            name = normalize_ws(a.get_text())
            href = absolutize(BASE, a.get("href","").strip())
            if not href or not name:
                continue
            found[href] = name
    except Exception:
        pass

    # fallback kalau parsing gagal
    SEED = OrderedDict([
        ("https://travel.kompas.com/travel-news", "Travel News"),
        ("https://travel.kompas.com/travel-ideas", "Travel Ideas"),
        ("https://travel.kompas.com/hotel-story", "Hotel Story"),
        ("https://travel.kompas.com/travelpedia", "Travelpedia"),
    ])
    for href, name in SEED.items():
        found.setdefault(href, name)

    return list(found.items())

# ==========================
# Ambil daftar URL artikel per subcategory
# ==========================
def is_article_url(href: str):
    if not href or "kompas.com" not in href:
        return False
    if "/read/" not in href:
        return False
    if any(b in href for b in ["/komentar/", "/copy/"]):
        return False
    return True

def collect_urls_from_list(listing_url):
    try:
        res = safe_get(listing_url)
    except Exception:
        return set()
    soup = BeautifulSoup(res.text, "lxml")
    urls = set()
    for a in soup.select("a[href*='/read/']"):
        href = a.get("href")
        if not href:
            continue
        full = absolutize(listing_url, href)
        if is_article_url(full):
            urls.add(full)
    return urls

def page_url(base, page):
    if page <= 1:
        return base
    parsed = urlparse(base)
    joiner = "&" if parsed.query else "?"
    return f"{base}{joiner}page={page}"

def crawl_subcategory_urls(sub_url, max_pages=None):
    discovered = OrderedDict()
    consecutive_empty = 0
    page = 1
    while True:
        if max_pages is not None and page > max_pages:
            break
        url = page_url(sub_url, page)
        urls = collect_urls_from_list(url)
        before = len(discovered)
        for u in sorted(urls):
            discovered.setdefault(u, None)
        gained = len(discovered) - before
        print(f"  [page={page}] +{gained} URL (total {len(discovered)})")
        time.sleep(random.uniform(*REQUEST_DELAY))
        consecutive_empty = consecutive_empty + 1 if gained == 0 else 0
        if consecutive_empty >= 3:
            break
        page += 1
    return list(discovered.keys())

# ==========================
# Parsing artikel
# ==========================
def extract_publish_date(soup):
    meta = soup.find("meta", attrs={"name": "content_PublishedDate"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    meta2 = soup.select_one('meta[property="article:published_time"]')
    if meta2 and meta2.get("content"):
        return meta2["content"].strip()
    return ""

def extract_tags(soup):
    meta = soup.find("meta", attrs={"name": "content_tags"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    tag_links = soup.select("a.tag__article__link, .tag__item a")
    if tag_links:
        tags = [normalize_ws(a.get_text()) for a in tag_links if a.get_text().strip()]
        return ", ".join(tags)
    return ""

def parse_article(url):
    res = safe_get(url)
    soup = BeautifulSoup(res.text, "lxml")
    title_el = soup.select_one("h1.read__title") or soup.select_one("h1.article__title") or soup.select_one("h1")
    judul = normalize_ws(title_el.get_text()) if title_el else normalize_ws(soup.title.get_text() if soup.title else "")
    tanggal_publish = extract_publish_date(soup)
    tags = extract_tags(soup)
    wrapper = soup.select_one(".read__content") or soup.select_one(".article__content") or soup
    ps = wrapper.find_all("p")
    paragraphs = []
    for p in ps:
        txt = p.get_text(" ").strip()
        if not txt:
            continue
        if looks_like_baca_juga(txt):
            continue
        if "KOMPAS.com" in txt and "Download" in txt:
            continue
        paragraphs.append(normalize_ws(txt))
    konten = " ".join(paragraphs)
    return {"judul": judul, "tanggal_publish": tanggal_publish, "tags": tags, "konten": konten}

# ==========================
# Pipeline utama
# ==========================
def run_scrape_travel(output_csv_path, max_pages_per_sub=None):
    ensure_csv(output_csv_path)
    done = load_done_urls(output_csv_path)
    print(f"URL sudah ada di CSV: {len(done)}")

    submenus = discover_menu_links()
    print("Sub-kategori terdeteksi:")
    for href, name in submenus:
        print(f" - {name}: {href}")

    all_urls = OrderedDict()
    for href, name in submenus:
        print(f"\nCrawl sub-kategori: {name}")
        urls = crawl_subcategory_urls(href, max_pages=max_pages_per_sub)
        for u in urls:
            all_urls.setdefault((u, name), None)

    print(f"\nTotal kandidat (URL unik per sub): {len(all_urls)}")

    category = "Travel"
    saved = 0
    for i, ((url, subcat), _) in enumerate(tqdm(all_urls.items(), desc="Scraping", unit="url"), 1):
        if url in done:
            continue
        try:
            data = parse_article(url)
            if not data or not data.get("judul") or not data.get("konten"):
                continue
            row = {
                "url": url,
                "category": category,
                "subcategory": subcat,
                "tanggal_publish": data["tanggal_publish"],
                "judul": data["judul"],
                "tags": data["tags"],
                "konten": data["konten"]
            }
            append_row(output_csv_path, row)
            done.add(url)
            saved += 1
        except KeyboardInterrupt:
            print("\n⛔ Dihentikan manual, progres tersimpan.")
            break
        except Exception as e:
            print(f"\nERROR [{i}] {url} -> {e.__class__.__name__}: {e}")
        finally:
            time.sleep(random.uniform(*REQUEST_DELAY))

    print(f"Selesai. Artikel baru tersimpan: {saved}.")
    print("CSV:", output_csv_path)

# ==========================
# Jalankan
# ==========================
run_scrape_travel(OUTPUT_CSV, max_pages_per_sub=MAX_PAGES_PER_SUB)
# Out:
# URL sudah ada di CSV: 0
# Sub-kategori terdeteksi:
#  - Travel News: https://travel.kompas.com/travel-news
#  - Travel Ideas: https://travel.kompas.com/travel-ideas
#  - Hotel Story: https://travel.kompas.com/hotel-story
#  - Travelpedia: https://travel.kompas.com/travelpedia
#  - Food: https://www.kompas.com/food
#  - Ohayo Jepang: https://ohayojepang.kompas.com/
#  - Indeks: https://indeks.kompas.com/?site=travel
#
# Crawl sub-kategori: Travel News
#   [page=1] +47 URL (total 47)
#   [page=2] +20 URL (total 67)
#   [page=3] +19 URL (total 86)
#   [page=4] +20 URL (total 106)
#   [page=5] +20 URL (total 126)
#   [page=6] +20 URL (total 146)
#   [page=7] +20 URL (total 166)
#   [page=8] +19 URL (total 185)
#   [page=9] +20 URL (total 205)
#   [page=10] +12 URL (total 217)
#   [page=11] +0 URL (total 217)
#   [page=12] +0 URL (total 217)
#   [page=13] +0 URL (total 217)
#
# Crawl sub-kategori: Travel Ideas
#   [page=1] +51 URL (total 51)
#   [page=2] +17 URL (total 68)
#   [page=3] +19 URL (total 87)
#   [page=4] +20 URL (total 107)
#   [page=5] +20 URL (total 127)
#   [page=6] +20 URL (total 147)
#   [page=7] +20 URL (total 167)
#   [page=8] +20 URL (total 187)
#   [page=9] +20 URL (total 207)
#   [page=10] +12 URL (total 219)
#   [page=11] +0 URL (total 219)
#   [page=12] +0 URL (total 219)
#   [page=13] +0 URL (total 219)
#
# Crawl sub-kategori: Hotel Story
#   [page=1] +48 URL (total 48)
#   [page=2] +20 URL (total 68)
#   [page=3] +19 URL (total 87)
#   [page=4] +20 URL (total 107)
#   [page=5] +20 URL (total 127)
#   [page=6] +20 URL (total 147)
#   [page=7] +20 URL (total 167)
#   [page=8] +20 URL (total 187)
#   [page=9] +20 URL (total 207)
#   [page=10] +12 URL (total 219)
#   [page=11] +0 URL (total 219)
#   [page=12] +0 URL (total 219)
#   [page=13] +0 URL (total 219)
#
# Crawl sub-kategori: Travelpedia
#   [page=1] +47 URL (total 47)
#   [page=2] +19 URL (total 66)
#   [page=3] +20 URL (total 86)
#   [page=4] +19 URL (total 105)
#   [page=5] +19 URL (total 124)
#   [page=6] +20 URL (total 144)
#   [page=7] +19 URL (total 163)
#   [page=8] +20 URL (total 183)
#   [page=9] +19 URL (total 202)
#   [page=10] +12 URL (total 214)
#   [page=11] +0 URL (total 214)
#   [page=12] +0 URL (total 214)
#   [page=13] +0 URL (total 214)
#
# Crawl sub-kategori: Food
#   [page=1] +38 URL (total 38)
#   [page=2] +15 URL (total 53)
#   [page=3] +14 URL (total 67)
#   [page=4] +20 URL (total 87)
#   [page=5] +18 URL (total 105)
#   [page=6] +20 URL (total 125)
#   [page=7] +20 URL (total 145)
#   [page=8] +20 URL (total 165)
#   [page=9] +20 URL (total 185)
#   [page=10] +20 URL (total 205)
#   [page=11] +0 URL (total 205)
#   [page=12] +0 URL (total 205)
#   [page=13] +0 URL (total 205)
#
# Crawl sub-kategori: Ohayo Jepang
#   [page=1] +39 URL (total 39)
#   [page=2] +0 URL (total 39)
#   [page=3] +0 URL (total 39)
#   [page=4] +0 URL (total 39)
#
# Crawl sub-kategori: Indeks
#   [page=1] +4 URL (total 4)
#   [page=2] +0 URL (total 4)
#   [page=3] +0 URL (total 4)
#   [page=4] +0 URL (total 4)
#
# Total kandidat (URL unik per sub): 1117
# Scraping: 100%|██████████| 1117/1117 [35:29<00:00,  1.91s/url]
# Selesai. Artikel baru tersimpan: 1042.
# CSV: /content/drive/MyDrive/KompasTravel/kompas_travel_scraped.csv

# %% [markdown]
# # Scraping Sains

# %%
from google.colab import drive
import os

# Tentukan folder dan file output di Drive
DRIVE_FOLDER = "/content/drive/MyDrive/KompasSains"
os.makedirs(DRIVE_FOLDER, exist_ok=True)

OUTPUT_CSV = os.path.join(DRIVE_FOLDER, "kompas_sains_scraped.csv")
print("Folder Drive:", DRIVE_FOLDER)
print("File output :", OUTPUT_CSV)
# Out:
# Folder Drive: /content/drive/MyDrive/KompasSains
# File output : /content/drive/MyDrive/KompasSains/kompas_sains_scraped.csv

# %%
# Scraper Kompas Money (menu-aware + subcategory + tags + resumeable)

import os, re, time, csv, random, json
from urllib.parse import urljoin, urlparse
import requests
from bs4 import BeautifulSoup
from collections import OrderedDict
from tqdm import tqdm

# ==========================
# Konfigurasi umum
# ==========================
BASE = "https://www.kompas.com/sains"
REQUEST_DELAY = (0.8, 1.6)
TIMEOUT = 20
MAX_PAGES_PER_SUB = None  # None = lanjut sampai 3 halaman kosong berturut-turut
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
}

# ==========================
# Session HTTP dengan retry
# ==========================
from requests.adapters import HTTPAdapter, Retry

def make_session():
    s = requests.Session()
    retries = Retry(
        total=5, connect=5, read=5,
        backoff_factor=1.2,
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=frozenset(["GET"])
    )
    s.headers.update(HEADERS)
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.mount("http://", HTTPAdapter(max_retries=retries))
    return s

SESSION = make_session()

# ==========================
# CSV helper
# ==========================
FIELDNAMES = ["url", "category", "subcategory", "tanggal_publish", "judul", "tags", "konten"]

def ensure_csv(path):
    if not os.path.exists(path):
        with open(path, "w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=FIELDNAMES)
            writer.writeheader()

def load_done_urls(path):
    done = set()
    if os.path.exists(path):
        with open(path, "r", encoding="utf-8") as f:
            r = csv.DictReader(f)
            for row in r:
                u = (row.get("url") or "").strip()
                if u:
                    done.add(u)
    return done

def append_row(path, row: dict):
    clean = {k: (row.get(k) or "") for k in FIELDNAMES}
    with open(path, "a", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=FIELDNAMES)
        w.writerow(clean)

# ==========================
# Utilities
# ==========================
def normalize_ws(text):
    return re.sub(r"\s+", " ", (text or "").strip())

def looks_like_baca_juga(text):
    return "baca juga" in (text or "").lower()

def safe_get(url):
    r = SESSION.get(url, timeout=TIMEOUT)
    r.raise_for_status()
    return r

def absolutize(base_url, href):
    if href.startswith("//"):
        return "https:" + href
    if href.startswith("/"):
        parsed = urlparse(base_url)
        return f"{parsed.scheme}://{parsed.netloc}{href}"
    return href

# ==========================
# Dapatkan daftar sub-kategori dari menu
# ==========================
def discover_menu_links():
    found = OrderedDict()
    try:
        r = safe_get(BASE)
        soup = BeautifulSoup(r.text, "lxml")
        for a in soup.select(".kanalHeader[data-kanal='sains'] .kanalMenu a[href]"):
            name = normalize_ws(a.get_text())
            href = absolutize(BASE, a.get("href","").strip())
            if not href or not name:
                continue
            found[href] = name
    except Exception:
        pass

    # fallback kalau parsing gagal
    SEED = OrderedDict([
        ("https://www.kompas.com/sains/fenomena", "Fenomena"),
        ("https://www.kompas.com/sains/kita", "Kita"),
        ("https://www.kompas.com/sains/oh-begitu", "Oh Begitu"),
        ("https://www.kompas.com/sains/halo-prof", "Halo Prof"),
        ("https://www.kompas.com/sains/baru-jadi-ortu", "Baru Jadi Ortu"),
        ("https://www.kompas.com/sains/prof-cilik", "Halo Prof"),
    ])
    for href, name in SEED.items():
        found.setdefault(href, name)

    return list(found.items())

# ==========================
# Ambil daftar URL artikel per subcategory
# ==========================
def is_article_url(href: str):
    if not href or "kompas.com" not in href:
        return False
    if "/read/" not in href:
        return False
    if any(b in href for b in ["/komentar/", "/copy/"]):
        return False
    return True

def collect_urls_from_list(listing_url):
    try:
        res = safe_get(listing_url)
    except Exception:
        return set()
    soup = BeautifulSoup(res.text, "lxml")
    urls = set()
    for a in soup.select("a[href*='/read/']"):
        href = a.get("href")
        if not href:
            continue
        full = absolutize(listing_url, href)
        if is_article_url(full):
            urls.add(full)
    return urls

def page_url(base, page):
    if page <= 1:
        return base
    parsed = urlparse(base)
    joiner = "&" if parsed.query else "?"
    return f"{base}{joiner}page={page}"

def crawl_subcategory_urls(sub_url, max_pages=None):
    discovered = OrderedDict()
    consecutive_empty = 0
    page = 1
    while True:
        if max_pages is not None and page > max_pages:
            break
        url = page_url(sub_url, page)
        urls = collect_urls_from_list(url)
        before = len(discovered)
        for u in sorted(urls):
            discovered.setdefault(u, None)
        gained = len(discovered) - before
        print(f"  [page={page}] +{gained} URL (total {len(discovered)})")
        time.sleep(random.uniform(*REQUEST_DELAY))
        consecutive_empty = consecutive_empty + 1 if gained == 0 else 0
        if consecutive_empty >= 3:
            break
        page += 1
    return list(discovered.keys())

# ==========================
# Parsing artikel
# ==========================
def extract_publish_date(soup):
    meta = soup.find("meta", attrs={"name": "content_PublishedDate"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    meta2 = soup.select_one('meta[property="article:published_time"]')
    if meta2 and meta2.get("content"):
        return meta2["content"].strip()
    return ""

def extract_tags(soup):
    meta = soup.find("meta", attrs={"name": "content_tags"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    tag_links = soup.select("a.tag__article__link, .tag__item a")
    if tag_links:
        tags = [normalize_ws(a.get_text()) for a in tag_links if a.get_text().strip()]
        return ", ".join(tags)
    return ""

def parse_article(url):
    res = safe_get(url)
    soup = BeautifulSoup(res.text, "lxml")
    title_el = soup.select_one("h1.read__title") or soup.select_one("h1.article__title") or soup.select_one("h1")
    judul = normalize_ws(title_el.get_text()) if title_el else normalize_ws(soup.title.get_text() if soup.title else "")
    tanggal_publish = extract_publish_date(soup)
    tags = extract_tags(soup)
    wrapper = soup.select_one(".read__content") or soup.select_one(".article__content") or soup
    ps = wrapper.find_all("p")
    paragraphs = []
    for p in ps:
        txt = p.get_text(" ").strip()
        if not txt:
            continue
        if looks_like_baca_juga(txt):
            continue
        if "KOMPAS.com" in txt and "Download" in txt:
            continue
        paragraphs.append(normalize_ws(txt))
    konten = " ".join(paragraphs)
    return {"judul": judul, "tanggal_publish": tanggal_publish, "tags": tags, "konten": konten}

# ==========================
# Pipeline utama
# ==========================
def run_scrape_sains(output_csv_path, max_pages_per_sub=None):
    ensure_csv(output_csv_path)
    done = load_done_urls(output_csv_path)
    print(f"URL sudah ada di CSV: {len(done)}")

    submenus = discover_menu_links()
    print("Sub-kategori terdeteksi:")
    for href, name in submenus:
        print(f" - {name}: {href}")

    all_urls = OrderedDict()
    for href, name in submenus:
        print(f"\nCrawl sub-kategori: {name}")
        urls = crawl_subcategory_urls(href, max_pages=max_pages_per_sub)
        for u in urls:
            all_urls.setdefault((u, name), None)

    print(f"\nTotal kandidat (URL unik per sub): {len(all_urls)}")

    category = "Sains"
    saved = 0
    for i, ((url, subcat), _) in enumerate(tqdm(all_urls.items(), desc="Scraping", unit="url"), 1):
        if url in done:
            continue
        try:
            data = parse_article(url)
            if not data or not data.get("judul") or not data.get("konten"):
                continue
            row = {
                "url": url,
                "category": category,
                "subcategory": subcat,
                "tanggal_publish": data["tanggal_publish"],
                "judul": data["judul"],
                "tags": data["tags"],
                "konten": data["konten"]
            }
            append_row(output_csv_path, row)
            done.add(url)
            saved += 1
        except KeyboardInterrupt:
            print("\n⛔ Dihentikan manual, progres tersimpan.")
            break
        except Exception as e:
            print(f"\nERROR [{i}] {url} -> {e.__class__.__name__}: {e}")
        finally:
            time.sleep(random.uniform(*REQUEST_DELAY))

    print(f"Selesai. Artikel baru tersimpan: {saved}.")
    print("CSV:", output_csv_path)

# ==========================
# Jalankan
# ==========================
run_scrape_sains(OUTPUT_CSV, max_pages_per_sub=MAX_PAGES_PER_SUB)
# Out:
# URL sudah ada di CSV: 0
# Sub-kategori terdeteksi:
#  - Fenomena: https://www.kompas.com/sains/fenomena
#  - Kita: https://www.kompas.com/sains/kita
#  - Oh Begitu: https://www.kompas.com/sains/oh-begitu
#  - Halo Prof: https://www.kompas.com/sains/halo-prof
#  - Baru Jadi Ortu: https://www.kompas.com/sains/baru-jadi-ortu
#  - Prof Cilik: https://www.kompas.com/sains/prof-cilik
#  - Indeks: https://www.kompas.com/sains/indeks
#
# Crawl sub-kategori: Fenomena
#   [page=1] +32 URL (total 32)
#   [page=2] +0 URL (total 32)
#   [page=3] +0 URL (total 32)
#   [page=4] +0 URL (total 32)
#
# Crawl sub-kategori: Kita
#   [page=1] +36 URL (total 36)
#   [page=2] +0 URL (total 36)
#   [page=3] +0 URL (total 36)
#   [page=4] +0 URL (total 36)
#
# Crawl sub-kategori: Oh Begitu
#   [page=1] +35 URL (total 35)
#   [page=2] +0 URL (total 35)
#   [page=3] +0 URL (total 35)
#   [page=4] +0 URL (total 35)
#
# Crawl sub-kategori: Halo Prof
#   [page=1] +36 URL (total 36)
#   [page=2] +0 URL (total 36)
#   [page=3] +0 URL (total 36)
#   [page=4] +0 URL (total 36)
#
# Crawl sub-kategori: Baru Jadi Ortu
#   [page=1] +36 URL (total 36)
#   [page=2] +0 URL (total 36)
#   [page=3] +0 URL (total 36)
#   [page=4] +0 URL (total 36)
#
# Crawl sub-kategori: Prof Cilik
#   [page=1] +36 URL (total 36)
#   [page=2] +0 URL (total 36)
#   [page=3] +0 URL (total 36)
#   [page=4] +0 URL (total 36)
#
# Crawl sub-kategori: Indeks
#   [page=1] +21 URL (total 21)
#   [page=2] +0 URL (total 21)
#   [page=3] +0 URL (total 21)
#   [page=4] +0 URL (total 21)
#
# Total kandidat (URL unik per sub): 232
# Scraping: 100%|██████████| 232/232 [03:54<00:00,  1.01s/url]
# Selesai. Artikel baru tersimpan: 131.
# CSV: /content/drive/MyDrive/KompasSains/kompas_sains_scraped.csv

# %% [markdown]
# # Scraping Bola

# %%
from google.colab import drive
import os

# Tentukan folder dan file output di Drive
DRIVE_FOLDER = "/content/drive/MyDrive/KompasBola"
os.makedirs(DRIVE_FOLDER, exist_ok=True)

OUTPUT_CSV = os.path.join(DRIVE_FOLDER, "kompas_bola_scraped.csv")
print("Folder Drive:", DRIVE_FOLDER)
print("File output :", OUTPUT_CSV)
# Out:
# Folder Drive: /content/drive/MyDrive/KompasBola
# File output : /content/drive/MyDrive/KompasBola/kompas_bola_scraped.csv

# %%
# Scraper Kompas Money (menu-aware + subcategory + tags + resumeable)

import os, re, time, csv, random, json
from urllib.parse import urljoin, urlparse
import requests
from bs4 import BeautifulSoup
from collections import OrderedDict
from tqdm import tqdm

# ==========================
# Konfigurasi umum
# ==========================
BASE = "https://bola.kompas.com/"
REQUEST_DELAY = (0.8, 1.6)
TIMEOUT = 20
MAX_PAGES_PER_SUB = None  # None = lanjut sampai 3 halaman kosong berturut-turut
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
}

# ==========================
# Session HTTP dengan retry
# ==========================
from requests.adapters import HTTPAdapter, Retry

def make_session():
    s = requests.Session()
    retries = Retry(
        total=5, connect=5, read=5,
        backoff_factor=1.2,
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=frozenset(["GET"])
    )
    s.headers.update(HEADERS)
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.mount("http://", HTTPAdapter(max_retries=retries))
    return s

SESSION = make_session()

# ==========================
# CSV helper
# ==========================
FIELDNAMES = ["url", "category", "subcategory", "tanggal_publish", "judul", "tags", "konten"]

def ensure_csv(path):
    if not os.path.exists(path):
        with open(path, "w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=FIELDNAMES)
            writer.writeheader()

def load_done_urls(path):
    done = set()
    if os.path.exists(path):
        with open(path, "r", encoding="utf-8") as f:
            r = csv.DictReader(f)
            for row in r:
                u = (row.get("url") or "").strip()
                if u:
                    done.add(u)
    return done

def append_row(path, row: dict):
    clean = {k: (row.get(k) or "") for k in FIELDNAMES}
    with open(path, "a", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=FIELDNAMES)
        w.writerow(clean)

# ==========================
# Utilities
# ==========================
def normalize_ws(text):
    return re.sub(r"\s+", " ", (text or "").strip())

def looks_like_baca_juga(text):
    return "baca juga" in (text or "").lower()

def safe_get(url):
    r = SESSION.get(url, timeout=TIMEOUT)
    r.raise_for_status()
    return r

def absolutize(base_url, href):
    if href.startswith("//"):
        return "https:" + href
    if href.startswith("/"):
        parsed = urlparse(base_url)
        return f"{parsed.scheme}://{parsed.netloc}{href}"
    return href

# ==========================
# Dapatkan daftar sub-kategori dari menu
# ==========================
def discover_menu_links():
    found = OrderedDict()
    try:
        r = safe_get(BASE)
        soup = BeautifulSoup(r.text, "lxml")
        for a in soup.select(".kanalHeader[data-kanal='bola'] .kanalMenu a[href]"):
            name = normalize_ws(a.get_text())
            href = absolutize(BASE, a.get("href","").strip())
            if not href or not name:
                continue
            found[href] = name
    except Exception:
        pass

    #fallback kalau parsing gagal
    SEED = OrderedDict([
        ("https://bola.kompas.com/timnas-indonesia", "Timnas Indonesia"),
        ("https://bola.kompas.com/liga-indonesia", "Liga Indonesia"),
        ("https://bola.kompas.com/liga-inggris", "Liga Inggris"),
        ("https://bola.kompas.com/liga-italia", "Liga Italia"),
        ("https://bola.kompas.com/liga-champions", "Liga Champions"),
        ("https://www.kompas.com/sports", "Sports"),
        ("https://www.kompas.com/motogp", "Motogp"),
        ("https://www.kompas.com/badminton", "Badminton"),
    ])
    for href, name in SEED.items():
        found.setdefault(href, name)

    return list(found.items())

# ==========================
# Ambil daftar URL artikel per subcategory
# ==========================
def is_article_url(href: str):
    if not href or "kompas.com" not in href:
        return False
    if "/read/" not in href:
        return False
    if any(b in href for b in ["/komentar/", "/copy/"]):
        return False
    return True

def collect_urls_from_list(listing_url):
    try:
        res = safe_get(listing_url)
    except Exception:
        return set()
    soup = BeautifulSoup(res.text, "lxml")
    urls = set()
    for a in soup.select("a[href*='/read/']"):
        href = a.get("href")
        if not href:
            continue
        full = absolutize(listing_url, href)
        if is_article_url(full):
            urls.add(full)
    return urls

def page_url(base, page):
    if page <= 1:
        return base
    parsed = urlparse(base)
    joiner = "&" if parsed.query else "?"
    return f"{base}{joiner}page={page}"

def crawl_subcategory_urls(sub_url, max_pages=None):
    discovered = OrderedDict()
    consecutive_empty = 0
    page = 1
    while True:
        if max_pages is not None and page > max_pages:
            break
        url = page_url(sub_url, page)
        urls = collect_urls_from_list(url)
        before = len(discovered)
        for u in sorted(urls):
            discovered.setdefault(u, None)
        gained = len(discovered) - before
        print(f"  [page={page}] +{gained} URL (total {len(discovered)})")
        time.sleep(random.uniform(*REQUEST_DELAY))
        consecutive_empty = consecutive_empty + 1 if gained == 0 else 0
        if consecutive_empty >= 3:
            break
        page += 1
    return list(discovered.keys())

# ==========================
# Parsing artikel
# ==========================
def extract_publish_date(soup):
    meta = soup.find("meta", attrs={"name": "content_PublishedDate"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    meta2 = soup.select_one('meta[property="article:published_time"]')
    if meta2 and meta2.get("content"):
        return meta2["content"].strip()
    return ""

def extract_tags(soup):
    meta = soup.find("meta", attrs={"name": "content_tags"})
    if meta and meta.get("content"):
        return meta["content"].strip()
    tag_links = soup.select("a.tag__article__link, .tag__item a")
    if tag_links:
        tags = [normalize_ws(a.get_text()) for a in tag_links if a.get_text().strip()]
        return ", ".join(tags)
    return ""

def parse_article(url):
    res = safe_get(url)
    soup = BeautifulSoup(res.text, "lxml")
    title_el = soup.select_one("h1.read__title") or soup.select_one("h1.article__title") or soup.select_one("h1")
    judul = normalize_ws(title_el.get_text()) if title_el else normalize_ws(soup.title.get_text() if soup.title else "")
    tanggal_publish = extract_publish_date(soup)
    tags = extract_tags(soup)
    wrapper = soup.select_one(".read__content") or soup.select_one(".article__content") or soup
    ps = wrapper.find_all("p")
    paragraphs = []
    for p in ps:
        txt = p.get_text(" ").strip()
        if not txt:
            continue
        if looks_like_baca_juga(txt):
            continue
        if "KOMPAS.com" in txt and "Download" in txt:
            continue
        paragraphs.append(normalize_ws(txt))
    konten = " ".join(paragraphs)
    return {"judul": judul, "tanggal_publish": tanggal_publish, "tags": tags, "konten": konten}

# ==========================
# Pipeline utama
# ==========================
def run_scrape_bola(output_csv_path, max_pages_per_sub=None):
    ensure_csv(output_csv_path)
    done = load_done_urls(output_csv_path)
    print(f"URL sudah ada di CSV: {len(done)}")

    submenus = discover_menu_links()
    print("Sub-kategori terdeteksi:")
    for href, name in submenus:
        print(f" - {name}: {href}")

    all_urls = OrderedDict()
    for href, name in submenus:
        print(f"\nCrawl sub-kategori: {name}")
        urls = crawl_subcategory_urls(href, max_pages=max_pages_per_sub)
        for u in urls:
            all_urls.setdefault((u, name), None)

    print(f"\nTotal kandidat (URL unik per sub): {len(all_urls)}")

    category = "Bola"
    saved = 0
    for i, ((url, subcat), _) in enumerate(tqdm(all_urls.items(), desc="Scraping", unit="url"), 1):
        if url in done:
            continue
        try:
            data = parse_article(url)
            if not data or not data.get("judul") or not data.get("konten"):
                continue
            row = {
                "url": url,
                "category": category,
                "subcategory": subcat,
                "tanggal_publish": data["tanggal_publish"],
                "judul": data["judul"],
                "tags": data["tags"],
                "konten": data["konten"]
            }
            append_row(output_csv_path, row)
            done.add(url)
            saved += 1
        except KeyboardInterrupt:
            print("\n⛔ Dihentikan manual, progres tersimpan.")
            break
        except Exception as e:
            print(f"\nERROR [{i}] {url} -> {e.__class__.__name__}: {e}")
        finally:
            time.sleep(random.uniform(*REQUEST_DELAY))

    print(f"Selesai. Artikel baru tersimpan: {saved}.")
    print("CSV:", output_csv_path)

# ==========================
# Jalankan
# ==========================
run_scrape_bola(OUTPUT_CSV, max_pages_per_sub=MAX_PAGES_PER_SUB)
# Out:
# URL sudah ada di CSV: 0
# Sub-kategori terdeteksi:
#  - Timnas Indonesia: https://bola.kompas.com/timnas-indonesia
#  - Liga Indonesia: https://bola.kompas.com/liga-indonesia
#  - Liga Inggris: https://bola.kompas.com/liga-inggris
#  - Liga Italia: https://bola.kompas.com/liga-italia
#  - Liga Champions: https://bola.kompas.com/liga-champions
#  - Klasemen: https://bola.kompas.com/klasemen
#  - Liga Indonesia: https://bola.kompas.com/klasemen/liga-indonesia
#  - Liga Inggris: https://bola.kompas.com/klasemen/liga-inggris
#  - Liga Italia: https://bola.kompas.com/klasemen/liga-italia
#  - Liga Champions: https://bola.kompas.com/klasemen/liga-champions
#  - Sports: https://www.kompas.com/sports
#  - Motogp: https://www.kompas.com/motogp
#  - Badminton: https://www.kompas.com/badminton
#  - Indeks: https://indeks.kompas.com/?site=bola
#
# Crawl sub-kategori: Timnas Indonesia
#   [page=1] +30 URL (total 30)
#   [page=2] +0 URL (total 30)
#   [page=3] +0 URL (total 30)
#   [page=4] +0 URL (total 30)
#
# Crawl sub-kategori: Liga Indonesia
#   [page=1] +41 URL (total 41)
#   [page=2] +0 URL (total 41)
#   [page=3] +0 URL (total 41)
#   [page=4] +0 URL (total 41)
#
# Crawl sub-kategori: Liga Inggris
#   [page=1] +41 URL (total 41)
#   [page=2] +0 URL (total 41)
#   [page=3] +0 URL (total 41)
#   [page=4] +0 URL (total 41)
#
# Crawl sub-kategori: Liga Italia
#   [page=1] +41 URL (total 41)
#   [page=2] +0 URL (total 41)
#   [page=3] +0 URL (total 41)
#   [page=4] +0 URL (total 41)
#
# Crawl sub-kategori: Liga Champions
#   [page=1] +41 URL (total 41)
#   [page=2] +0 URL (total 41)
#   [page=3] +0 URL (total 41)
#   [page=4] +0 URL (total 41)
#
# Crawl sub-kategori: Klasemen
#   [page=1] +36 URL (total 36)
#   [page=2] +0 URL (total 36)
#   [page=3] +0 URL (total 36)
#   [page=4] +0 URL (total 36)
#
# Crawl sub-kategori: Liga Indonesia
#   [page=1] +36 URL (total 36)
#   [page=2] +0 URL (total 36)
#   [page=3] +0 URL (total 36)
#   [page=4] +0 URL (total 36)
#
# Crawl sub-kategori: Liga Inggris
#   [page=1] +36 URL (total 36)
#   [page=2] +0 URL (total 36)
#   [page=3] +0 URL (total 36)
#   [page=4] +0 URL (total 36)
#
# Crawl sub-kategori: Liga Italia
#   [page=1] +36 URL (total 36)
#   [page=2] +0 URL (total 36)
#   [page=3] +0 URL (total 36)
#   [page=4] +0 URL (total 36)
#
# Crawl sub-kategori: Liga Champions
#   [page=1] +36 URL (total 36)
#   [page=2] +0 URL (total 36)
#   [page=3] +0 URL (total 36)
#   [page=4] +0 URL (total 36)
#
# Crawl sub-kategori: Sports
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Motogp
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Badminton
#   [page=1] +31 URL (total 31)
#   [page=2] +0 URL (total 31)
#   [page=3] +0 URL (total 31)
#   [page=4] +0 URL (total 31)
#
# Crawl sub-kategori: Indeks
#   [page=1] +21 URL (total 21)
#   [page=2] +20 URL (total 41)
#   [page=3] +1 URL (total 42)
#   [page=4] +0 URL (total 42)
#   [page=5] +0 URL (total 42)
#   [page=6] +0 URL (total 42)
#
# Total kandidat (URL unik per sub): 365
# Scraping: 100%|██████████| 365/365 [06:56<00:00,  1.14s/url]
# Selesai. Artikel baru tersimpan: 218.
# CSV: /content/drive/MyDrive/KompasBola/kompas_bola_scraped.csv

# %% [markdown]
# # Preprocessing Money

# %%
import pandas as pd
import re
import os

# %%
file_id = "1nk0y7u_usHXum3HISicsVuCMyqDrAzVT"
url = f"https://drive.google.com/uc?id={file_id}"

df = pd.read_csv(url)
df.head()
# Out:
#                                                  url category subcategory  \
# 0  https://money.kompas.com/read/2019/08/01/12421...    Money       Ekbis
# 1  https://money.kompas.com/read/2025/11/09/08100...    Money       Ekbis
# 2  https://money.kompas.com/read/2025/11/09/22024...    Money       Ekbis
# 3  https://money.kompas.com/read/2025/11/10/06280...    Money       Ekbis
# 4  https://money.kompas.com/read/2025/11/10/06572...    Money       Ekbis
#
#        tanggal_publish                                              judul  \
# 0  2019-08-01 12:42:15  Kompas.com Kembali Jadi Pemenang Kategori Medi...
# 1  2025-11-09 21:53:45  Warren Buffett Siap Pamit, Kas Berkshire Sentu...
# 2  2025-11-09 22:02:45  Emiten Ramai-ramai Lakukan Buyback Saham, Apa ...
# 3  2025-11-10 06:28:00  Soal Redenominasi Rupiah, Pemerintah Perlu Bua...
# 4  2025-11-10 06:57:27  Wall Street Sepekan Ini Diproyeksi Goyang, Inv...
#
#                                                 tags  \
# 0              media online, Kompas.com, Superbrands
# 1  Berkshire Hathaway, warren buffet, kas berkshi...
# 2  pasar modal, aksi korporasi, investasi saham, ...
# 3  redenominasi, uang rupiah, RUU Redenominasi, r...
# 4              Wall Street, bursa saham, pasar saham
#
#                                               konten
# 0  JAKARTA, KOMPAS.com — Superbrands, lembaga arb...
# 1  KOMPAS.com – Saham Berkshire Hathaway naik 4,5...
# 2  JAKARTA, KOMPAS.com — Sejumlah emiten melakuka...
# 3  JAKARTA, KOMPAS.com - Chief Economist Permata ...
# 4  NEW YORK, KOMPAS.com - Bursa saham Amerika Ser...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              354 non-null    object
#  1   category         354 non-null    object
#  2   subcategory      354 non-null    object
#  3   tanggal_publish  354 non-null    object
#  4   judul            354 non-null    object
#  5   tags             354 non-null    object
#  6   konten           354 non-null    object
# dtypes: object(7)
# memory usage: 19.5+ KB

# %%
df.rename(columns={
    'judul': 'judul_berita',
    'konten': 'konten_berita'
}, inplace=True)

# %%
df.columns.tolist()
# Out:
# ['url',
#  'category',
#  'subcategory',
#  'tanggal_publish',
#  'judul_berita',
#  'tags',
#  'konten_berita']

# %% [markdown]
# ## Null Handling

# %%
df['konten_berita'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Perbaiki Penulisan

# %%
def clean_text(text):
    # mengganti newline dengan spasi
    text = text.replace("\n", " ")
    # hapus spasi berlebih
    text = re.sub(r'\s+', ' ', text).strip()
    # spasi setelah tanda baca jika belum ada
    text = re.sub(r'([.,;:!?])(?!\s)', r'\1 ', text)
    # domain
    #text = re.sub(r'\.(?!\s|[a-zA-Z])', r'. ', text)
    # hapus spasi berlebih setelah penambahan
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  JAKARTA, KOMPAS. com — Superbrands, lembaga ar...
# 1  KOMPAS. com – Saham Berkshire Hathaway naik 4,...
# 2  JAKARTA, KOMPAS. com — Sejumlah emiten melakuk...
# 3  JAKARTA, KOMPAS. com - Chief Economist Permata...
# 4  NEW YORK, KOMPAS. com - Bursa saham Amerika Se...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0  Kompas. com Kembali Jadi Pemenang Kategori Med...
# 1  Warren Buffett Siap Pamit, Kas Berkshire Sentu...
# 2  Emiten Ramai-ramai Lakukan Buyback Saham, Apa ...
# 3  Soal Redenominasi Rupiah, Pemerintah Perlu Bua...
# 4  Wall Street Sepekan Ini Diproyeksi Goyang, Inv...

# %% [markdown]
# ## Hapus Atribut Teks Tidak Penting

# %%
import re

def clean_kompas_text(text: str) -> str:
    # ubah kompas. com menjadi kompas.com
    text = re.sub(r'(?i)kompas\s*\.\s*com', 'kompas.com', text)

    # hapus lokasi di awal kalimat seperti "JAKARTA, —", "NEW YORK, -", dll
    text = re.sub(
        r'^[A-ZÀ-Ý][A-ZÀ-Ý\s\(\)\/\-\.]*,\s*[—–-]\s*',
        '',
        text.strip()
    )

    # hapus kompas doc
    text = re.sub(r'(?is)kompas\.com/\s*dok\.[^.]*\.', '', text)

    # hapus kompas.com
    text = re.sub(r'(?i)(?:[A-Za-z]*\s*[-–\\\/]*)?kompas\.com[\\/A-Za-z0-9\-]*', '', text)

    # gabungan
    text = re.sub(r'^[A-Za-z\s]*?[a-z](?=[A-Z])', '', text)

    # hapus baca, baca juga, dan kombinasinya
    #text = re.sub(r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n])', '', text)
    text = re.sub(
    r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n]|$)',
    '',
    text)

    # mention
    text = re.sub(r'\(@[^)]+\)', '', text)
    text = re.sub(r'@\w+', '', text)

    # kredit kompas.com\
    text = re.sub(r'(?i)\bkompas\.com/[\w\s.]+?[a-z](?=\s*[A-Z]{2,}|[A-Z][a-z]*[A-Z])', '', text)

    # hapus .com yang mungkin tersisa
    text = re.sub(r'\b\w*\.com\b', '', text, flags=re.IGNORECASE)

    # tanda baca dan spasi
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)
    text = re.sub(r'([.,!?;:])([^\s"”’])', r'\1 \2', text)
    text = re.sub(r'(?<=\w)\(', r' (', text)
    text = re.sub(r'\(\s+', '(', text)
    text = re.sub(r'\s+\)', ')', text)
    text = re.sub(r'\)(?=[A-Za-z0-9])', r') ', text)
    text = re.sub(r'\s+(")', r'\1', text)
    text = re.sub(r'\.\s*"', '. "', text)

    # tanda baca berulang
    text = re.sub(r'([.,!?;:])(\s*\1)+', r'\1', text)
    text = re.sub(r'([.,!?;:])\s*[.,!?;:]+', r'\1', text)
    text = re.sub(r'"\s*"', '"', text)
    text = re.sub(r'""+', '"', text)

    # non huruf awal karakter
    text = re.sub(r'^[^A-Za-z0-9]+', '', text)

    # spasi ganda
    text = re.sub(r'\s{2,}', ' ', text)

    # trim spasi
    text = text.strip()

    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_kompas_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  Superbrands, lembaga arbiter internasional unt...
# 1  Saham Berkshire Hathaway naik 4, 5 persen pada...
# 2  Sejumlah emiten melakukan aksi korporasi berup...
# 3  Chief Economist Permata Bank, Josua Pardede, m...
# 4  Bursa saham Amerika Serikat (AS) alias Wall St...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_kompas_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0  Kembali Jadi Pemenang Kategori Media Online Te...
# 1  Warren Buffett Siap Pamit, Kas Berkshire Sentu...
# 2  Emiten Ramai-ramai Lakukan Buyback Saham, Apa ...
# 3  Soal Redenominasi Rupiah, Pemerintah Perlu Bua...
# 4  Wall Street Sepekan Ini Diproyeksi Goyang, Inv...

# %%
df["judul_berita"] = df["judul_berita"].apply(
    lambda x: x.strip() + "." if not re.search(r'[.!?…]$', str(x).strip()) else x.strip()
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              354 non-null    object
#  1   category         354 non-null    object
#  2   subcategory      354 non-null    object
#  3   tanggal_publish  354 non-null    object
#  4   judul_berita     354 non-null    object
#  5   tags             354 non-null    object
#  6   konten_berita    354 non-null    object
# dtypes: object(7)
# memory usage: 19.5+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("kompas_money_cleaned.csv", index=False)

# %% [markdown]
# # Preprocessing Tekno

# %%
file_id = "1W7Tp9nhryglg7I0FIEA5nXg2dQSgwvLx"
url = f"https://drive.google.com/uc?id={file_id}"

df = pd.read_csv(url)
df.head()
# Out:
#                                                  url category subcategory  \
# 0  http://tekno.kompas.com/read/2025/10/13/112200...    Tekno   Apps & OS
# 1  http://tekno.kompas.com/read/2025/10/14/160300...    Tekno   Apps & OS
# 2  http://tekno.kompas.com/read/2025/10/26/130300...    Tekno   Apps & OS
# 3  https://money.kompas.com/read/2019/08/01/12421...    Tekno   Apps & OS
# 4  https://tekno.kompas.com/read/2025/06/14/18070...    Tekno   Apps & OS
#
#        tanggal_publish                                              judul  \
# 0  2025-10-13 11:22:00  Menjajal Dyson OnTrac, Headphone Futuristik Ha...
# 1  2025-10-14 16:03:00  Menjajal Samsung Galaxy A17 4G: Kamera Stabil,...
# 2  2025-10-26 13:03:00  Hands-on Samsung Galaxy Tab A11: Tablet Rp 2 J...
# 3  2019-08-01 12:42:15  Kompas.com Kembali Jadi Pemenang Kategori Medi...
# 4  2025-11-04 14:50:47  Mengapa HP Android dan iPhone Wajib Restart Ru...
#
#                                                 tags  \
# 0  musik, headphone, dyson, ANC, Dyson OnTrac, he...
# 1  Samsung, hands on, Samsung Galaxy A17 4G, Harg...
# 2  Samsung, Indonesia, hands on, samsung Galaxy T...
# 3              media online, Kompas.com, Superbrands
# 4                   Samsung, restart, restart iPhone
#
#                                               konten
# 0  Ringkasan artikel: KOMPAS.com - Dyson selama i...
# 1  KOMPAS.com – Samsung resmi meluncurkan Galaxy ...
# 2  Rangkuman berita: KOMPAS.com - Pekan lalu, Sam...
# 3  JAKARTA, KOMPAS.com — Superbrands, lembaga arb...
# 4  KOMPAS.com – Vendor ponsel Samsung menganjurka...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              401 non-null    object
#  1   category         401 non-null    object
#  2   subcategory      401 non-null    object
#  3   tanggal_publish  401 non-null    object
#  4   judul            401 non-null    object
#  5   tags             401 non-null    object
#  6   konten           401 non-null    object
# dtypes: object(7)
# memory usage: 22.1+ KB

# %%
df.rename(columns={
    'judul': 'judul_berita',
    'konten': 'konten_berita'
}, inplace=True)

# %%
df.columns.tolist()
# Out:
# ['url',
#  'category',
#  'subcategory',
#  'tanggal_publish',
#  'judul_berita',
#  'tags',
#  'konten_berita']

# %% [markdown]
# ## Null Handling

# %%
df['konten_berita'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Perbaiki Penulisan

# %%
def clean_text(text):
    # mengganti newline dengan spasi
    text = text.replace("\n", " ")
    # hapus spasi berlebih
    text = re.sub(r'\s+', ' ', text).strip()
    # spasi setelah tanda baca jika belum ada
    text = re.sub(r'([.,;:!?])(?!\s)', r'\1 ', text)
    # domain
    #text = re.sub(r'\.(?!\s|[a-zA-Z])', r'. ', text)
    # hapus spasi berlebih setelah penambahan
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  Ringkasan artikel: KOMPAS. com - Dyson selama ...
# 1  KOMPAS. com – Samsung resmi meluncurkan Galaxy...
# 2  Rangkuman berita: KOMPAS. com - Pekan lalu, Sa...
# 3  JAKARTA, KOMPAS. com — Superbrands, lembaga ar...
# 4  KOMPAS. com – Vendor ponsel Samsung menganjurk...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0  Menjajal Dyson OnTrac, Headphone Futuristik Ha...
# 1  Menjajal Samsung Galaxy A17 4G: Kamera Stabil,...
# 2  Hands-on Samsung Galaxy Tab A11: Tablet Rp 2 J...
# 3  Kompas. com Kembali Jadi Pemenang Kategori Med...
# 4  Mengapa HP Android dan iPhone Wajib Restart Ru...

# %% [markdown]
# ## Hapus Atribut Teks Tidak Penting

# %%
import re

def clean_kompas_text(text: str) -> str:
    # ubah kompas. com menjadi kompas.com
    text = re.sub(r'(?i)kompas\s*\.\s*com', 'kompas.com', text)

    # hapus lokasi di awal kalimat seperti "JAKARTA, —", "NEW YORK, -", dll
    text = re.sub(
    r'^\s*[A-ZÀ-Ý][A-ZÀ-Ý\s\(\)\/\-\.]*,\s*[–—-]?\s*',
    '',
    text.strip()
    )

    # hapus frasa "Ringkasan berita", "Ringkasan artikel", "Rangkuman berita"
    text = re.sub(
    r'(?i)^(ringkasan|rangkuman)\s+(berita|artikel)\s*[:：–—-]\s*',
    '',
    text.strip()
    )

    # hapus kompas doc
    text = re.sub(r'(?is)kompas\.com/\s*dok\.[^.]*\.', '', text)

    # hapus kompas.com
    text = re.sub(r'(?i)(?:[A-Za-z]*\s*[-–\\\/]*)?kompas\.com[\\/A-Za-z0-9\-]*', '', text)

    # gabungan
    text = re.sub(r'^[A-Za-z\s]*?[a-z](?=[A-Z])', '', text)

    # hapus baca, baca juga, dan kombinasinya
    #text = re.sub(r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n])', '', text)
    text = re.sub(
    r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n]|$)',
    '',
    text)

    # mention
    text = re.sub(r'\(@[^)]+\)', '', text)
    text = re.sub(r'@\w+', '', text)

    # kredit kompas.com\
    text = re.sub(r'(?i)\bkompas\.com/[\w\s.]+?[a-z](?=\s*[A-Z]{2,}|[A-Z][a-z]*[A-Z])', '', text)

    # hapus .com yang mungkin tersisa
    text = re.sub(r'\b\w*\.com\b', '', text, flags=re.IGNORECASE)

    # tanda baca dan spasi
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)
    text = re.sub(r'([.,!?;:])([^\s"”’])', r'\1 \2', text)
    text = re.sub(r'(?<=\w)\(', r' (', text)
    text = re.sub(r'\(\s+', '(', text)
    text = re.sub(r'\s+\)', ')', text)
    text = re.sub(r'\)(?=[A-Za-z0-9])', r') ', text)
    text = re.sub(r'\s+(")', r'\1', text)
    text = re.sub(r'\.\s*"', '. "', text)

    # tanda baca berulang
    text = re.sub(r'([.,!?;:])(\s*\1)+', r'\1', text)
    text = re.sub(r'([.,!?;:])\s*[.,!?;:]+', r'\1', text)
    text = re.sub(r'"\s*"', '"', text)
    text = re.sub(r'""+', '"', text)

    # non huruf awal karakter
    text = re.sub(r'^[^A-Za-z0-9]+', '', text)

    # spasi ganda
    text = re.sub(r'\s{2,}', ' ', text)

    # trim spasi
    text = text.strip()

    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_kompas_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  Dyson selama ini dikenal dengan produk-produk ...
# 1  Samsung resmi meluncurkan Galaxy A17 4G di Ind...
# 2  Pekan lalu, Samsung resmi meluncurkan tablet e...
# 3  Superbrands, lembaga arbiter internasional unt...
# 4  Vendor ponsel Samsung menganjurkan pengguna un...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_kompas_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0         Trac, Headphone Futuristik Harga Rp10 Juta
# 1  Menjajal Samsung Galaxy A17 4G: Kamera Stabil,...
# 2  Hands-on Samsung Galaxy Tab A11: Tablet Rp 2 J...
# 3  Kembali Jadi Pemenang Kategori Media Online Te...
# 4                         Phone Wajib Restart Rutin?

# %%
df["judul_berita"] = df["judul_berita"].apply(
    lambda x: x.strip() + "." if not re.search(r'[.!?…]$', str(x).strip()) else x.strip()
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              401 non-null    object
#  1   category         401 non-null    object
#  2   subcategory      401 non-null    object
#  3   tanggal_publish  401 non-null    object
#  4   judul_berita     401 non-null    object
#  5   tags             401 non-null    object
#  6   konten_berita    401 non-null    object
# dtypes: object(7)
# memory usage: 22.1+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("kompas_tekno_cleaned.csv", index=False)

# %% [markdown]
# # Preprocessing Otomotif

# %%
file_id = "1cvmmcIAI6vkInwqIUvu9vyai-g1JiUF4"
url = f"https://drive.google.com/uc?id={file_id}"

df = pd.read_csv(url)
df.head()
# Out:
#                                                  url  category subcategory  \
# 0  https://money.kompas.com/read/2019/08/01/12421...  Otomotif        News
# 1  https://otomotif.kompas.com/read/2025/11/09/20...  Otomotif        News
# 2  https://otomotif.kompas.com/read/2025/11/09/21...  Otomotif        News
# 3  https://otomotif.kompas.com/read/2025/11/10/07...  Otomotif        News
# 4  https://otomotif.kompas.com/read/2025/11/10/08...  Otomotif        News
#
#        tanggal_publish                                              judul  \
# 0  2019-08-01 12:42:15  Kompas.com Kembali Jadi Pemenang Kategori Medi...
# 1  2025-11-09 20:45:28  Hasil MotoGP Portugal 2025: Bezzecchi Juara, M...
# 2  2025-11-09 21:10:40  Klasemen MotoGP 2025 Usai GP Portugal: Duo Már...
# 3  2025-11-10 07:42:00  Pemulihan Lancar, Marc Marquez Segera Kembali ...
# 4  2025-11-10 08:42:00  Tantangan Suzuki Menjual Satria Pro di Tengah ...
#
#                                                 tags  \
# 0              media online, Kompas.com, Superbrands
# 1  MotoGP, balap motor, MotoGP Portugal, motogp 2...
# 2                  MotoGP, klasemen, MotoGP Portugal
# 3              MotoGP, Marc Marquez, Ducati, Marquez
# 4   motor matik, Satria F150, Teuku Agha, Satria Pro
#
#                                               konten
# 0  JAKARTA, KOMPAS.com — Superbrands, lembaga arb...
# 1  JAKARTA, KOMPAS.com - MotoGP Portugal 2025 yan...
# 2  JAKARTA, KOMPAS.com - Marco Bezzecchi tampil g...
# 3  JAKARTA, KOMPAS.com – Manajer, Marc Marquez ya...
# 4  BOGOR, KOMPAS.com - Suzuki Indomobil Sales (SI...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362 entries, 0 to 361
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              362 non-null    object
#  1   category         362 non-null    object
#  2   subcategory      362 non-null    object
#  3   tanggal_publish  354 non-null    object
#  4   judul            362 non-null    object
#  5   tags             362 non-null    object
#  6   konten           362 non-null    object
# dtypes: object(7)
# memory usage: 19.9+ KB

# %%
df.rename(columns={
    'judul': 'judul_berita',
    'konten': 'konten_berita'
}, inplace=True)

# %%
df.columns.tolist()
# Out:
# ['url',
#  'category',
#  'subcategory',
#  'tanggal_publish',
#  'judul_berita',
#  'tags',
#  'konten_berita']

# %% [markdown]
# ## Null Handling

# %%
df['konten_berita'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Perbaiki Penulisan

# %%
def clean_text(text):
    # mengganti newline dengan spasi
    text = text.replace("\n", " ")
    # hapus spasi berlebih
    text = re.sub(r'\s+', ' ', text).strip()
    # spasi setelah tanda baca jika belum ada
    text = re.sub(r'([.,;:!?])(?!\s)', r'\1 ', text)
    # domain
    #text = re.sub(r'\.(?!\s|[a-zA-Z])', r'. ', text)
    # hapus spasi berlebih setelah penambahan
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  JAKARTA, KOMPAS. com — Superbrands, lembaga ar...
# 1  JAKARTA, KOMPAS. com - MotoGP Portugal 2025 ya...
# 2  JAKARTA, KOMPAS. com - Marco Bezzecchi tampil ...
# 3  JAKARTA, KOMPAS. com – Manajer, Marc Marquez y...
# 4  BOGOR, KOMPAS. com - Suzuki Indomobil Sales (S...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0  Kompas. com Kembali Jadi Pemenang Kategori Med...
# 1  Hasil MotoGP Portugal 2025: Bezzecchi Juara, M...
# 2  Klasemen MotoGP 2025 Usai GP Portugal: Duo Már...
# 3  Pemulihan Lancar, Marc Marquez Segera Kembali ...
# 4  Tantangan Suzuki Menjual Satria Pro di Tengah ...

# %% [markdown]
# ## Hapus Atribut Teks Tidak Penting

# %%
import re

def clean_kompas_text(text: str) -> str:
    # ubah "kompas. com" menjadi "kompas.com"
    text = re.sub(r'(?i)\bkompas\s*\.\s*com\b', 'kompas.com', text.strip())

    # hapus jika kompas.com muncul di awal kalimat
    text = re.sub(r'(?i)^\s*kompas\.com[:,\-\s]*', '', text.strip())

    # hapus lokasi di awal kalimat seperti "JAKARTA, —", "NEW YORK, -", dll
    text = re.sub(
    r'^\s*[A-ZÀ-Ý][A-ZÀ-Ý\s\(\)\/\-\.]*,\s*[–—-]?\s*',
    '',
    text.strip()
    )

    # hapus frasa "Ringkasan berita", "Ringkasan artikel", "Rangkuman berita"
    text = re.sub(
    r'(?i)^(ringkasan|rangkuman)\s+(berita|artikel)\s*[:：–—-]\s*',
    '',
    text.strip()
    )

    # hapus kompas doc
    text = re.sub(r'(?is)kompas\.com/\s*dok\.[^.]*\.', '', text)

    # hapus kompas.com
    text = re.sub(r'(?i)(?:[A-Za-z]*\s*[-–\\\/]*)?kompas\.com[\\/A-Za-z0-9\-]*', '', text)

    # gabungan
    text = re.sub(r'^[A-Za-z\s]*?[a-z](?=[A-Z])', '', text)

    # hapus baca, baca juga, dan kombinasinya
    #text = re.sub(r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n])', '', text)
    text = re.sub(
    r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n]|$)',
    '',
    text)

    # mention
    text = re.sub(r'\(@[^)]+\)', '', text)
    text = re.sub(r'@\w+', '', text)

    # kredit kompas.com\
    text = re.sub(r'(?i)\bkompas\.com/[\w\s.]+?[a-z](?=\s*[A-Z]{2,}|[A-Z][a-z]*[A-Z])', '', text)

    # hapus .com yang mungkin tersisa
    text = re.sub(r'\b\w*\.com\b', '', text, flags=re.IGNORECASE)

    # tanda baca dan spasi
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)
    text = re.sub(r'([.,!?;:])([^\s"”’])', r'\1 \2', text)
    text = re.sub(r'(?<=\w)\(', r' (', text)
    text = re.sub(r'\(\s+', '(', text)
    text = re.sub(r'\s+\)', ')', text)
    text = re.sub(r'\)(?=[A-Za-z0-9])', r') ', text)
    text = re.sub(r'\s+(")', r'\1', text)
    text = re.sub(r'\.\s*"', '. "', text)

    # tanda baca berulang
    text = re.sub(r'([.,!?;:])(\s*\1)+', r'\1', text)
    text = re.sub(r'([.,!?;:])\s*[.,!?;:]+', r'\1', text)
    text = re.sub(r'"\s*"', '"', text)
    text = re.sub(r'""+', '"', text)

    # non huruf awal karakter
    text = re.sub(r'^[^A-Za-z0-9]+', '', text)

    # spasi ganda
    text = re.sub(r'\s{2,}', ' ', text)

    # trim spasi
    text = text.strip()

    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_kompas_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  Superbrands, lembaga arbiter internasional unt...
# 1  MotoGP Portugal 2025 yang digelar di Sirkuit A...
# 2  Marco Bezzecchi tampil gemilang di Grand Prix ...
# 3  Manajer, Marc Marquez yaitu Jaime Martinez men...
# 4  Suzuki Indomobil Sales (SIS) resmi meluncurkan...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_kompas_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0  Kembali Jadi Pemenang Kategori Media Online Te...
# 1   GP Portugal 2025: Bezzecchi Juara, Marquez Kedua
# 2  GP 2025 Usai GP Portugal: Duo Márquez di Posis...
# 3  Pemulihan Lancar, Marc Marquez Segera Kembali ...
# 4  Tantangan Suzuki Menjual Satria Pro di Tengah ...

# %%
df["judul_berita"] = df["judul_berita"].apply(
    lambda x: x.strip() + "." if not re.search(r'[.!?…]$', str(x).strip()) else x.strip()
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362 entries, 0 to 361
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              362 non-null    object
#  1   category         362 non-null    object
#  2   subcategory      362 non-null    object
#  3   tanggal_publish  354 non-null    object
#  4   judul_berita     362 non-null    object
#  5   tags             362 non-null    object
#  6   konten_berita    362 non-null    object
# dtypes: object(7)
# memory usage: 19.9+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("kompas_otomotif_cleaned.csv", index=False)

# %% [markdown]
# # Preprocessing Nusaraya

# %%
file_id = "1YLosd1sCRZJAWIvzGfreHMeEXomdpTk7"
url = f"https://drive.google.com/uc?id={file_id}"

df = pd.read_csv(url)
df.head()
# Out:
#                                                  url  category  \
# 0  http://medan.kompas.com/read/2025/11/09/125603...  Nusaraya
# 1  http://medan.kompas.com/read/2025/11/09/193503...  Nusaraya
# 2  http://medan.kompas.com/read/2025/11/09/201230...  Nusaraya
# 3  http://medan.kompas.com/read/2025/11/10/052336...  Nusaraya
# 4  http://medan.kompas.com/read/2025/11/10/053000...  Nusaraya
#
#       subcategory      tanggal_publish  \
# 0  Sumatera Utara  2025-11-09 12:56:03
# 1  Sumatera Utara  2025-11-09 19:35:03
# 2  Sumatera Utara  2025-11-09 20:12:30
# 3  Sumatera Utara   2025-11-10 5:23:36
# 4  Sumatera Utara   2025-11-10 5:30:00
#
#                                                judul  \
# 0  Detik-detik Wanita di Deli Serdang Tewas Usai ...
# 1  Datangi Pusat Pasar Medan, Menteri PU: Bocor S...
# 2  Wanita Penagih Utang di Medan Dikeroyok Keluar...
# 3  Siswa di Nias Lewati Sungai ke Sekolah karena ...
# 4  Firasat Driver Ojol Benar, Tangannya sampai Be...
#
#                                                 tags  \
# 0  kriminal, bunuh diri, Sumatera Utara, pengania...
# 1  Medan, sumut, Menteri PU Dody Hanggodo, pasar ...
# 2  penagih utang medan dikeroyok, video penagih u...
# 3  Menteri PU, pembangunan jembatan, Bupati Nias,...
# 4    Medan, sumut, paket narkotika driver ojol medan
#
#                                               konten
# 0  MEDAN, KOMPAS.com - Seorang perempuan berinisi...
# 1  MEDAN,KOMPAS.com- Menteri Pekerjaan Umum (PU) ...
# 2  MEDAN, KOMPAS.com- Seorang pegawai koperasi di...
# 3  MEDAN, KOMPAS.com - Menteri Pekerjaan Umum (PU...
# 4  MEDAN, KOMPAS.com – Seorang driver ojek online...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3777 entries, 0 to 3776
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              3777 non-null   object
#  1   category         3777 non-null   object
#  2   subcategory      3777 non-null   object
#  3   tanggal_publish  3777 non-null   object
#  4   judul            3777 non-null   object
#  5   tags             3774 non-null   object
#  6   konten           3777 non-null   object
# dtypes: object(7)
# memory usage: 206.7+ KB

# %%
df.rename(columns={
    'judul': 'judul_berita',
    'konten': 'konten_berita'
}, inplace=True)

# %%
df.columns.tolist()
# Out:
# ['url',
#  'category',
#  'subcategory',
#  'tanggal_publish',
#  'judul_berita',
#  'tags',
#  'konten_berita']

# %% [markdown]
# ## Null Handling

# %%
df['konten_berita'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Perbaiki Penulisan

# %%
def clean_text(text):
    # mengganti newline dengan spasi
    text = text.replace("\n", " ")
    # hapus spasi berlebih
    text = re.sub(r'\s+', ' ', text).strip()
    # spasi setelah tanda baca jika belum ada
    text = re.sub(r'([.,;:!?])(?!\s)', r'\1 ', text)
    # domain
    #text = re.sub(r'\.(?!\s|[a-zA-Z])', r'. ', text)
    # hapus spasi berlebih setelah penambahan
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  MEDAN, KOMPAS. com - Seorang perempuan berinis...
# 1  MEDAN, KOMPAS. com- Menteri Pekerjaan Umum (PU...
# 2  MEDAN, KOMPAS. com- Seorang pegawai koperasi d...
# 3  MEDAN, KOMPAS. com - Menteri Pekerjaan Umum (P...
# 4  MEDAN, KOMPAS. com – Seorang driver ojek onlin...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0  Detik-detik Wanita di Deli Serdang Tewas Usai ...
# 1  Datangi Pusat Pasar Medan, Menteri PU: Bocor S...
# 2  Wanita Penagih Utang di Medan Dikeroyok Keluar...
# 3  Siswa di Nias Lewati Sungai ke Sekolah karena ...
# 4  Firasat Driver Ojol Benar, Tangannya sampai Be...

# %% [markdown]
# ## Hapus Atribut Teks Tidak Penting

# %%
import re

def clean_kompas_text(text: str) -> str:
    # ubah kompas. com menjadi kompas.com
    text = re.sub(r'(?i)kompas\s*\.\s*com', 'kompas.com', text)

    # hapus lokasi di awal kalimat seperti "JAKARTA, —", "NEW YORK, -", dll
    text = re.sub(
    r'^\s*[A-ZÀ-Ý][A-ZÀ-Ý\s\(\)\/\-\.]*,\s*[–—-]?\s*',
    '',
    text.strip()
    )

    # hapus frasa "Ringkasan berita", "Ringkasan artikel", "Rangkuman berita"
    text = re.sub(
    r'(?i)^(ringkasan|rangkuman)\s+(berita|artikel)\s*[:：–—-]\s*',
    '',
    text.strip()
    )

    # hapus kompas doc
    text = re.sub(r'(?is)kompas\.com/\s*dok\.[^.]*\.', '', text)

    # hapus kompas.com
    text = re.sub(r'(?i)(?:[A-Za-z]*\s*[-–\\\/]*)?kompas\.com[\\/A-Za-z0-9\-]*', '', text)

    # gabungan
    text = re.sub(r'^[A-Za-z\s]*?[a-z](?=[A-Z])', '', text)

    # hapus baca, baca juga, dan kombinasinya
    #text = re.sub(r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n])', '', text)
    text = re.sub(
    r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n]|$)',
    '',
    text)

    # mention
    text = re.sub(r'\(@[^)]+\)', '', text)
    text = re.sub(r'@\w+', '', text)

    # kredit kompas.com\
    text = re.sub(r'(?i)\bkompas\.com/[\w\s.]+?[a-z](?=\s*[A-Z]{2,}|[A-Z][a-z]*[A-Z])', '', text)

    # hapus .com yang mungkin tersisa
    text = re.sub(r'\b\w*\.com\b', '', text, flags=re.IGNORECASE)

    # tanda baca dan spasi
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)
    text = re.sub(r'([.,!?;:])([^\s"”’])', r'\1 \2', text)
    text = re.sub(r'(?<=\w)\(', r' (', text)
    text = re.sub(r'\(\s+', '(', text)
    text = re.sub(r'\s+\)', ')', text)
    text = re.sub(r'\)(?=[A-Za-z0-9])', r') ', text)
    text = re.sub(r'\s+(")', r'\1', text)
    text = re.sub(r'\.\s*"', '. "', text)

    # tanda baca berulang
    text = re.sub(r'([.,!?;:])(\s*\1)+', r'\1', text)
    text = re.sub(r'([.,!?;:])\s*[.,!?;:]+', r'\1', text)
    text = re.sub(r'"\s*"', '"', text)
    text = re.sub(r'""+', '"', text)

    # non huruf awal karakter
    text = re.sub(r'^[^A-Za-z0-9]+', '', text)

    # spasi ganda
    text = re.sub(r'\s{2,}', ' ', text)

    # trim spasi
    text = text.strip()

    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_kompas_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  Seorang perempuan berinisial AS, tiga puluh li...
# 1  Menteri Pekerjaan Umum (PU) RI Dody Hanggodo m...
# 2  Seorang pegawai koperasi di Medan, Sumatera Ut...
# 3  Menteri Pekerjaan Umum (PU) Doddy Hanggodo mer...
# 4  Seorang driver ojek online berinisial J melapo...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_kompas_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0  Detik-detik Wanita di Deli Serdang Tewas Usai ...
# 1  Datangi Pusat Pasar Medan, Menteri PU: Bocor S...
# 2  Wanita Penagih Utang di Medan Dikeroyok Keluar...
# 3  Siswa di Nias Lewati Sungai ke Sekolah karena ...
# 4  Firasat Driver Ojol Benar, Tangannya sampai Be...

# %%
df["judul_berita"] = df["judul_berita"].apply(
    lambda x: x.strip() + "." if not re.search(r'[.!?…]$', str(x).strip()) else x.strip()
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3777 entries, 0 to 3776
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              3777 non-null   object
#  1   category         3777 non-null   object
#  2   subcategory      3777 non-null   object
#  3   tanggal_publish  3777 non-null   object
#  4   judul_berita     3777 non-null   object
#  5   tags             3774 non-null   object
#  6   konten_berita    3777 non-null   object
# dtypes: object(7)
# memory usage: 206.7+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("kompas_nusaraya_cleaned.csv", index=False)

# %% [markdown]
# # Preprocessing Lifestyle

# %%
file_id = "173bnAoXlH9wWQxcqQUtt17wQVH2dLyRr"
url = f"https://drive.google.com/uc?id={file_id}"

df = pd.read_csv(url)
df.head()
# Out:
#                                                  url   category  \
# 0  https://buku.kompas.com/read/5366/arti-the-sun...  Lifestyle
# 1  https://buku.kompas.com/read/5368/apa-arti-goa...  Lifestyle
# 2  https://buku.kompas.com/read/5435/ciri-cowok-t...  Lifestyle
# 3  https://buku.kompas.com/read/5451/10-olahan-ma...  Lifestyle
# 4  https://buku.kompas.com/read/5462/berani-berge...  Lifestyle
#
#          subcategory      tanggal_publish  \
# 0  Beauty & Grooming  2025-10-22 09:00:00
# 1  Beauty & Grooming  2025-11-05 11:00:00
# 2  Beauty & Grooming  2025-10-21 17:00:00
# 3  Beauty & Grooming  2025-10-21 15:00:00
# 4  Beauty & Grooming  2025-10-22 09:00:00
#
#                                                judul  \
# 0            Arti The Sunset Is Beautiful, Isn’t It?
# 1  Apa Arti GOAT dalam Sepak Bola? Yuk, Cari Tahu...
# 2  Ciri Cowok Temperamental, Penyebab, dan Cara M...
# 3  10 Olahan Makanan dari Sayuran yang Mudah Dimasak
# 4  Berani Bergeser, Berani Memimpin: Menyelami Ga...
#
#                                                 tags  \
# 0  Trivia, The Sunset Is Beautiful,  Isn’t It, Re...
# 1  Trivia, Arti GOAT, Sepak Bola, Rekomendasi Buk...
# 2  Trivia, Cowok Tempramental, Rekomendasi Buku, ...
# 3  Trivia, Olahan Makanan dari Sayuran, Resep Mas...
# 4  Leadershift, Pengembangan Diri, Elex Media Kom...
#
#                                               konten
# 0  Arti " The sunset is beautiful, isn't it?" bel...
# 1  Penggemar sepak bola pasti sudah tidak asing d...
# 2  Pernahkah kamu bertemu seseorang dengan emosi ...
# 3  Olahan makanan dari sayur merupakan pilihan te...
# 4  Kepemimpinan selalu menjadi topik yang tak per...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              137 non-null    object
#  1   category         137 non-null    object
#  2   subcategory      137 non-null    object
#  3   tanggal_publish  137 non-null    object
#  4   judul            137 non-null    object
#  5   tags             128 non-null    object
#  6   konten           137 non-null    object
# dtypes: object(7)
# memory usage: 7.6+ KB

# %%
df.rename(columns={
    'judul': 'judul_berita',
    'konten': 'konten_berita'
}, inplace=True)

# %%
df.columns.tolist()
# Out:
# ['url',
#  'category',
#  'subcategory',
#  'tanggal_publish',
#  'judul_berita',
#  'tags',
#  'konten_berita']

# %% [markdown]
# ## Null Handling

# %%
df['konten_berita'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Perbaiki Penulisan

# %%
def clean_text(text):
    # mengganti newline dengan spasi
    text = text.replace("\n", " ")
    # hapus spasi berlebih
    text = re.sub(r'\s+', ' ', text).strip()
    # spasi setelah tanda baca jika belum ada
    text = re.sub(r'([.,;:!?])(?!\s)', r'\1 ', text)
    # domain
    #text = re.sub(r'\.(?!\s|[a-zA-Z])', r'. ', text)
    # hapus spasi berlebih setelah penambahan
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  Arti " The sunset is beautiful, isn't it? " be...
# 1  Penggemar sepak bola pasti sudah tidak asing d...
# 2  Pernahkah kamu bertemu seseorang dengan emosi ...
# 3  Olahan makanan dari sayur merupakan pilihan te...
# 4  Kepemimpinan selalu menjadi topik yang tak per...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0            Arti The Sunset Is Beautiful, Isn’t It?
# 1  Apa Arti GOAT dalam Sepak Bola? Yuk, Cari Tahu...
# 2  Ciri Cowok Temperamental, Penyebab, dan Cara M...
# 3  10 Olahan Makanan dari Sayuran yang Mudah Dimasak
# 4  Berani Bergeser, Berani Memimpin: Menyelami Ga...

# %% [markdown]
# ## Hapus Atribut Teks Tidak Penting

# %%
import re

def clean_kompas_text(text: str) -> str:
    # ubah kompas. com menjadi kompas.com
    text = re.sub(r'(?i)kompas\s*\.\s*com', 'kompas.com', text)

    # hapus lokasi di awal kalimat seperti "JAKARTA, —", "NEW YORK, -", dll
    text = re.sub(
    r'^\s*[A-ZÀ-Ý][A-ZÀ-Ý\s\(\)\/\-\.]*,\s*[–—-]?\s*',
    '',
    text.strip()
    )

    # hapus frasa "Ringkasan berita", "Ringkasan artikel", "Rangkuman berita"
    text = re.sub(
    r'(?i)^(ringkasan|rangkuman)\s+(berita|artikel)\s*[:：–—-]\s*',
    '',
    text.strip()
    )

    # hapus kompas doc
    text = re.sub(r'(?is)kompas\.com/\s*dok\.[^.]*\.', '', text)

    # hapus kompas.com
    text = re.sub(r'(?i)(?:[A-Za-z]*\s*[-–\\\/]*)?kompas\.com[\\/A-Za-z0-9\-]*', '', text)

    # gabungan
    text = re.sub(r'^[A-Za-z\s]*?[a-z](?=[A-Z])', '', text)

    # hapus baca, baca juga, dan kombinasinya
    #text = re.sub(r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n])', '', text)
    text = re.sub(
    r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n]|$)',
    '',
    text)

    # mention
    text = re.sub(r'\(@[^)]+\)', '', text)
    text = re.sub(r'@\w+', '', text)

    # kredit kompas.com\
    text = re.sub(r'(?i)\bkompas\.com/[\w\s.]+?[a-z](?=\s*[A-Z]{2,}|[A-Z][a-z]*[A-Z])', '', text)

    # hapus .com yang mungkin tersisa
    text = re.sub(r'\b\w*\.com\b', '', text, flags=re.IGNORECASE)

    # tanda baca dan spasi
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)
    text = re.sub(r'([.,!?;:])([^\s"”’])', r'\1 \2', text)
    text = re.sub(r'(?<=\w)\(', r' (', text)
    text = re.sub(r'\(\s+', '(', text)
    text = re.sub(r'\s+\)', ')', text)
    text = re.sub(r'\)(?=[A-Za-z0-9])', r') ', text)
    text = re.sub(r'\s+(")', r'\1', text)
    text = re.sub(r'\.\s*"', '. "', text)

    # tanda baca berulang
    text = re.sub(r'([.,!?;:])(\s*\1)+', r'\1', text)
    text = re.sub(r'([.,!?;:])\s*[.,!?;:]+', r'\1', text)
    text = re.sub(r'"\s*"', '"', text)
    text = re.sub(r'""+', '"', text)

    # non huruf awal karakter
    text = re.sub(r'^[^A-Za-z0-9]+', '', text)

    # spasi ganda
    text = re.sub(r'\s{2,}', ' ', text)

    # trim spasi
    text = text.strip()

    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_kompas_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  Arti" The sunset is beautiful, isn't it?" bela...
# 1  Penggemar sepak bola pasti sudah tidak asing d...
# 2  Pernahkah kamu bertemu seseorang dengan emosi ...
# 3  Olahan makanan dari sayur merupakan pilihan te...
# 4  Kepemimpinan selalu menjadi topik yang tak per...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_kompas_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0            Arti The Sunset Is Beautiful, Isn’t It?
# 1  Apa Arti GOAT dalam Sepak Bola? Yuk, Cari Tahu...
# 2  Ciri Cowok Temperamental, Penyebab, dan Cara M...
# 3  10 Olahan Makanan dari Sayuran yang Mudah Dimasak
# 4  Berani Bergeser, Berani Memimpin: Menyelami Ga...

# %%
df["judul_berita"] = df["judul_berita"].apply(
    lambda x: x.strip() + "." if not re.search(r'[.!?…]$', str(x).strip()) else x.strip()
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              137 non-null    object
#  1   category         137 non-null    object
#  2   subcategory      137 non-null    object
#  3   tanggal_publish  137 non-null    object
#  4   judul_berita     137 non-null    object
#  5   tags             128 non-null    object
#  6   konten_berita    137 non-null    object
# dtypes: object(7)
# memory usage: 7.6+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("kompas_lifestyle_cleaned.csv", index=False)

# %% [markdown]
# # Preprocessing Travel

# %%
file_id = "1uk90zJF1UddTu9DLoxQaDr9MnNfoFNO7"
url = f"https://drive.google.com/uc?id={file_id}"

df = pd.read_csv(url)
df.head()
# Out:
#                                                  url category  subcategory  \
# 0  https://money.kompas.com/read/2019/08/01/12421...   Travel  Travel News
# 1  https://travel.kompas.com/read/2025/09/30/1201...   Travel  Travel News
# 2  https://travel.kompas.com/read/2025/10/02/1452...   Travel  Travel News
# 3  https://travel.kompas.com/read/2025/10/10/1201...   Travel  Travel News
# 4  https://travel.kompas.com/read/2025/10/15/1631...   Travel  Travel News
#
#        tanggal_publish                                              judul  \
# 0  2019-08-01 12:42:15  Kompas.com Kembali Jadi Pemenang Kategori Medi...
# 1  2025-09-30 12:01:00  Ekspektasi Vs Realita Wisata Bali yang Disorot...
# 2  2025-10-02 14:52:07  Permudah Turis Asing Datang, Aplikasi All Indo...
# 3  2025-10-10 12:01:00  Kunjungan Wisman Januari–Agustus 2025 Tembus 1...
# 4  2025-11-07 07:49:37  Bali Jadi Pulau Terbaik di Asia 2025, Kalahkan...
#
#                                                 tags  \
# 0              media online, Kompas.com, Superbrands
# 1  Bali, Pariwisata Bali, Wisata bali disorot med...
# 2  Kemenpar, bandara soekarno hatta, Wamenpar Ni ...
# 3  kunjungan wisman, kunjungan wisman 2025, kunju...
# 4         Bali, Bali Jadi Pulau Terbaik di Asia 2025
#
#                                               konten
# 0  JAKARTA, KOMPAS.com — Superbrands, lembaga arb...
# 1  KOMPAS.com - Bali selama ini memang dikenal se...
# 2  KOMPAS.com - Aplikasi "All Indonesia" resmi di...
# 3  KOMPAS.com – Kementerian Pariwisata (Kemenpar)...
# 4  KOMPAS.com — Pulau Bali kembali menegaskan rep...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1042 entries, 0 to 1041
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              1042 non-null   object
#  1   category         1042 non-null   object
#  2   subcategory      1042 non-null   object
#  3   tanggal_publish  1042 non-null   object
#  4   judul            1042 non-null   object
#  5   tags             1042 non-null   object
#  6   konten           1042 non-null   object
# dtypes: object(7)
# memory usage: 57.1+ KB

# %%
df.rename(columns={
    'judul': 'judul_berita',
    'konten': 'konten_berita'
}, inplace=True)

# %%
df.columns.tolist()
# Out:
# ['url',
#  'category',
#  'subcategory',
#  'tanggal_publish',
#  'judul_berita',
#  'tags',
#  'konten_berita']

# %% [markdown]
# ## Null Handling

# %%
df['konten_berita'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Perbaiki Penulisan

# %%
def clean_text(text):
    # mengganti newline dengan spasi
    text = text.replace("\n", " ")
    # hapus spasi berlebih
    text = re.sub(r'\s+', ' ', text).strip()
    # spasi setelah tanda baca jika belum ada
    text = re.sub(r'([.,;:!?])(?!\s)', r'\1 ', text)
    # domain
    #text = re.sub(r'\.(?!\s|[a-zA-Z])', r'. ', text)
    # hapus spasi berlebih setelah penambahan
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  JAKARTA, KOMPAS. com — Superbrands, lembaga ar...
# 1  KOMPAS. com - Bali selama ini memang dikenal s...
# 2  KOMPAS. com - Aplikasi "All Indonesia" resmi d...
# 3  KOMPAS. com – Kementerian Pariwisata (Kemenpar...
# 4  KOMPAS. com — Pulau Bali kembali menegaskan re...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0  Kompas. com Kembali Jadi Pemenang Kategori Med...
# 1  Ekspektasi Vs Realita Wisata Bali yang Disorot...
# 2  Permudah Turis Asing Datang, Aplikasi All Indo...
# 3  Kunjungan Wisman Januari–Agustus 2025 Tembus 1...
# 4  Bali Jadi Pulau Terbaik di Asia 2025, Kalahkan...

# %% [markdown]
# ## Hapus Atribut Teks Tidak Penting

# %%
import re

def clean_kompas_text(text: str) -> str:
    # ubah kompas. com menjadi kompas.com
    text = re.sub(r'(?i)kompas\s*\.\s*com', 'kompas.com', text)

    # hapus lokasi di awal kalimat seperti "JAKARTA, —", "NEW YORK, -", dll
    text = re.sub(
    r'^\s*[A-ZÀ-Ý][A-ZÀ-Ý\s\(\)\/\-\.]*,\s*[–—-]?\s*',
    '',
    text.strip()
    )

    # hapus frasa "Ringkasan berita", "Ringkasan artikel", "Rangkuman berita"
    text = re.sub(
    r'(?i)^(ringkasan|rangkuman)\s+(berita|artikel)\s*[:：–—-]\s*',
    '',
    text.strip()
    )

    # hapus kompas doc
    text = re.sub(r'(?is)kompas\.com/\s*dok\.[^.]*\.', '', text)

    # hapus kompas.com
    text = re.sub(r'(?i)(?:[A-Za-z]*\s*[-–\\\/]*)?kompas\.com[\\/A-Za-z0-9\-]*', '', text)

    # gabungan
    text = re.sub(r'^[A-Za-z\s]*?[a-z](?=[A-Z])', '', text)

    # hapus baca, baca juga, dan kombinasinya
    #text = re.sub(r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n])', '', text)
    text = re.sub(
    r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n]|$)',
    '',
    text)

    # mention
    text = re.sub(r'\(@[^)]+\)', '', text)
    text = re.sub(r'@\w+', '', text)

    # kredit kompas.com\
    text = re.sub(r'(?i)\bkompas\.com/[\w\s.]+?[a-z](?=\s*[A-Z]{2,}|[A-Z][a-z]*[A-Z])', '', text)

    # hapus .com yang mungkin tersisa
    text = re.sub(r'\b\w*\.com\b', '', text, flags=re.IGNORECASE)

    # tanda baca dan spasi
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)
    text = re.sub(r'([.,!?;:])([^\s"”’])', r'\1 \2', text)
    text = re.sub(r'(?<=\w)\(', r' (', text)
    text = re.sub(r'\(\s+', '(', text)
    text = re.sub(r'\s+\)', ')', text)
    text = re.sub(r'\)(?=[A-Za-z0-9])', r') ', text)
    text = re.sub(r'\s+(")', r'\1', text)
    text = re.sub(r'\.\s*"', '. "', text)

    # tanda baca berulang
    text = re.sub(r'([.,!?;:])(\s*\1)+', r'\1', text)
    text = re.sub(r'([.,!?;:])\s*[.,!?;:]+', r'\1', text)
    text = re.sub(r'"\s*"', '"', text)
    text = re.sub(r'""+', '"', text)

    # non huruf awal karakter
    text = re.sub(r'^[^A-Za-z0-9]+', '', text)

    # spasi ganda
    text = re.sub(r'\s{2,}', ' ', text)

    # trim spasi
    text = text.strip()

    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_kompas_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  Superbrands, lembaga arbiter internasional unt...
# 1  Bali selama ini memang dikenal sebagai destina...
# 2  Aplikasi"All Indonesia" resmi diluncurkan untu...
# 3  Kementerian Pariwisata (Kemenpar) melaporkan b...
# 4  Pulau Bali kembali menegaskan reputasinya seba...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_kompas_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0  Kembali Jadi Pemenang Kategori Media Online Te...
# 1  Ekspektasi Vs Realita Wisata Bali yang Disorot...
# 2  Permudah Turis Asing Datang, Aplikasi All Indo...
# 3  Kunjungan Wisman Januari–Agustus 2025 Tembus 1...
# 4  Bali Jadi Pulau Terbaik di Asia 2025, Kalahkan...

# %%
df["judul_berita"] = df["judul_berita"].apply(
    lambda x: x.strip() + "." if not re.search(r'[.!?…]$', str(x).strip()) else x.strip()
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1042 entries, 0 to 1041
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              1042 non-null   object
#  1   category         1042 non-null   object
#  2   subcategory      1042 non-null   object
#  3   tanggal_publish  1042 non-null   object
#  4   judul_berita     1042 non-null   object
#  5   tags             1042 non-null   object
#  6   konten_berita    1042 non-null   object
# dtypes: object(7)
# memory usage: 57.1+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("kompas_travel_cleaned.csv", index=False)

# %% [markdown]
# # Preprocessing Sains

# %%
file_id = "1LDrZ0xhjd6oPfaYwklqBELfk0cIqVer9"
url = f"https://drive.google.com/uc?id={file_id}"

df = pd.read_csv(url)
df.head()
# Out:
#                                                  url category subcategory  \
# 0  https://money.kompas.com/read/2019/08/01/12421...    Sains    Fenomena
# 1  https://www.kompas.com/sains/read/2024/01/27/2...    Sains    Fenomena
# 2  https://www.kompas.com/sains/read/2024/01/28/1...    Sains    Fenomena
# 3  https://www.kompas.com/sains/read/2024/01/28/1...    Sains    Fenomena
# 4  https://www.kompas.com/sains/read/2024/01/29/1...    Sains    Fenomena
#
#        tanggal_publish                                              judul  \
# 0  2019-08-01 12:42:15  Kompas.com Kembali Jadi Pemenang Kategori Medi...
# 1  2024-01-27 20:13:40                               Apa Itu Debu Kosmik?
# 2  2024-01-28 10:36:47  Danau Singkarak Sumatera Barat Diguncang 5 Ren...
# 3  2024-01-28 14:32:00  Berapa Lama Mahluk Nyari Abadi Tardigrade Bisa...
# 4  2024-01-29 16:10:17  5 Manfaat Campuran Bawang Putih dan Jahe untuk...
#
#                                                 tags  \
# 0              media online, Kompas.com, Superbrands
# 1  debu kosmik, debu luar angkasa, ruang angkasa,...
# 2                             gempa, Danau Singkarak
# 3  Tardigrade, Mahluk Nyari Abadi Tardigrade , be...
# 4  manfaat jahe, manfaat bawang putih, manfaat ca...
#
#                                               konten
# 0  JAKARTA, KOMPAS.com — Superbrands, lembaga arb...
# 1  KOMPAS.com - Saat kita melihat ke langit malam...
# 2  KOMPAS.com - Area Danau Singkarak, Sumatera Ba...
# 3  KOMPAS.com - Tardigrade mungkin adalah hewan y...
# 4  KOMPAS.com - Bawang putih dan jahe sama-sama t...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              131 non-null    object
#  1   category         131 non-null    object
#  2   subcategory      131 non-null    object
#  3   tanggal_publish  131 non-null    object
#  4   judul            131 non-null    object
#  5   tags             131 non-null    object
#  6   konten           131 non-null    object
# dtypes: object(7)
# memory usage: 7.3+ KB

# %%
df.rename(columns={
    'judul': 'judul_berita',
    'konten': 'konten_berita'
}, inplace=True)

# %%
df.columns.tolist()
# Out:
# ['url',
#  'category',
#  'subcategory',
#  'tanggal_publish',
#  'judul_berita',
#  'tags',
#  'konten_berita']

# %% [markdown]
# ## Null Handling

# %%
df['konten_berita'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Perbaiki Penulisan

# %%
def clean_text(text):
    # mengganti newline dengan spasi
    text = text.replace("\n", " ")
    # hapus spasi berlebih
    text = re.sub(r'\s+', ' ', text).strip()
    # spasi setelah tanda baca jika belum ada
    text = re.sub(r'([.,;:!?])(?!\s)', r'\1 ', text)
    # domain
    #text = re.sub(r'\.(?!\s|[a-zA-Z])', r'. ', text)
    # hapus spasi berlebih setelah penambahan
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  JAKARTA, KOMPAS. com — Superbrands, lembaga ar...
# 1  KOMPAS. com - Saat kita melihat ke langit mala...
# 2  KOMPAS. com - Area Danau Singkarak, Sumatera B...
# 3  KOMPAS. com - Tardigrade mungkin adalah hewan ...
# 4  KOMPAS. com - Bawang putih dan jahe sama-sama ...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0  Kompas. com Kembali Jadi Pemenang Kategori Med...
# 1                               Apa Itu Debu Kosmik?
# 2  Danau Singkarak Sumatera Barat Diguncang 5 Ren...
# 3  Berapa Lama Mahluk Nyari Abadi Tardigrade Bisa...
# 4  5 Manfaat Campuran Bawang Putih dan Jahe untuk...

# %% [markdown]
# ## Hapus Atribut Teks Tidak Penting

# %%
import re

def clean_kompas_text(text: str) -> str:
    # ubah kompas. com menjadi kompas.com
    text = re.sub(r'(?i)kompas\s*\.\s*com', 'kompas.com', text)

    # hapus lokasi di awal kalimat seperti "JAKARTA, —", "NEW YORK, -", dll
    text = re.sub(
    r'^\s*[A-ZÀ-Ý][A-ZÀ-Ý\s\(\)\/\-\.]*,\s*[–—-]?\s*',
    '',
    text.strip()
    )

    # hapus frasa "Ringkasan berita", "Ringkasan artikel", "Rangkuman berita"
    text = re.sub(
    r'(?i)^(ringkasan|rangkuman)\s+(berita|artikel)\s*[:：–—-]\s*',
    '',
    text.strip()
    )

    # hapus kompas doc
    text = re.sub(r'(?is)kompas\.com/\s*dok\.[^.]*\.', '', text)

    # hapus kompas.com
    text = re.sub(r'(?i)(?:[A-Za-z]*\s*[-–\\\/]*)?kompas\.com[\\/A-Za-z0-9\-]*', '', text)

    # gabungan
    text = re.sub(r'^[A-Za-z\s]*?[a-z](?=[A-Z])', '', text)

    # hapus baca, baca juga, dan kombinasinya
    #text = re.sub(r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n])', '', text)
    text = re.sub(
    r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n]|$)',
    '',
    text)

    # mention
    text = re.sub(r'\(@[^)]+\)', '', text)
    text = re.sub(r'@\w+', '', text)

    # kredit kompas.com\
    text = re.sub(r'(?i)\bkompas\.com/[\w\s.]+?[a-z](?=\s*[A-Z]{2,}|[A-Z][a-z]*[A-Z])', '', text)

    # hapus .com yang mungkin tersisa
    text = re.sub(r'\b\w*\.com\b', '', text, flags=re.IGNORECASE)

    # tanda baca dan spasi
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)
    text = re.sub(r'([.,!?;:])([^\s"”’])', r'\1 \2', text)
    text = re.sub(r'(?<=\w)\(', r' (', text)
    text = re.sub(r'\(\s+', '(', text)
    text = re.sub(r'\s+\)', ')', text)
    text = re.sub(r'\)(?=[A-Za-z0-9])', r') ', text)
    text = re.sub(r'\s+(")', r'\1', text)
    text = re.sub(r'\.\s*"', '. "', text)

    # tanda baca berulang
    text = re.sub(r'([.,!?;:])(\s*\1)+', r'\1', text)
    text = re.sub(r'([.,!?;:])\s*[.,!?;:]+', r'\1', text)
    text = re.sub(r'"\s*"', '"', text)
    text = re.sub(r'""+', '"', text)

    # non huruf awal karakter
    text = re.sub(r'^[^A-Za-z0-9]+', '', text)

    # spasi ganda
    text = re.sub(r'\s{2,}', ' ', text)

    # trim spasi
    text = text.strip()

    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_kompas_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  Superbrands, lembaga arbiter internasional unt...
# 1  Saat kita melihat ke langit malam, langit terl...
# 2  Area Danau Singkarak, Sumatera Barat diguncang...
# 3  Tardigrade mungkin adalah hewan yang paling un...
# 4  Bawang putih dan jahe sama-sama terkenal denga...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_kompas_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0  Kembali Jadi Pemenang Kategori Media Online Te...
# 1                               Apa Itu Debu Kosmik?
# 2  Danau Singkarak Sumatera Barat Diguncang 5 Ren...
# 3  Berapa Lama Mahluk Nyari Abadi Tardigrade Bisa...
# 4  5 Manfaat Campuran Bawang Putih dan Jahe untuk...

# %%
df["judul_berita"] = df["judul_berita"].apply(
    lambda x: x.strip() + "." if not re.search(r'[.!?…]$', str(x).strip()) else x.strip()
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              131 non-null    object
#  1   category         131 non-null    object
#  2   subcategory      131 non-null    object
#  3   tanggal_publish  131 non-null    object
#  4   judul_berita     131 non-null    object
#  5   tags             131 non-null    object
#  6   konten_berita    131 non-null    object
# dtypes: object(7)
# memory usage: 7.3+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("kompas_sains_cleaned.csv", index=False)

# %% [markdown]
# # Preprocessing Bola

# %%
import pandas as pd
import re
import os

# %%
file_id = "1eOpacOsUADGvqNprtC_D29cZRXFeQPWu"
url = f"https://drive.google.com/uc?id={file_id}"

df = pd.read_csv(url)
df.head()
# Out:
#                                                  url category  \
# 0  https://bola.kompas.com/read/2025/11/10/180917...     Bola
# 1  https://bola.kompas.com/read/2025/11/10/231905...     Bola
# 2  https://bola.kompas.com/read/2025/11/10/234616...     Bola
# 3  https://bola.kompas.com/read/2025/11/10/235440...     Bola
# 4  https://bola.kompas.com/read/2025/11/11/001045...     Bola
#
#         subcategory      tanggal_publish  \
# 0  Timnas Indonesia  2025-11-10 18:09:17
# 1  Timnas Indonesia  2025-11-10 23:19:05
# 2  Timnas Indonesia  2025-11-10 23:46:16
# 3  Timnas Indonesia  2025-11-10 23:54:40
# 4  Timnas Indonesia  2025-11-11 00:10:45
#
#                                                judul  \
# 0  Link Live Streaming Timnas U17 Indonesia Vs Ho...
# 1  Live Skor Timnas U17 Indonesia Vs Honduras 2-1...
# 2  Hasil Timnas U17 Indonesia Vs Honduras 2-1, Ga...
# 3  Klasemen Akhir Grup H Piala Dunia U17 Usai Tim...
# 4  Timnas U17 Indonesia Vs Honduras 2-1: 3 Syarat...
#
#                                                 tags  \
# 0  Honduras, Link Live Streaming, timnas u17 Indo...
# 1  Honduras, Piala Dunia U17, timnas u17, Piala D...
# 2  Nova Arianto, timnas u17 Indonesia, Hasil Timn...
# 3  klasemen, timnas u17 Indonesia, Piala Dunia U1...
# 4  Honduras, timnas u17 Indonesia, Piala Dunia U1...
#
#                                               konten
# 0  KOMPAS.com - Timnas U17 Indonesia akan melakon...
# 1  KOMPAS.com - Timnas U17 Indonesia unggul 2-1 a...
# 2  KOMPAS.com - Timnas U17 Indonesia berhasil mer...
# 3  KOMPAS.com - Timnas U17 Indonesia memainkan pe...
# 4  KOMPAS.com - Timnas U17 Indonesia sukses merai...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              218 non-null    object
#  1   category         218 non-null    object
#  2   subcategory      218 non-null    object
#  3   tanggal_publish  218 non-null    object
#  4   judul            218 non-null    object
#  5   tags             218 non-null    object
#  6   konten           218 non-null    object
# dtypes: object(7)
# memory usage: 12.1+ KB

# %%
df.rename(columns={
    'judul': 'judul_berita',
    'konten': 'konten_berita'
}, inplace=True)

# %%
df.columns.tolist()
# Out:
# ['url',
#  'category',
#  'subcategory',
#  'tanggal_publish',
#  'judul_berita',
#  'tags',
#  'konten_berita']

# %% [markdown]
# ## Null Handling

# %%
df['konten_berita'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Perbaiki Penulisan

# %%
def clean_text(text):
    # mengganti newline dengan spasi
    text = text.replace("\n", " ")
    # hapus spasi berlebih
    text = re.sub(r'\s+', ' ', text).strip()
    # spasi setelah tanda baca jika belum ada
    text = re.sub(r'([.,;:!?])(?!\s)', r'\1 ', text)
    # domain
    #text = re.sub(r'\.(?!\s|[a-zA-Z])', r'. ', text)
    # hapus spasi berlebih setelah penambahan
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  KOMPAS. com - Timnas U17 Indonesia akan melako...
# 1  KOMPAS. com - Timnas U17 Indonesia unggul 2-1 ...
# 2  KOMPAS. com - Timnas U17 Indonesia berhasil me...
# 3  KOMPAS. com - Timnas U17 Indonesia memainkan p...
# 4  KOMPAS. com - Timnas U17 Indonesia sukses mera...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0  Link Live Streaming Timnas U17 Indonesia Vs Ho...
# 1  Live Skor Timnas U17 Indonesia Vs Honduras 2-1...
# 2  Hasil Timnas U17 Indonesia Vs Honduras 2-1, Ga...
# 3  Klasemen Akhir Grup H Piala Dunia U17 Usai Tim...
# 4  Timnas U17 Indonesia Vs Honduras 2-1: 3 Syarat...

# %% [markdown]
# ## Hapus Atribut Teks Tidak Penting

# %%
import re

def clean_kompas_text(text: str) -> str:
    # ubah kompas. com menjadi kompas.com
    text = re.sub(r'(?i)kompas\s*\.\s*com', 'kompas.com', text)

    # hapus kompas doc
    text = re.sub(r'(?is)kompas\.com/\s*dok\.[^.]*\.', '', text)

    # hapus kompas.com
    text = re.sub(r'(?i)(?:[A-Za-z]*\s*[-–\\\/]*)?kompas\.com[\\/A-Za-z0-9\-]*', '', text)

    # gabungan
    text = re.sub(r'^[A-Za-z\s]*?[a-z](?=[A-Z])', '', text)

    # hapus baca, baca juga, dan kombinasinya
    #text = re.sub(r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n])', '', text)
    text = re.sub(
    r'(?i)\(?baca(?:\s+(?:juga|selengkapnya))?\s*[:：]\s*[^.!?\n]*(?=[.!?\n]|$)',
    '',
    text)

    # mention
    text = re.sub(r'\(@[^)]+\)', '', text)
    text = re.sub(r'@\w+', '', text)

    # kredit kompas.com\
    text = re.sub(r'(?i)\bkompas\.com/[\w\s.]+?[a-z](?=\s*[A-Z]{2,}|[A-Z][a-z]*[A-Z])', '', text)

    # hapus .com yang mungkin tersisa
    text = re.sub(r'\b\w*\.com\b', '', text, flags=re.IGNORECASE)

    # tanda baca dan spasi
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)
    text = re.sub(r'([.,!?;:])([^\s"”’])', r'\1 \2', text)
    text = re.sub(r'(?<=\w)\(', r' (', text)
    text = re.sub(r'\(\s+', '(', text)
    text = re.sub(r'\s+\)', ')', text)
    text = re.sub(r'\)(?=[A-Za-z0-9])', r') ', text)
    text = re.sub(r'\s+(")', r'\1', text)
    text = re.sub(r'\.\s*"', '. "', text)

    # tanda baca berulang
    text = re.sub(r'([.,!?;:])(\s*\1)+', r'\1', text)
    text = re.sub(r'([.,!?;:])\s*[.,!?;:]+', r'\1', text)
    text = re.sub(r'"\s*"', '"', text)
    text = re.sub(r'""+', '"', text)

    # non huruf awal karakter
    text = re.sub(r'^[^A-Za-z0-9]+', '', text)

    # spasi ganda
    text = re.sub(r'\s{2,}', ' ', text)

    # trim spasi
    text = text.strip()

    return text

# %%
df['konten_berita'] = df['konten_berita'].apply(clean_kompas_text)
print(df[['konten_berita']].head())
# Out:
#                                        konten_berita
# 0  Timnas U17 Indonesia akan melakoni partai pamu...
# 1  Timnas U17 Indonesia unggul 2-1 atas Honduras ...
# 2  Timnas U17 Indonesia berhasil meraih kemenanga...
# 3  Timnas U17 Indonesia memainkan pertandingan te...
# 4  Timnas U17 Indonesia sukses meraih kemenangan ...

# %%
df['judul_berita'] = df['judul_berita'].apply(clean_kompas_text)
print(df[['judul_berita']].head())
# Out:
#                                         judul_berita
# 0  Link Live Streaming Timnas U17 Indonesia Vs Ho...
# 1  Live Skor Timnas U17 Indonesia Vs Honduras 2-1...
# 2  Hasil Timnas U17 Indonesia Vs Honduras 2-1, Ga...
# 3  Klasemen Akhir Grup H Piala Dunia U17 Usai Tim...
# 4  Timnas U17 Indonesia Vs Honduras 2-1: 3 Syarat...

# %%
df["judul_berita"] = df["judul_berita"].apply(
    lambda x: x.strip() + "." if not re.search(r'[.!?…]$', str(x).strip()) else x.strip()
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              218 non-null    object
#  1   category         218 non-null    object
#  2   subcategory      218 non-null    object
#  3   tanggal_publish  218 non-null    object
#  4   judul_berita     218 non-null    object
#  5   tags             218 non-null    object
#  6   konten_berita    218 non-null    object
# dtypes: object(7)
# memory usage: 12.1+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("kompas_bola_cleaned.csv", index=False)
